# %% [markdown]
# # definition 1

# %%
from keras.preprocessing.text import Tokenizer
import codecs
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import nltk
from konlpy.tag import Okt
from tqdm import tqdm

# train set
name = "1"
filename1 = './new_data/definition'+name+'_spynorth_scaling_trust.txt'
filename2 = './new_data/definition'+name+'_spynorth_scaling_untrust.txt'
filename3 = './new_data/definition'+name+'_intistranger_scaling_trust.txt'
filename4 = './new_data/definition'+name+'_intistranger_scaling_untrust.txt'
filename5 = './new_data/definition'+name+'_assassin_scaling_trust.txt'
filename6 = './new_data/definition'+name+'_assassin_scaling_untrust.txt'
filename7 = './new_data/definition'+name+'_1987_scaling_trust.txt'
filename8 = './new_data/definition'+name+'_1987_scaling_untrust.txt'
filename9 = './new_data/definition'+name+'_taxi_scaling_trust.txt'
filename10 = './new_data/definition'+name+'_taxi_scaling_untrust.txt'


with codecs.open(filename1, 'r', encoding='utf-8-sig') as f:
    lines1 = f.readlines()
with codecs.open(filename2, 'r', encoding='utf-8-sig') as f:
    lines2 = f.readlines()
with codecs.open(filename3, 'r', encoding='utf-8-sig') as f:
    lines3 = f.readlines()
with codecs.open(filename4, 'r', encoding='utf-8-sig') as f:
    lines4 = f.readlines()
with codecs.open(filename5, 'r', encoding='utf-8-sig') as f:
    lines5 = f.readlines()
with codecs.open(filename6, 'r', encoding='utf-8-sig') as f:
    lines6 = f.readlines()
with codecs.open(filename7, 'r', encoding='utf-8-sig') as f:
    lines7 = f.readlines()
with codecs.open(filename8, 'r', encoding='utf-8-sig') as f:
    lines8 = f.readlines()
with codecs.open(filename9, 'r', encoding='utf-8-sig') as f:
    lines9 = f.readlines()
with codecs.open(filename10, 'r', encoding='utf-8-sig') as f:
    lines10 = f.readlines()




# test set


with codecs.open('./new_data/definition'+name+'_spynorth_test_t.txt', 'r', 'utf-8-sig') as f:
    test1 = f.readlines()
with codecs.open('./new_data/definition'+name+'_spynorth_test_ut.txt', 'r', 'utf-8-sig') as f:
    test2 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test3 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test4 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test5 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test6 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test7 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test8 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test9 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test10 = f.readlines()

# %% [markdown]
# ## 공작

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1
lines_ut = lines2
test_t = test1
test_ut = test2


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []
for line in lines_t:
    li = []
    r = float(line.split(",")[0])
    senti = float(line.split(",")[1])
    corr = float(line.split(",")[2])
    text = line.split(",")[3]
    lines_.append(text.strip())
    # 네개 다 배열에 넣음
    line1 = line.split(',')
    line1[3] = line1[3].strip()
    lines1_.append(line1)
    li.append(r)
    li.append(senti)
    li.append(corr)
    lines3_.append(li)
    a = line.split(",")[0] +" "+ line.split(",")[1] +" "+ line.split(",")[2]
    feature1.append(a)
    
    

for line in lines_ut:
    li = []
    r = float(line.split(",")[0])
    senti = float(line.split(",")[1])
    corr = float(line.split(",")[2])
    text = line.split(",")[3]
    lines_.append(text.strip())
    line1 = line.split(',')
    line1[3] = line1[3].strip()
    lines1_.append(line1)
    li.append(r)
    li.append(senti)
    li.append(corr)
    lines3_.append(li)
    a = line.split(",")[0] +" "+ line.split(",")[1] +" "+ line.split(",")[2]
    feature1.append(a)

for line in test_t:
    li = []
    r = float(line.split(",")[0])
    senti = float(line.split(",")[1])
    corr = float(line.split(",")[2])
    text = line.split(",")[3]
    test_lines_.append(text.strip()) # trust
    line1 = line.split(',')
    line1[3] = line1[3].strip()
    lines2_.append(line1)
    li.append(r)
    li.append(senti)
    li.append(corr)
    lines4_.append(li)
    a = line.split(",")[0] +" "+ line.split(",")[1] +" "+ line.split(",")[2]
    feature2.append(a)
    
for line in test_ut:
    li = []
    r = float(line.split(",")[0])
    senti = float(line.split(",")[1])
    corr = float(line.split(",")[2])
    text = line.split(",")[3]
    test_lines_.append(text.strip()) # untrust
    line1 = line.split(',')
    line1[3] = line1[3].strip()
    lines2_.append(line1)
    li.append(r)
    li.append(senti)
    li.append(corr)
    lines4_.append(li)
    a = line.split(",")[0] +" "+ line.split(",")[1] +" "+ line.split(",")[2]
    feature2.append(a)

# %%
feature1 = np.array(feature1)
feature2 = np.array(feature2)
feature1
# Out:
# array(['10.0 0.953160524368286 0.0468394756317139',
#        '1.0 0.1366767585277557 0.0366767585277557',
#        '1.0 0.6950927972793579 0.5950927972793579', ...,
#        '10.0 0.2116392850875854 0.7883607149124146',
#        '10.0 0.9076826572418212 0.0923173427581788',
#        '10.0 0.940783143043518 0.059216856956482'], dtype='<U45')

# %%
lines1_
# Out:
# [['10.0', '0.953160524368286', '0.0468394756317139', '재미있네여 황정민 연기둣'],
#  ['1.0',
#   '0.1366767585277557',
#   '0.0366767585277557',
#   'ㅋㅋ 북한의 도발이 다 우파의 모략이야? 어지간히 해라 아무리 정권이 넘어갔어도..ㅡㅡ'],
#  ['1.0',
#   '0.6950927972793579',
#   '0.5950927972793579',
#   '우리나라에서 북한에게 도발을 부탁했다고??   정치성향을 떠나 서해5도 백령도에서 군 복무했던 사람으로 보기 ㅈㄴ 불편했다'],
#  ['10.0',
#   '0.6853748559951782',
#   '0.3146251440048218',
#   '알바들 지들 실체가 들어나니 아주그냥 OO발광이구나 이영화는 전국민이봐야된다 자칭보수라는 애들의 실체가 이 영화에 다 나온다'],
#  ['1.0', '0.4100162386894226', '0.3100162386894226', '정치색이 너무 심함...'],
#  ['1.0',
#   '0.6256514191627502',
#   '0.5256514191627503',
#   '히틀러가 영화로 사람들을 선동했듯  이번 정권은 이 영화를 통해 보수를 부도덕한 악인으로 몰아가고있더라  도대체 이 정권이 히틀러의 선동과 다를게 뭔지  적폐청산이라면서 정작 자기들이 행하는건 적폐인지 모른다는게 소름끼치더라....'],
#  ['1.0',
#   '0.8537758588790894',
#   '0.7537758588790894',
#   '그냥저냥 지루해서 원래라면 6점. 그런데 역겨운 정치병 환자들과 가르치려드는 10점알바들 때문에 무조건 1점. 이거 보고 알바들 부들부들 댈거 생각하니 깨알고소 ㅅㅅㅅㅅ'],
#  ['1.0', '0.2375493943691253', '0.1375493943691253', '걍 정치선전용 영화 그이상 그이하도 아님'],
#  ['1.0',
#   '0.0144155621528625',
#   '0.0855844378471375',
#   '옛날 같았으면 이 영화 만든 감독 쥐도새도 모르게 끌려갔다.... 세상 참 좋아졌다 그제?'],
#  ['1.0', '0.6180214285850525', '0.5180214285850525', '와..  씹노잼..ㄷ ㄷㄷ'],
#  ['1.0', '0.5490031242370605', '0.4490031242370605', '중간에 잤어요..ㅠ 피곤'],
#  ['1.0',
#   '0.5452268123626709',
#   '0.4452268123626709',
#   '첫날은알바들때문에평점이9점대였는데낚인사람들이평점달아서조만간4점대진입할거같음 미션하고신과함께까지는좋았는데공작보고망침 전현적인좌성향영화'],
#  ['1.0',
#   '0.1172494888305664',
#   '0.0172494888305664',
#   '정치병쓰렉영화 제발 정치영화 쳐그니내라특히 북한미화 좌빨영화'],
#  ['1.0',
#   '0.0101397633552551',
#   '0.0898602366447449',
#   '배우들 개개인의 연기는 좋으나.. 쥐어짜는듯한 저질 스토리에 할말을 잃었습니다.진심 1점도 아깝네요ㅡㅡ'],
#  ['1.0', '0.4501606225967407', '0.3501606225967407', '너무 편향이 심한거같아'],
#  ['1.0', '0.3998540341854095', '0.2998540341854094', '선동으로 가득찬 북한 미화 영화'],
#  ['1.0', '0.6971355676651001', '0.5971355676651001', '잠안올때보면 존영화다...'],
#  ['1.0',
#   '0.4928244650363922',
#   '0.3928244650363922',
#   '자기 생각이 진실이라고생각하는 당신이 안타깝소 세상에는생각이 다른사람이 아주 많이 있다오 소위 진보라고 생각하고 영화를 만드는 사람들 그 편협한 생각이 또다른 블랙리스트 라는것을 잊지 마시오 윤감독'],
#  ['10.0', '0.5250243544578552', '0.4749756455421448', '수꼴 일베들이 싫어 할만할 역사적 팩트'],
#  ['10.0',
#   '0.3687919378280639',
#   '0.631208062171936',
#   '불편하실분들이 많아서 평점 테러당할것같더만 역시나 ㅋㅋㅋ'],
#  ['1.0',
#   '0.5313010215759277',
#   '0.4313010215759277',
#   '정치색이 아예 한쪽으로 쭉가버린 선동영화..'],
#  ['1.0',
#   '0.501646101474762',
#   '0.401646101474762',
#   '정치 선동 영화.... 북한은 우리 주적... 잊지말자 주적이다.'],
#  ['1.0', '0.4270825982093811', '0.3270825982093811', '졸릴까 졸린다 연기력은 갑'],
#  ['1.0', '0.6225917339324951', '0.5225917339324951', '정권 바뀌자마자 기다렸다는듯이 ㅋㅋ'],
#  ['10.0', '0.8089179992675781', '0.1910820007324218', '잘봤습니다뜨거운 우정'],
#  ['1.0', '0.536584734916687', '0.436584734916687', '평론가란 것들이 좌좀들 뿐이구나'],
#  ['1.0', '0.4784738421440124', '0.3784738421440123', '졸려죽을뻔 ㅜㅜ 이해 못하겟어요'],
#  ['1.0',
#   '0.3507444858551025',
#   '0.2507444858551024',
#   '역사왜곡은 둘째 치고 영화 자체가 너무 지루..이성민 연기는 훌륭!'],
#  ['1.0',
#   '0.2078806757926941',
#   '0.107880675792694',
#   '아니ㅋㅋㅋㅋ북한미화 왜하는거임? 역겹네역겨워'],
#  ['1.0',
#   '0.0098439753055572',
#   '0.0901560246944428',
#   '간첩이 감독이냐? 김정은이 시키드나? 문재인이 시키드나? 이딴걸 영화라고 만들고 티비에 틀어대는 tvn 빨갱이냐?'],
#  ['1.0',
#   '0.2379208207130432',
#   '0.1379208207130432',
#   '그냥 빨갱이 OOO 영화였다  영화관 나오면서 욕하기는 처음'],
#  ['1.0', '0.4284349977970123', '0.3284349977970122', '좌편향에 선동에~ 대단하다 Cj'],
#  ['10.0', '0.5934062600135803', '0.4065937399864197', '리처장 보는 맛으로 보는 영화..'],
#  ['10.0',
#   '0.2730746269226074',
#   '0.7269253730773926',
#   '이거 1점 주는 애들은 진짜 수준이 얼마나 낮은거냐'],
#  ['1.0', '0.0117760002613067', '0.0882239997386933', '좌파영화 ㅡㅡ뭐지 ..'],
#  ['1.0', '4.0399063436780125e-05', '0.0999596009365632', '영화본시간이아깝다 최악의영화'],
#  ['1.0', '0.0051575005054473', '0.0948424994945527', '쓰레기 중에 쓰레기 빨갱이 영화'],
#  ['1.0',
#   '0.6471819877624512',
#   '0.5471819877624512',
#   '친북영화 아웃... 지금 나라경제가 누구때문에 말아먹고 있는데..'],
#  ['1.0',
#   '0.2968768775463104',
#   '0.1968768775463104',
#   '이념을 떠나서 영화자체가 씹노잼에 집중1도안된다.'],
#  ['10.0',
#   '0.4307425916194916',
#   '0.5692574083805084',
#   '와.. 신과 함께 보다가이거 보니  힐링이네...영화가 좌파니 어쩌니 하는 애들아  시사다큐좀 봐라.'],
#  ['1.0', '0.1476863324642181', '0.0476863324642181', '이건 아니지! 너무 빨갛잖아!!'],
#  ['10.0', '0.3957431316375732', '0.6042568683624268', '황정민 조진웅 이성민끝판왕 끝'],
#  ['1.0', '0.2399109005928039', '0.1399109005928039', '너무한쪽으로모는거아닌가'],
#  ['1.0', '0.0656227469444274', '0.0343772530555726', '재미는 있었지만 의도가 뻔히 보여서 1점'],
#  ['1.0', '0.2430156171321869', '0.1430156171321868', '연평도 장난치나...'],
#  ['1.0', '0.0186166167259216', '0.0813833832740784', '희대의 쓰레기 빨갱이 영화'],
#  ['1.0', '0.4152732491493225', '0.3152732491493225', '적당히해라 북한미화를'],
#  ['1.0', '0.5105477571487427', '0.4105477571487427', '이제 영화까지....'],
#  ['1.0', '0.6225917339324951', '0.5225917339324951', '정지색 오짐ㅋㅋ 좌성향'],
#  ['1.0', '0.3397710919380188', '0.2397710919380188', '참나.. 괜히봤네....'],
#  ['1.0', '0.2249044775962829', '0.1249044775962829', '완전 노잼보다가잣습니다...'],
#  ['1.0', '0.1680832803249359', '0.0680832803249359', '실화를 너무 과장한 듯 합니다'],
#  ['1.0',
#   '0.2201284766197204',
#   '0.1201284766197204',
#   '별루 재미는 없음~글구 제발 북한 미화좀시키지말자~~짜증남!'],
#  ['10.0',
#   '0.5652217268943787',
#   '0.4347782731056213',
#   '말그대로 첩보. 한국 첩보영화의 한 획을 긋다.'],
#  ['1.0', '0.1551055014133453', '0.0551055014133453', '이거 국가보안법 걸려야하는거 아님?'],
#  ['1.0',
#   '0.8062237501144409',
#   '0.7062237501144409',
#   '영화의 허구적인 스토리의 관점에서 보면 볼 만하다. 휴민트 정보가 흘러들어가 대거 숙청되고 안기부  기무사 수 천명을 정리한 것을 안다면 영화스토리는 좌파의 거짓말 논리에 가깝다'],
#  ['10.0',
#   '0.107640117406845',
#   '0.892359882593155',
#   '스파이물이라해서 쌈박질을 생각하면 재미없을듯. 그리고 이걸로 선동이라하는 애들 있는데 진짜 아무리 생각해봐도 김대중 노무현 이름만 나오면 불타오르는 애들이라는 생각밖에 안듦. 제발 적어도 실화인지 아닌지 찾고 욕이나해라.'],
#  ['10.0',
#   '0.72944176197052',
#   '0.27055823802948',
#   '맵지도 달지도않게 잘 만든 영화같음스파이물에서 이렇게 잘 짜여진 한국형 영화는 처음이었고 자극적 요소없이 흐름따라 잘 만든듯.그렇지만 주지훈 연기는 좀...북한사람 역할이면 적어도 말투 연구는 했어야지. .'],
#  ['1.0', '0.0418629348278045', '0.0581370651721955', '찐짜 중말 정말 베리 재미 없네요'],
#  ['1.0', '0.5676426887512207', '0.4676426887512207', '문모대통령 측근들과 관람할듯'],
#  ['10.0', '0.8235436081886292', '0.1764563918113708', '판독기가 돌아갔다고하니 꼭 봐야겠군'],
#  ['1.0', '0.3072675764560699', '0.2072675764560698', '연평도가...선동이네요..'],
#  ['10.0',
#   '0.2170652449131012',
#   '0.7829347550868988',
#   '선동같은소리하고있네자한당OOO들 기웃거리지좀마세요 안창피하시나요'],
#  ['10.0',
#   '0.088980883359909',
#   '0.9110191166400908',
#   '이런 웰 메이드 영화를 보고도 문재인 정부를 위한 영화다  빨갱이 영화다 지껄이는 인간들은 뇌에 우동사리만 찬거냐?'],
#  ['1.0',
#   '0.1025505661964416',
#   '0.0025505661964415',
#   '이래서 내가 국산 영화는 절대 돈주고 안 본다'],
#  ['2.0',
#   '0.4872469305992126',
#   '0.2872469305992126',
#   '아무것도 모르고 봤는데 선동영화였다...;;;'],
#  ['10.0',
#   '0.2593201100826263',
#   '0.7406798899173737',
#   '공작은 총으로 하는게 아니라는걸 보여주는 진짜 공작영화'],
#  ['1.0', '0.402153730392456', '0.3021537303924559', '걍북한 미화 영화 !!!!'],
#  ['1.0',
#   '0.6458020806312561',
#   '0.5458020806312561',
#   'ㄹㅇ 좌좀 영화수준 ㅋㅋ 지금이 북한빠돌이쩝쩝이 시대아니랄까봐 ㅋㅋ 애쓴다 퉷'],
#  ['10.0', '0.9172571301460266', '0.0827428698539733', '베츙이들때문에 10점드립니다^^'],
#  ['1.0', '0.6918486952781677', '0.5918486952781677', '시간 가는줄 알고 봤어요'],
#  ['10.0', '0.897242546081543', '0.102757453918457', '진짜 재밌다 다섯글자로 끝'],
#  ['1.0',
#   '0.0355711877346038',
#   '0.0644288122653962',
#   '공작?? 이 영화를 만든 것 자체가 공작이다. 진짜 무슨 사회의 숨겨진 진실이라도 밝혀내는냥 조작해서 이런 영화를 만들다니.. 나라 지키다가 죽은 사람들은 뭐냐.. 이게 나라냐?'],
#  ['1.0', '0.5162375569343567', '0.4162375569343567', '국민을 개돼지로보는건 좌좀진보였네'],
#  ['1.0',
#   '0.2937548458576202',
#   '0.1937548458576201',
#   '연기는 정말 다 지렸습니다하지만 정치색이 한 쪽으로 너무 쏠려있어서 싫어요'],
#  ['10.0',
#   '0.6009763479232788',
#   '0.3990236520767212',
#   '아직도 찌 ㅈ ㅕ죽여야할 반역자들이 곳곳에 도사리고 있음을 별점 1점짜리 댓글알바를 보면서  다시한번 느낀다'],
#  ['1.0',
#   '0.6375641226768494',
#   '0.5375641226768494',
#   '나는 공산당이 싫어요이런 거짓선동영화가 버젓이 나오다니.. 여기가 북한인가'],
#  ['10.0',
#   '0.2785920202732086',
#   '0.7214079797267914',
#   '사실은 북한은 아무잘못도 없다는걸 이제야 알게 됬네요 이 영화가 아니였으면 몰랐을 사실들... 감사합니다..'],
#  ['10.0',
#   '0.2150816023349762',
#   '0.7849183976650238',
#   '1점 주는 애들은 목적이 뭐지? 한국형 스파이물 이구만.'],
#  ['1.0',
#   '0.1002340614795684',
#   '0.0002340614795683',
#   '정말 재정신으로 영화 만든건가 싶다. 종북이 실제로 존재한다는걸 영화보고 실감했다. 이거 스토리 누가 짠거야? 진짜 사람베이비맞나 싶네...'],
#  ['1.0', '0.3290851414203644', '0.2290851414203643', '차라리 인랑을 봐라 개쓰렉'],
#  ['1.0', '0.0028530359268188', '0.0971469640731812', '사상 최악의  영화 수고해라'],
#  ['10.0', '0.3526169657707214', '0.6473830342292786', '보는내내 긴장감 쩔었다...'],
#  ['10.0',
#   '0.5902650952339172',
#   '0.4097349047660827',
#   '알바들  때문에 10점 먼 정치 인식으로 영화를 평가하냐?'],
#  ['1.0', '0.1060762107372284', '0.0060762107372283', '그냥 좌좀영화....'],
#  ['10.0',
#   '0.9791642427444458',
#   '0.0208357572555542',
#   '잘 만든 영화입니다정신차리고 살아야겠다는 생각이드네요'],
#  ['10.0',
#   '0.5901532173156738',
#   '0.4098467826843261',
#   '영상미죽이네  배우연기 이성민 황정민 조진웅 주지훈까지 연기깔끔  더이상 북풍으로 국민들에게 안통하는걸 확인사살시켜주네'],
#  ['1.0', '0.4571933150291443', '0.3571933150291443', '리얼도피하고  속닥속닥도 피했던난데'],
#  ['1.0', '0.7627969980239868', '0.6627969980239868', '전형적인 좌파 영화. 미국이 적국인듯'],
#  ['10.0',
#   '0.5255007147789001',
#   '0.4744992852210998',
#   '별점봐라 영화를 그냥 정치색에 말고 그냥 영화로 봐라 그리고 내부자들과 비슷하게 분명 저런비리는 존재한다 가능했고 정치인들 하는 더러운짓들을 보면 충분히 실제있는 일이다 그리고 대중이 개돼지가 아니라면 정치에 휘말리지말고 배우들 연기 보면서 즐겨라'],
#  ['10.0', '0.3383520841598511', '0.6616479158401489', '연기들이 볼만함. 추천합니다'],
#  ['1.0', '0.4471614360809326', '0.3471614360809326', '에휴..ㅎ....ㅅ...ㅊ...'],
#  ['10.0',
#   '0.3669712543487549',
#   '0.6330287456512451',
#   '신과함께랑 공작이랑 두개 다봤는데 공작이 낳음'],
#  ['1.0',
#   '0.2489766478538513',
#   '0.1489766478538512',
#   '민주당을 위한 김대중을 위한 빨갱이들을 위한 영화네요'],
#  ['1.0', '0.4927912354469299', '0.3927912354469298', '정치색이 아주 노골적이네요'],
#  ['10.0', '0.8010987043380737', '0.1989012956619262', '볼만합니다 총풍사건이군여'],
#  ['10.0',
#   '0.7973133325576782',
#   '0.2026866674423217',
#   '국정원 알바들의 별점테러에 방어 10점 준다 영화 잘 만들었고 배우들 연기 쩔고 내용도 쫄깃하다 단점없는 거 아니기에 실제로는 8점 정도 드립니다 윤종빈 당신은 말이 너무 많아'],
#  ['1.0', '0.2742177248001098', '0.1742177248001098', '평론가 평점 개오지네.'],
#  ['1.0',
#   '0.8543791770935059',
#   '0.7543791770935059',
#   '실화를 바탕으로 한 영화라고 했으나  중간중간 픽션들을 사실인냥 끼워집어 넣은 영화. 특정 정치색에 편중됐다는 느낌을 영화 끝날 때까지 지울 수 없었다. 명품배우들의 연기로 빠져들다가도 내용 때문에 집중할 수 없었던 기분 나쁜 영화였음.'],
#  ['1.0',
#   '0.2173016965389251',
#   '0.117301696538925',
#   '진부한 전개  짜맞춘 긴장감  연기는 잘해서 2점.'],
#  ['10.0', '0.294168472290039', '0.7058315277099609', '역사를 잊은 민족에게 미래는 없다.'],
#  ['1.0', '0.2956620454788208', '0.1956620454788208', '빨갱이영화 북한놈들 ㅂ꺼지라'],
#  ['1.0', '0.1600529253482818', '0.0600529253482818', '개돼지들이 환장할 ㅈ같은 좌파영화만들었네'],
#  ['1.0',
#   '0.0467063784599304',
#   '0.0532936215400696',
#   '화가난다. 연평도가 정권 개입을 위한 수단이었다? 진짜 이 영화에 쓴 내 11000원이 아깝다'],
#  ['1.0',
#   '0.2649003863334656',
#   '0.1649003863334655',
#   '노잼 영화  이런 영화 출연하는 배우까지 밉다'],
#  ['1.0', '0.0922261178493499', '0.00777388215065', '북한은 쓰레기 집단이다'],
#  ['1.0',
#   '0.3972221314907074',
#   '0.2972221314907074',
#   '희대의 OOO기 영화. 영화적 가치는 리얼 인랑을 압도하고 픽션이라는 되도않는 변명으로 정치왜곡과 개돼지 선동을 보여주는 개돼지 전용 영화'],
#  ['1.0', '0.6798430681228638', '0.5798430681228638', '평점 왜 이렇게 높나요?'],
#  ['1.0', '0.6225917339324951', '0.5225917339324951', '핵대중 미화 오지네 ㅋㅋ'],
#  ['1.0',
#   '0.1433821618556976',
#   '0.0433821618556976',
#   '여자친구는 재밌었다는데 개인적으로 재미없었음 순국하신 장병들을 얼마나 더럽히고 모욕해야는지 혹여 북한과 정부의 자작극이라 할지라도 북한에 의해 순국한건 사실이고  추측으로 매도하는 감독은 북한에게 포쏴달라는 쓰.레.기들하고 동급이야 이 개.새.끼야'],
#  ['1.0',
#   '0.0462804436683654',
#   '0.0537195563316346',
#   '진짜 ㅈ 노잼 개재미없으 제발 보지마셈 ㅋㅋㅋㅋ'],
#  ['1.0', '0.3010319471359253', '0.2010319471359253', '선동하지마슈 감독양반'],
#  ['1.0',
#   '0.006420612335205',
#   '0.093579387664795',
#   '보는내내...너무지루해서졸았음ㅠㅠ영화보면서존거처음..기대했는데뭔가 반전도없고..감동도없고그냥 한분위기로 쭉~~~~ 진짜너무지루했음..'],
#  ['1.0',
#   '0.0302260518074035',
#   '0.0697739481925965',
#   '1점도 아깝다 안기부해체 국정원해체 기무사해체대한민국간첩잡이들 다 없애고 간첩은 이제 누가 잡나?? 요즘 같은 평화시대에 간첩이 어디있냐는 철수같은 소리 또 하면 개돼지지뭐...'],
#  ['10.0',
#   '0.338046133518219',
#   '0.661953866481781',
#   '팩트를 정확히 표현한 영화선동이라는 말로 까내리려는 무식한 종자들이 현실을 좀 직시 했으면..'],
#  ['10.0',
#   '0.8662640452384949',
#   '0.1337359547615051',
#   '보는내내 빅꿀잼 ㄹㅇ루 최고임. 주작뭐라하시는 것들은 팩트체크하고오시져'],
#  ['10.0',
#   '0.8389002084732056',
#   '0.1610997915267944',
#   '스토리 소재도 흥미롭고배우들 연기력 수준이 높아서영화에 더 몰입할 수 있었습니다저는 재밌게 봤습니다!'],
#  ['1.0', '0.0363780558109283', '0.0636219441890717', '빨갱 선동영화ㅡㅡ미친'],
#  ['1.0',
#   '0.0485205352306366',
#   '0.0514794647693634',
#   '별 한개도 아까움. 이런 영화가 버젓이 개봉되다니 나라의 앞날이 심히 걱정됩니다.'],
#  ['1.0',
#   '0.0001844465732574',
#   '0.0998155534267426',
#   '좌파 선동 영화 재미도 없고 감흥도 없고 최악'],
#  ['1.0',
#   '0.091250866651535',
#   '0.0087491333484649',
#   '아무내용없는 북한찬양일색북쪽에서 개봉했어야할 영화'],
#  ['1.0',
#   '0.6015651822090149',
#   '0.5015651822090149',
#   '좌파의 역겨운 자기합리화영화윤종빈 감독 실망이다'],
#  ['1.0', '0.0006826817989349', '0.0993173182010651', '재미없다재미없다재미없다'],
#  ['1.0',
#   '0.8310613632202148',
#   '0.7310613632202149',
#   '북한   문재인 김대중 노무현 빠는 영화임~ 대실망'],
#  ['1.0',
#   '0.2602691352367401',
#   '0.1602691352367401',
#   '찬양할게 없어서 김정일 살인마 새끼를 위대한 지도자로 찬양하냐. 노답이다..'],
#  ['1.0',
#   '0.3396404981613159',
#   '0.2396404981613159',
#   '대단하네 ㅋㅋ 고상한척하면서 누구를 미화 하네 ㅋㅋㅋ 개노답 ㅋㅋㅋ'],
#  ['1.0',
#   '0.3190580010414123',
#   '0.2190580010414123',
#   '우매한 백성들 선동하기 딱 좋은 영화다 그제이?'],
#  ['1.0', '0.368878424167633', '0.2688784241676329', '연기만 좋았다....'],
#  ['1.0',
#   '0.1278482377529144',
#   '0.0278482377529143',
#   '북한미화 잘 봤습니다.나중에는 6.25도 남한이 먼저 선제공격한걸로 만들겠네요북한 주민 죽어가는 그런 장면을 왜 넣어서 동정심 들게하는건 또 뭔지?'],
#  ['2.0',
#   '0.0402055084705352',
#   '0.1597944915294648',
#   '김정일이 왜 우파 정권에 협조하냐? 그리고 김대중을 마치 정의로운 투사로 묘하하는데 김다중이 북한은 핵을 만들 의지가 없다란 개소리에 한반도는 핵위협에 산다 앞뒤내용 맞지않고 개돼지 선동용으로 영화를 상연하니 말세다'],
#  ['1.0', '0.5288988947868347', '0.4288988947868347', '노잼ㅇㅇ노잼ㅇㅇ노잼'],
#  ['10.0',
#   '0.829988956451416',
#   '0.1700110435485839',
#   '알바들 별점 작업 고생들한다  근데재밌더라  꼭 보고  별 점 눌러라.   ㅋㅋ 그리고  요즘 시댕ㆍ기 좌빨좌빨   이런거  안먹히더라  프레임좀  바꾸자알바들  분탕질에  놀아나는  모지리들은  좀  생각좀  하고살길'],
#  ['1.0', '0.0030588507652282', '0.0969411492347718', '감동도 없고 재미도 없다...'],
#  ['1.0', '0.5103067755699158', '0.4103067755699158', '결국 레드 선동이 참 쉽다.'],
#  ['1.0',
#   '0.1624245941638946',
#   '0.0624245941638945',
#   '이런영화인줄 알았다면 절대 안봤을텐데기분이 엄청 더럽네 아 씨'],
#  ['10.0', '0.9924287796020508', '0.0075712203979492', '최고입니다 올해 최고의 영화!!'],
#  ['1.0',
#   '0.2920967638492584',
#   '0.1920967638492584',
#   '북한 옹호도 적당히... 이게 나라구나.무섭다. 어찌 적국을...'],
#  ['1.0', '0.5989444851875305', '0.4989444851875305', '진짜 김대중찬양 영화네ㅋㅋㅋ어이없다'],
#  ['1.0',
#   '0.312224268913269',
#   '0.2122242689132689',
#   '일단 안보고 반개드림. 댓글에 종북 좌파 미화 영화라고 해서.'],
#  ['10.0', '0.7297263145446777', '0.2702736854553222', '올해본 영화중 마녀와 공작이 젤 낫다'],
#  ['2.0',
#   '0.0277305841445922',
#   '0.1722694158554078',
#   '아 정치 영화 그만왜이렇게 요즘 정치 영화가 많냐이럴줄알았음 안봤음밑도끝도없다'],
#  ['1.0',
#   '0.1898725032806396',
#   '0.0898725032806395',
#   '윤감독님 이전 영화 너무 좋아했는데 이건 아니죠. 대중이 쩔뚝이 자식이 북한에 내 세금으로 원조평화한거잖아요. 북한 빨갱이들이 얼마나 야비한데 북한을 평화수호자처럼 포장?? 연평해전때 북한 포격에 팔잘리고  다리 잘리고 목숨 잃은 청년들은 소모품??'],
#  ['1.0', '0.3480429649353027', '0.2480429649353026', '대한민국 국민 맞냐...'],
#  ['2.0', '0.2122255563735962', '0.0122255563735961', '문재잉이 공작하는 영화대중이가 왜나와'],
#  ['1.0', '0.5160923600196838', '0.4160923600196838', '개10노잼 진심입니다'],
#  ['1.0',
#   '0.4109365046024322',
#   '0.3109365046024321',
#   '북한 미화좀 작작하세요.그리고  연평도 쏜게 우리나라가 북한한테 부탁한짓이다.??이런 픽션을 그려놓고 마지막에 사실을 기반으로 했다하면 뭔말이요피해자들 눈에 피눈물 나오게 만드는 선동영화 보는내내 불편했네요 진짜.'],
#  ['1.0',
#   '0.34455007314682',
#   '0.24455007314682',
#   '이석기가 만든 영화인줄... 좌파의 좌파에 의한 좌파를 위한 선전선동 영화. 좌파 빨갱이 미화 조작선동 모략질도 이정도면 선을 넘어도 한참 넘어 이적행위로 국가보안법에 의해 처벌해야 된다고 본다. 참으로 문재인스럽다.'],
#  ['1.0', '0.3428378701210022', '0.2428378701210022', '종북영화 종북영화..'],
#  ['1.0',
#   '0.5751931071281433',
#   '0.4751931071281433',
#   '연기를 떠나서 자라나는 청소년들이 이 영화를 보고 사실로 생각할까 우려스럽다. 확인되지 않은 사실을 말하며 사실기반영화라니.. 실망스럽다 감독'],
#  ['1.0',
#   '0.4448169469833374',
#   '0.3448169469833374',
#   '희대의 사기영화 개대중이가 문재앙이가 그리좋아?'],
#  ['10.0', '0.988666296005249', '0.0113337039947509', '잘봤어요~긴장감 최고'],
#  ['10.0',
#   '0.8211014866828918',
#   '0.1788985133171081',
#   '내가 지금까지 본 한국 영화중 가장 무겁다.'],
#  ['1.0',
#   '0.1514141261577606',
#   '0.0514141261577605',
#   '한국영화계를 좌파가 점령했다는걸 보여주는영화....북한은 왜이리 미화하는지;'],
#  ['10.0',
#   '0.6127904653549194',
#   '0.3872095346450805',
#   '일베충들 평점테러만 아니면 9점은 넘을영화'],
#  ['1.0', '0.0765610635280609', '0.0234389364719391', '이건 좀     아니지 않나..'],
#  ['10.0',
#   '0.052306592464447',
#   '0.947693407535553',
#   '호불호가 갈릴수밖에없는 정치적영화 그렇지만실제로 있는흑금성이야기를 모르시는분들은봐도 상관없을것이다 지루한면이 있었지만 볼만한 구강액션영화'],
#  ['8.0',
#   '0.9829785227775574',
#   '0.1829785227775573',
#   '실화 기반에 첩보 드라마!! 이런류의 영화도 울나라에서 많이 나와야 하지 않겠냐? 맨날 국정원이 총쏘고 액션하는것도 좋지만  담백하게 말로도 충분이 재미있게 잘 풀어낼수 있거늘'],
#  ['1.0', '0.0728560090065002', '0.0271439909934998', '김대중 미화는 1점을 줘야겠지요?'],
#  ['1.0',
#   '0.4487637877464294',
#   '0.3487637877464293',
#   '빨갱이가 그리 좋나요??  머하는 겁니까?'],
#  ['1.0',
#   '0.5443704128265381',
#   '0.4443704128265381',
#   '너무 편파적인데요?현정권에서만 나올수 있는 영화'],
#  ['1.0', '0.8473443984985352', '0.7473443984985352', '좌편향적인 정치색 짙은 영화!'],
#  ['9.0',
#   '0.9868900179862976',
#   '0.0868900179862975',
#   '올해 본 영화중 가장 몰입하며 본 영화  조조할인으로 봣는데 만석인거 처음봤다. 신과함께  미션임파서블 보다 오히려 더 재밌었던. 다만 정치색이 너무 강해 후반부로 갈수록 보기 불편했다'],
#  ['10.0', '0.9083948731422424', '0.0916051268577575', '이성민 진짜 연기 잘한다'],
#  ['1.0',
#   '0.0776807069778442',
#   '0.0223192930221558',
#   '제에발 영화에 정치색좀 넣지마라 진짜 승질나네 대통령도 어짜피 문재인인대 아직도 이러는 이유가뭐야?? 영화는 좀 중립적으로 만들라고 쫌'],
#  ['2.0', '0.5348181128501892', '0.3348181128501892', '미친 좌빨영화 보게만드네'],
#  ['1.0',
#   '0.8073492646217346',
#   '0.7073492646217346',
#   '빨갱이 새끼들 눈물콧물 질질 싸다가 오르가즘까지 느낄듯ㅋㅋㅋㅋ 에휴 빨갱이새끼들 니네가 하는 짓이 그렇지뭐~ 내가하면 로맨스  남이하면 불륜^^ 할줄 아는 건 선동밖에 없는 새끼들. 오로지 감성에 젖어서 갈대보다도 쉽게 선동당하는 우리 국민들^^'],
#  ['1.0', '0.0022291243076324', '0.0977708756923676', '정치색 그득한 최악의 좌편향 영화'],
#  ['1.0', '0.5331175923347473', '0.4331175923347473', '효ㅕ헐섯ㄹ설허려 허'],
#  ['1.0',
#   '0.5487053394317627',
#   '0.4487053394317627',
#   '거짓으로 드러난 총풍사건을 사실인양 믿게만듬 보수는 언제나 악 진보는 정의로 그려냄 김대중을 북이 싫어하는 인물로 종북색을 흐림 당선시 해방이라도 한듯 온국민이 환호하는 장면만찍어 국가의 영웅인양 그려냄6.25는 실패한 통일전쟁이다- 김대중 -'],
#  ['1.0', '0.4619496762752533', '0.3619496762752533', '평점이 이상하게 높네 소신있게'],
#  ['1.0',
#   '0.6710333824157715',
#   '0.5710333824157715',
#   '잠자기 좋은 영화황정민씨 팬 이었는데이번 영화는 글쎄 폭망 할 것 같은예감'],
#  ['10.0',
#   '0.7275370955467224',
#   '0.2724629044532776',
#   '첨에 혹평들보고 흔들렸는데 결국 재밌게봤음 신경안쓰고 편안한 관람하시면 될듯'],
#  ['1.0', '0.349586009979248', '0.2495860099792479', '좌편향식 영화 우덜식 영화'],
#  ['1.0',
#   '0.5739508271217346',
#   '0.4739508271217346',
#   '진짜 보는 내내 불편했다 국민이 개 돼지다'],
#  ['10.0', '0.4765869975090027', '0.5234130024909973', '일베충들 단체로와서 분탕질하네'],
#  ['1.0', '0.4060568809509277', '0.3060568809509276', '왜 400만이넘게 본지 모르겠다'],
#  ['1.0',
#   '0.5092605352401733',
#   '0.4092605352401733',
#   '확실한거 총기무력 도발 사실이지만너무 미하네'],
#  ['10.0',
#   '0.9954794645309448',
#   '0.0045205354690551',
#   '몰입도 최고입니다. 명배우들이라 연기력도 최고에요'],
#  ['1.0',
#   '0.1322855651378631',
#   '0.0322855651378631',
#   '0 점 없냐. 역사 왜곡 진실 왜곡 나라 망치는 OOO기 영화 망해라'],
#  ['1.0',
#   '0.5733404159545898',
#   '0.4733404159545898',
#   '빨갱이의  빨갱이에 의한  빨갱이를 위한..'],
#  ['8.0',
#   '0.2106272578239441',
#   '0.589372742176056',
#   '이거재미없다느니 댓글알바라는애들은 수준이 어느정도인건가ㅋㅋ 가서 니들이 좋아하는 유치하지만 영상미좋은 마블시리즈나 봐라 이정도 수준의 첩보영화면 상당히 잘만든영화다'],
#  ['1.0',
#   '0.0433041453361511',
#   '0.0566958546638489',
#   '영화에 정치색 들어가있다 = 개 쓰레기 영화^^'],
#  ['1.0',
#   '0.4437907040119171',
#   '0.3437907040119171',
#   '전형적인 좌빨미화영화국뽕미화 좌빨미화 영화는 믿고 거르세요'],
#  ['1.0',
#   '0.0140378773212432',
#   '0.0859621226787568',
#   '너무 1점이 많고 김대중 선전영화라는데 그럼 안 봐도 뻔하니 보기를 포기해야겠다.'],
#  ['1.0',
#   '0.2848809659481048',
#   '0.1848809659481048',
#   '보통 영화의 클라이믹스는 가장 감동적인 장면이 차지하는데 이 영화는 김대중이 당선되는 순간에 가장 웅장한 음악이 나오며 클라이믹스임을 알림 ㅋㅋ 사람들 백이면 백 다 뭐냐는 표정 ㅋㅋㅋㅋ 여친이랑 절대 보지말것'],
#  ['2.0', '0.402153730392456', '0.202153730392456', '김대중 찬양 북한미화 영화'],
#  ['1.0',
#   '0.2181329429149627',
#   '0.1181329429149627',
#   '박근혜가 괜히 블랙리스트를 만든게 아니라는 생각이 들게 한 영화 심지어 지원을 하지 않은게 죄도 아니고 이번 정부도 화이트리스트 블랙리스트 존재함 ㅋㅋㅋㅋ'],
#  ['10.0',
#   '0.9478491544723512',
#   '0.0521508455276488',
#   '실화라서 더욱 몰입도 충분!  이이제이 듣고 만들었다죠! 현대사적으로도 가치있는 수작입니다!'],
#  ['10.0',
#   '0.3069380521774292',
#   '0.6930619478225708',
#   '일베 벌러지 같은 것들 ㅋㅋ 그래봤자 니들은  넷상에서나 상남자 ....현실에선 기집같은 것들 ㅋㅋ'],
#  ['1.0',
#   '0.1484129428863525',
#   '0.0484129428863525',
#   '요즘 영화 는 너무 좌향좌로 가는거 같아서 한국영화 보기가 싫어진다영화인들이 좌파가 많은건지 아님 좌파를 표방하는건지 너무 정치적이고 북을 찬양하는듯한 영화다. 제발 이러지 맙시다. 국민들도 알건 압니다.'],
#  ['1.0',
#   '0.8505294919013977',
#   '0.7505294919013977',
#   'ㅋㅋㅋ 알바쓸거면 좀 티안나게하지 10점짜리 알바들 너무 티난다 야~'],
#  ['1.0',
#   '0.4441629350185394',
#   '0.3441629350185393',
#   '연기고 나발이고 재미가 있어야지 연기 구경하러 가나'],
#  ['10.0',
#   '0.8152337074279785',
#   '0.1847662925720214',
#   '10점짜리는 아니지만  1점 주는 인간들 짱나서 10점 준다.'],
#  ['1.0', '0.5432490706443787', '0.4432490706443787', '리얼을피했으면 공작도피하라'],
#  ['1.0', '0.4337955117225647', '0.3337955117225647', '하아..거의 판타지....'],
#  ['1.0',
#   '0.0068627595901489',
#   '0.0931372404098511',
#   '1점도 주기아까운 좌파식 내로남불 선동영화'],
#  ['1.0',
#   '0.771289050579071',
#   '0.6712890505790711',
#   '김대중이 북한에다가 14조원을 퍼다줘서 지금 우리가 김정은에게 인질잡힌 것인데 그것을 미화하는 영화인것 같아서 거부감이 들었다.. 그리고 터무니없는 결말...씁슬하다 그래서 비추한다'],
#  ['10.0', '0.4016051888465881', '0.5983948111534119', '영화보다 더 영화같은 이야기'],
#  ['10.0', '0.4028452932834625', '0.5971547067165375', '수구꼴통 토착왜구들 부들부들'],
#  ['1.0',
#   '0.2289357185363769',
#   '0.1289357185363769',
#   '좌파는 선동용 영화로 권력의 콩고물 먹는거 안지겹냐?'],
#  ['1.0', '0.1826428771018982', '0.0826428771018981', '안봐도 뻔한  빨갱이영화 아님?'],
#  ['1.0',
#   '0.2419238984584808',
#   '0.1419238984584808',
#   '보다보니 좌편향적인 정치적 영화라 중간에 껏음.. 재미도 없고'],
#  ['1.0', '0.6186666488647461', '0.5186666488647461', '어떤섹기들이 이영화보냐전라도냐?'],
#  ['1.0',
#   '0.6216526031494141',
#   '0.5216526031494141',
#   '약간의 사실 대부분의 허구 음모론에 기반한 역시는 역시인가'],
#  ['1.0',
#   '0.0023908913135528',
#   '0.0976091086864472',
#   '1개도 아깝다 지루하고 북한 미화를 다루는 영화.'],
#  ['1.0', '0.2116009891033172', '0.1116009891033172', '북한 없었으면 어쩔뻔 했어'],
#  ['1.0',
#   '0.1654937267303466',
#   '0.0654937267303465',
#   '댓글보니 가관이네요정치색이 이렇게 짙은 영화는 처음입니다뭐가 팩트고 뭐가 픽션인지 구분도 안돼는 영화네요'],
#  ['1.0', '0.0036177933216094', '0.0963822066783906', '개 선동영화 1점도 아까움 ㄹㅇ'],
#  ['1.0',
#   '0.2591250538825989',
#   '0.1591250538825988',
#   '배우들의 명연기는 영화를 살렸다. 내용이 산으로 갔을뿐.'],
#  ['10.0',
#   '0.3836370706558227',
#   '0.6163629293441772',
#   '좌냐. 우냐가 아니라. 옳고 그름의 기준으로 본다면 좋은 영화일 수 있다. 그리고 이건.. 그것이 알고싶다가 아니라. 픽션을 기반으로한 상업영화이니까..'],
#  ['1.0', '0.7827215790748596', '0.6827215790748596', '좌좀이 뭔지에 대해 생각하게하는 영화'],
#  ['1.0',
#   '0.2918988764286041',
#   '0.1918988764286041',
#   '극혐 좌편향 미화영화다 연평도포격을 북한에부탁햇다는 그런 개소리를 하는 ....'],
#  ['1.0', '0.2428005337715149', '0.1428005337715149', '카메라를왼쪽으로만들고찍은듯'],
#  ['10.0', '0.4465260803699493', '0.5534739196300507', '평점 테러 방지 위원회 ^^'],
#  ['2.0',
#   '0.0472285747528076',
#   '0.1527714252471924',
#   '그냥 선동영화 나라를 빨간색으로 만들려고 작정한거같음'],
#  ['1.0',
#   '0.7006357312202454',
#   '0.6006357312202454',
#   '영화를 보고 싶은데 자꾸 정치병 걸린 지들 생각만 주입하네  예전에 한국영화는 벗기는게 꼴보고 싫었고  그다음에는 조폭영화가 주구장창 나와 싫었는데  이제는 죄다 정치병 걸린 나팔수들 기록물 뿐.'],
#  ['1.0', '0.0656074583530426', '0.0343925416469574', '아 이건 아니지 ㅅㅂ ㅋㅋ'],
#  ['10.0', '0.9714310169219972', '0.0285689830780028', '최근본 영화중 가장재밌게 본영화'],
#  ['1.0',
#   '0.2720372974872589',
#   '0.1720372974872589',
#   '총풍사건은 수사 과정에서 고문이 있었다는 것은 알고 있냐? 고문으로도 당시 정부 및 이회창 캠프와는 연관성을 못 만들었다.  감독이 선동하는 영화다.  http://shindonga.donga.com/Library/3/02/13/106202/1'],
#  ['1.0',
#   '0.8781321048736572',
#   '0.7781321048736572',
#   '북한을 미워하지는 말아도 안타깝게 돌아가신 우리 국군장병분들에게 조금이라도 미안한 마음이 들게 한다면 보고싶지 않습니다.'],
#  ['1.0',
#   '0.1734301149845123',
#   '0.0734301149845123',
#   '아니 공산당이 싫다는데 반대하는애들은 뭐냐진짜 북괴군이 이걸 보고있나봐!!!!잡았다 괴례군!!!!'],
#  ['10.0',
#   '0.3245621025562286',
#   '0.6754378974437714',
#   '총풍사건이 뭔지 모르는 일베충들이 보면 발작하는 영화'],
#  ['10.0',
#   '0.2333682775497436',
#   '0.7666317224502563',
#   '개누리당놈들은 이영화 싫어합니다개누리놈들 이영화가실화가 아니었으면 상영금지가처분신청했은텐데 이런영화가 나와서다행이다'],
#  ['1.0',
#   '0.7148619890213013',
#   '0.6148619890213013',
#   '와 김머중 당선뜨고 바로 영화 끔 대한민국 멸망의 시작'],
#  ['1.0', '0.5680232048034668', '0.4680232048034668', '정치선동영화 역겹네 진짜'],
#  ['1.0',
#   '0.0117513537406921',
#   '0.0882486462593079',
#   "1점도 아깝다  감독 인터뷰 보고 대충 예상했지만 아니나 다를까 대놓고 좌향좌네... 바나나향 첨가 해놓고 바나나 우유라고 우기는 것처럼 현실 10%에 허구 90%로 글 써놓고 사실을 기반으로 했데ㅋㅋㅋ 대단하다 진짜 '짝짝짝'"],
#  ['8.0',
#   '0.3595005571842193',
#   '0.4404994428157807',
#   '솔까 이 영화는 좌파라고 욕먹을 수 있다고 생각하는데  518관련 영화는은 좌파가 아니지 ㅋㅋㅋ 왜 좌파냐 ? 전두환을 옹호는거냐? 니들이 말하는 좌파 우파 정의가 궁금하네. 쿠데타로 대통령이 되어도 저렇게 감싸주니'],
#  ['1.0', '0.0070362389087677', '0.0929637610912323', '1점도 아까운 간첩 영화'],
#  ['2.0',
#   '0.219626784324646',
#   '0.0196267843246459',
#   '와 평점 감상평 안봤으면 낚여서 볼뻔했다..'],
#  ['1.0',
#   '0.2979984283447265',
#   '0.1979984283447265',
#   '정치색이 노오오오란 영화.그짝동네에서 좋아할듯한 영화.'],
#  ['1.0', '0.2574500143527984', '0.1574500143527984', '이거이.. 빨갱이 아이오?'],
#  ['1.0', '0.2723327577114105', '0.1723327577114105', '영화로 북한 미화시키기 이제 보기 싫다'],
#  ['1.0', '0.1567956507205963', '0.0567956507205963', '초딩도 아니고 고마합시다.'],
#  ['1.0',
#   '0.2765393257141113',
#   '0.1765393257141112',
#   '영화 이렇게 만들어도 되는건가요? 북한을 이렇게 묘사해도 되는건지 모르겠네'],
#  ['1.0',
#   '0.402153730392456',
#   '0.3021537303924559',
#   '김일성 김정일 김정은 게섹희 독재세습 미화 영화'],
#  ['10.0', '0.9944311380386353', '0.0055688619613647', '최고입니다! 잘봤습니다!'],
#  ['10.0',
#   '0.9953970909118652',
#   '0.0046029090881347',
#   '영화가 담고 있는 묵직한팩트 신들린 연기도 좋지만 영화자체도 몰입감이 끝내주는 재밌는 영화였다'],
#  ['1.0',
#   '0.7459453344345093',
#   '0.6459453344345093',
#   '첨으로 보다가 나감 ㅋㅋ 진짜 역겨울정도로 너무하다 ㅋㅋ'],
#  ['1.0', '0.2631162405014038', '0.1631162405014038', '응 좌빨영화 안봐 ㅋㅋㅋ'],
#  ['10.0',
#   '0.1858359575271606',
#   '0.8141640424728394',
#   'ㅋㅋ일베충들의 1점테러 오졌네 부정하는가 북풍'],
#  ['1.0', '0.2899646759033203', '0.1899646759033203', '보다자는 몇안되는 영화 신과함께=공작'],
#  ['10.0',
#   '0.0574313402175903',
#   '0.9425686597824096',
#   '그것이 알고싶다 보고 역시 한국 보수들 쓰레기 역겨움 치를 떨게 되었다 매번 민주당 빨갱이다 하면서 진짜 빨갱이랑 손잡고 지들 권력 오래 빨려고 돈까지주며 자기 국민들목숨 앗아가게 전쟁 도발 수준을 부탁하는 개같은 자한당들 이제 더는 권력 못잡을거다'],
#  ['10.0', '0.3118133544921875', '0.6881866455078125', '틀딱알바들 평점테러판치네'],
#  ['1.0',
#   '0.2020694315433502',
#   '0.1020694315433501',
#   '개정은이 똥꼬나 핣는 재앙이가 제일 좋아할만한 영화네요'],
#  ['1.0', '0.2959609031677246', '0.1959609031677246', '"공작이 아닌 공""좌""악.. "'],
#  ['1.0',
#   '0.0602585673332214',
#   '0.0397414326667786',
#   '솔직히 지루해서 나오고 싶었다.. 너무 잔잔바리하다'],
#  ['1.0', '0.6560134887695312', '0.5560134887695313', '잘가다가 마지막에 이상한 정치색집어넣기'],
#  ['10.0',
#   '0.3867709040641784',
#   '0.6132290959358215',
#   '남한의 자칭보수라는 세력들이 북한수뇌부와 결탁하여 서로의 기득권을 유지하기위한 도발을 행한다는건 이미 알만한 사람들은 다 아는 이야기들..대표적으로 대선앞두고 한나라당 선거캠프에서 북한군에 휴전선에서 총한발만 쏴달라고 부탁한 총풍사건이 유명하지.'],
#  ['1.0',
#   '0.1716078519821167',
#   '0.0716078519821167',
#   '캬..ㅋㅋㅋㅋ주지훈 북한 사투리 어색함은 몸둘바를 모르겠고.. 말도안되는 스토리.. 전혀 논리적이지 못한 전개.. 전형적으로 보수를 아무이유 없이 까대는 좌편향 영화다.. 나도 진보지만.. 영화가 이러면 안되죠~'],
#  ['10.0',
#   '0.3480589389801025',
#   '0.6519410610198975',
#   '평점 태극기 부대들이 작업한...영화는 재미나요..영화는 영화일뿐...오버하는 댓글부대들 ㅉㅉㅉ'],
#  ['1.0', '0.4249378442764282', '0.3249378442764282', '영화에 팩트보다는 정치색이 ...'],
#  ['1.0',
#   '0.0264180600643157',
#   '0.0735819399356843',
#   '별 반개도 아깝다ㅋ 진짜 북한 정의롭게 미화하네ㅗㅗ'],
#  ['10.0',
#   '0.95489764213562',
#   '0.0451023578643799',
#   '마흔 여덟 인생에 본 세손가락 안에 드는 첩보영화이자  올해 본 최고의 영화.캐스팅의 힘'],
#  ['1.0',
#   '0.2177508175373077',
#   '0.1177508175373077',
#   '아무리 영화라도 이런식으로 대놓고 선동하면 안되죠'],
#  ['1.0', '0.2861440777778625', '0.1861440777778625', '문재인만세입니더!!!'],
#  ['1.0', '0.0035071969032287', '0.0964928030967713', '재미없음 내 시간 ㅜㅜㅜㅜ'],
#  ['10.0',
#   '0.7085216045379639',
#   '0.2914783954620361',
#   '진실이 드러나고 있습니다. 보수는 진보를 왜곡해 권력을 유지했고..정보기관은 그게 국가를 지키는 거라며 권력을 지켰습니다. 전남..그 땅은 종북이 아닙니다. 이제 정치적 왜곡을 그만두십쇼'],
#  ['1.0', '0.138847142457962', '0.038847142457962', '정도껏 해야지 이건뭐 어이가없다'],
#  ['10.0', '0.610819399356842', '0.3891806006431579', '총풍사건이 실화네요 ㅎㄷㄷ'],
#  ['1.0', '0.7835726737976074', '0.6835726737976074', '결론은 김대중이 최고라는 영화'],
#  ['10.0',
#   '0.9960672855377196',
#   '0.0039327144622803',
#   '완전 재밌음!! 이제 신과 함께 보러가야지'],
#  ['10.0', '0.7366607785224915', '0.2633392214775085', '쫀쫀한 긴장감이 대박!'],
#  ['2.0', '0.3430003225803375', '0.1430003225803375', '다른건 모르겠고 배우들 연기는 참 잘한다'],
#  ['2.0',
#   '0.5157361030578613',
#   '0.3157361030578613',
#   '긴장감없는 스파이액션의 연속  정권불법외화벌이하는처장과 치밀하게속이는공작원이 갑자기 눈물흘리며 착한사람이 되는 아이러니..'],
#  ['1.0',
#   '0.2462254166603088',
#   '0.1462254166603088',
#   '이게 무슨 정치색 뻘건 찬양영화냐...  헐....'],
#  ['1.0',
#   '0.5288988947868347',
#   '0.4288988947868347',
#   'for left  to left by left'],
#  ['1.0',
#   '0.2314951419830322',
#   '0.1314951419830322',
#   '진짜는 흑금성 이름 하나뿐..나머진 전부 픽션인데 꼭 사실처럼 만들어놨네 이거보고 개돼지들은 북한북한하면서 빨아대겠지'],
#  ['10.0',
#   '0.0444215834140777',
#   '0.9555784165859222',
#   '이거 재미없다는 놈들은 인천상륙작전이나 봐라'],
#  ['1.0', '0.2473740875720977', '0.1473740875720977', 'ㅈ같은 북한 찬양 영화ㅋㅋㅋ'],
#  ['1.0', '0.4095279574394226', '0.3095279574394226', '하 한심스럽다 빨갱이들'],
#  ['10.0',
#   '0.5022158622741699',
#   '0.4977841377258301',
#   '총 없이 보는 간첩물의 긴장감  묵직한 여운'],
#  ['1.0',
#   '0.0481168329715728',
#   '0.0518831670284272',
#   '1점도 아까운 정치선동영화~ 연평도를 마치 한국정부가 공작한것처럼 꾸미다니 정말 어이없음 도대체 이런 영화를 만든 감독은 제정신인지 암것도 모르는 사람은 있는거대로 받아들일것아닌가~ 양심의 문제인거 같다. 연평도 희생자님들 정말 미안하고 송구합니다'],
#  ['10.0',
#   '0.2374259829521179',
#   '0.7625740170478821',
#   '역사왜곡 왈가왈부 전에 팩트체킹이 우선인데 팩트확인도 안하고 빨갱이라니 뭐라 하는 평점 1점 준 일베충 개돼지들'],
#  ['10.0',
#   '0.9756780862808228',
#   '0.0243219137191772',
#   '와 소름돋는 이성민 배우의 연기! 오랜만에 배우의 힘이 느껴지는 영호ㅓ'],
#  ['10.0',
#   '0.7915384769439697',
#   '0.2084615230560302',
#   '이성민 부들부들 연기..  역시 믿고보는 차장님'],
#  ['2.0',
#   '0.0071001946926116',
#   '0.1928998053073884',
#   '지루해요 정치색도 강하고. 다른 거 볼 걸 그랬나 봐요 왠만하면 이런 류 영화 기억에 남는 게 있는데 감동도 재미도 없어요 ㅡㅡ'],
#  ['1.0', '0.1947139799594879', '0.0947139799594878', '이런 정치색 영화 이젠 지겹다.'],
#  ['10.0', '0.8356515169143677', '0.1643484830856323', '올해의 영화라 생각한다'],
#  ['10.0',
#   '0.9984772205352784',
#   '0.0015227794647215',
#   '영화를 뒤늦게나마 봣지만 진짜 재밋다 실화 기반이라 보는맛도 있고 진짜 재밋다 팝콘 중짜리 삿는데 대짜리 살껄그랫다'],
#  ['8.0', '0.5180488228797913', '0.2819511771202088', '볼만하네요. 성민이형 연기 ㅎㄷㄷ'],
#  ['1.0',
#   '0.3178402781486511',
#   '0.2178402781486511',
#   '또 하나의 김대중 찬양 영화. 남북대립이라는 흥미로운 소재를 갖고도 결국은 편향된 정치 시각을 더해 후반부를 망쳤다. 보수 진보 우파 좌파의 정치 성향은 개개인에 따라 다른 것이 당연하나  영상 매체는 가능한 중립성을 지켜야 옳지 않을까?'],
#  ['1.0',
#   '0.4021089076995849',
#   '0.3021089076995848',
#   '이게 무슨 첩보영화야 진짜 적국을 대놓고 미화하고 선동하네 ㅋㅋ'],
#  ['10.0', '0.7871544361114502', '0.2128455638885498', '바둑을 두는 영화네요..'],
#  ['8.0',
#   '0.0469544529914855',
#   '0.7530455470085146',
#   '503호년 언제쯤 사형하냐jQuery22406049483918407776_1533737586587? 아 그년 죽창으로 진짜 꽂아버리고 싶다'],
#  ['2.0',
#   '0.4670460820198059',
#   '0.2670460820198059',
#   '지문이 닳도록 현정권에 알아서 기고있는 바퀴벌레들의 영화.. 양심에 부끄럽지 않을까? 아 수치심이 있다면 바퀴벌레들이 아니지'],
#  ['1.0', '0.2534905970096588', '0.1534905970096588', '개어색 존노잼 ㄷㄷㄷㄷ'],
#  ['1.0', '0.6985267400741577', '0.5985267400741577', '나만 당할 수 없다 관우야'],
#  ['1.0',
#   '0.3167731165885925',
#   '0.2167731165885924',
#   '북한 리명운이 어떤사람인데 이런사람을 미화하는 영화를 남한에서 만들다니 깜짜 놀랐음..'],
#  ['10.0', '0.314448744058609', '0.685551255941391', '액션장면이 없어도 이렇게 쫄깃할 수가'],
#  ['10.0', '0.9635838270187378', '0.0364161729812622', '최고에요 잘봤습니다..'],
#  ['1.0', '0.0683298408985138', '0.0316701591014862', '영화 이렇게 만들면 안된다'],
#  ['10.0',
#   '0.3092469573020935',
#   '0.6907530426979065',
#   '개돼지 소리 듣기 싫은분들 보시고북풍 조작한 국회의원 누구인가 궁금하네요'],
#  ['1.0', '0.4557643532752991', '0.3557643532752991', '김정은이 투자했냐????'],
#  ['10.0',
#   '0.9650981426239014',
#   '0.0349018573760986',
#   '아주 재밌게 잘 보았습니다 역시 믿고보즈아'],
#  ['10.0',
#   '0.9381867051124572',
#   '0.0618132948875428',
#   '심하게 연기 잘하심! 시간 가는 줄 모름'],
#  ['1.0',
#   '0.7019836902618408',
#   '0.6019836902618408',
#   '아무리 재밌어도 정치색 있으면 불편해서 안보는데 너무 정치색이 짙다. 한국 정치인이 북한을 사주해서 한국을 공격한다고....? 그렇게 말 잘듣는 나라면 핵도 안 만들었겠다.'],
#  ['1.0', '0.5288988947868347', '0.4288988947868347', '프로파간다 프로파간다'],
#  ['10.0',
#   '0.968997836112976',
#   '0.031002163887024',
#   '정치적인것을 떠나 참 좋은배우들이 한국에 많다는것을 느낀 영화'],
#  ['10.0',
#   '0.2344750761985778',
#   '0.7655249238014222',
#   '이걸보고 정치색 얘기하는애들은 믿지마시고 보시면됩니다. 영화는 그냥 영화로보면 되고 충분히 잘만든 영화입니다. 영화를 보고 영화를 논하지 않고 정치를 말하는것 자체가 도둑이 제발저린거 아닐까요? 신과함께따위 씹어먹을영화입니다'],
#  ['1.0',
#   '0.723173201084137',
#   '0.623173201084137',
#   'ㄷㄷ...북한은 잘못없다..국정원의 잘못이다..이런발상을 한다는게..쫌...연기자들의 연기력이 아쉽다..'],
#  ['10.0',
#   '0.928116738796234',
#   '0.0718832612037659',
#   '극 영화에서 팩트를 다루는 일은 얼마나 어려운가! 이 영화는 팩트의 여부를 내려놓고 보았을 때 정말 괜찮은 첩보 영화임에 틀림없다. 사실 개인적으로는 이 영화가 팩트 기반이라는 현실에 충격을 받았고   슬펐다.'],
#  ['1.0',
#   '0.5826206803321838',
#   '0.4826206803321838',
#   '북 빨갱이 영화같네 진짜.. 황정민이 살려주는 영화'],
#  ['10.0',
#   '0.8018052577972412',
#   '0.1981947422027588',
#   '잼있게잘봤습니다~~헌데 스파이영화 내용은 거기서 거기지만 손에 땀을 쥐고봤고 눈물도 흘렸네요..'],
#  ['10.0',
#   '0.6435585618019104',
#   '0.3564414381980896',
#   '연기가 다들 진짜 좋았어요. 뻔하지만 정말 뻔하지 않은 영화입니다'],
#  ['1.0',
#   '0.1552786231040954',
#   '0.0552786231040954',
#   '이 영화를 다 본 내가 대견함.내가 본 영화 중에 가장 지루했음.'],
#  ['10.0', '0.9383208751678468', '0.0616791248321532', '특선영화로봤어요 재밌어요'],
#  ['1.0', '0.0291577279567718', '0.0708422720432282', '실화?실화?실화?실화?감독?'],
#  ['10.0',
#   '0.3555590510368347',
#   '0.6444409489631653',
#   '디테일한 묘사만으로도 충분한 볼거리인듯..'],
#  ['1.0', '0.2546473145484924', '0.1546473145484923', '비중립적 영화는 뽀로로보다도 못하다'],
#  ['10.0', '0.9025322198867798', '0.0974677801132202', '빨간맛이 약간 강하지만 재밌다'],
#  ['1.0', '0.4129573702812195', '0.3129573702812195', '토악질나오는 좌편향된 영화계'],
#  ['1.0',
#   '0.4213473796844482',
#   '0.3213473796844481',
#   '정치색깔 확실하네...인랑.공작..민주당을 위한 ..북폭돼지 우상화 영화~'],
#  ['10.0', '0.6277650594711304', '0.3722349405288696', '자한당 알바들  쀄애애애액!!!'],
#  ['1.0',
#   '0.092212826013565',
#   '0.007787173986435',
#   '정권이 바뀌니 영화도 바뀌는건가 싶네요.... 다 떠나서 재미가 일단 없었고  북한의 미사일 도발마저 우리나라의 책임으로 넘기는듯한 영화는 정치색이 어떻든지 대한민국 국민으로서 불쾌했습니다'],
#  ['10.0', '0.5674382448196411', '0.4325617551803589', '이것이 진정 첩보영화다'],
#  ['1.0',
#   '0.0026869177818298',
#   '0.0973130822181702',
#   '전형적인 쓰레기 선동영화. 심지어 재미도없음'],
#  ['1.0',
#   '0.0880199968814849',
#   '0.0119800031185151',
#   '영화보다 잠 재미없어맘마미아 신과함께가 백배 재미는데예매율 1위 노이해'],
#  ['1.0', '0.4094404578208923', '0.3094404578208922', '아...잘잤다....하하'],
#  ['1.0',
#   '0.2321359515190124',
#   '0.1321359515190124',
#   '진짜 너무한다 영화로도 선동하는거야?  좌파 너무 심하다 진짜'],
#  ['1.0',
#   '0.5288988947868347',
#   '0.4288988947868347',
#   '요약: 북조선만세 김정일만세 김대중동지 나이스샷'],
#  ['1.0',
#   '0.0699890255928039',
#   '0.0300109744071961',
#   '정말 비추입니다. 영화 보다가 졸아본적 없는데 참 난감하네요... 배우들이 다 멋진분들이라 기대했는데 정말 실망이예요. 내용도 뭔내용인지도 모르겠고 참 그렇네요....'],
#  ['1.0', '0.4884432256221771', '0.3884432256221771', '좌좀식 선동영화 설명 끝'],
#  ['1.0', '0.0459243953227996', '0.0540756046772004', '지루했음...진심으로..'],
#  ['10.0',
#   '0.0950033068656921',
#   '0.904996693134308',
#   '어머니랑 같이 보고 왔는데요. 진짜 스토리 전개며  배우님들의 연기력이며.. 뭐 하나 빠지는게 없네요짱이에요'],
#  ['10.0',
#   '0.9938580989837646',
#   '0.0061419010162353',
#   '꼭 보세요ㅜㅜ 존잼배우분들도 연기 너무 잘해요'],
#  ['1.0',
#   '0.3465654253959656',
#   '0.2465654253959655',
#   '좋은배우들이 왜 이런시나리오영화를 찍는지...'],
#  ['10.0',
#   '0.4038801491260528',
#   '0.5961198508739471',
#   '실화를 바탕으로 한얘기라 흥미진진 했네요 딴나라당 국민의짐당 노친네들 요즘이어떤시댄데 아직도 저런게 통할거라고 생각하는게 우습기도 하고 ㅋㅋ'],
#  ['1.0', '0.0089456737041473', '0.0910543262958527', '돈아까워서 이를갈았어요'],
#  ['10.0', '0.5735718607902527', '0.4264281392097473', '알바는  가라.신과함께는 집에서'],
#  ['10.0',
#   '0.6322875618934631',
#   '0.3677124381065368',
#   '배우들 연기가 진짜 대단하다 전에없던 한국영화! 잘만들었다'],
#  ['10.0',
#   '0.3179247379302978',
#   '0.6820752620697021',
#   '박사모들 평점테러 오지네 ㅋㅋ이 영화가 어딜봐서 북한찬양이라는거냐'],
#  ['10.0',
#   '0.4452623128890991',
#   '0.5547376871109009',
#   '댓글에 왜구 종자들 바글바글 하네 에휴..'],
#  ['10.0', '0.9486779570579528', '0.0513220429420472', '매우 재미있음 연기력 짱'],
#  ['10.0', '0.5643101930618286', '0.4356898069381714', '잘만들었네요....'],
#  ['1.0', '0.402153730392456', '0.3021537303924559', '북한미화 선동영화 수고'],
#  ['1.0', '0.005102664232254', '0.094897335767746', '이렇게 재미 없는 영화도 없을 듯'],
#  ['1.0',
#   '0.2635615468025207',
#   '0.1635615468025207',
#   '평점이 ....왜이리 높지 나만지루했나 ㅠㅠ'],
#  ['1.0', '0.2924809753894806', '0.1924809753894805', '북한 미화  선동에만 집중한 영화'],
#  ['10.0', '0.9759258031845092', '0.0240741968154908', '굿입니다 재미있게잘봤습니다'],
#  ['1.0',
#   '0.008965641260147',
#   '0.091034358739853',
#   '이런 쓰레기 영화를또볼수있는 날이올까?나는 보수도아니고진보도아니지만 이건 극진보 역사적사실이나 증거도없이 극진짜극에극으로 자한당 아니한나라당을 깍아내리고 지금지금 진보당이 정권을잡고 영화권까지 잡은건아닌지합니다 감독정치색을 사실인양 해놓은쓰레기네요'],
#  ['10.0', '0.6751784086227417', '0.3248215913772583', '정말 우리나라가 창피하메요'],
#  ['1.0',
#   '0.0522020757198333',
#   '0.0477979242801667',
#   '알바들 쩐다... 그냥 영화보지말고 그돈으로 맛있는거 사먹으세요..'],
#  ['10.0',
#   '0.9223361015319824',
#   '0.0776638984680175',
#   '최고의 영화 나의 믿음을 확신시켜주는 보수'],
#  ['10.0',
#   '0.4442534148693084',
#   '0.5557465851306915',
#   '좌파다. 선동이다. 북한미화다 하는 놈들 인터넷에 총풍사건 검색이라도 좀 해보고 댓글 달아라.. 방구석에서 손가락만 움직이지말고 쯧쯧'],
#  ['10.0', '0.6006572246551514', '0.3993427753448486', '이건 꼭.. 봐야되여..'],
#  ['1.0', '0.0907220244407653', '0.0092779755592347', '연기는 잘하고 내용은 지루하다'],
#  ['1.0',
#   '0.0405210554599761',
#   '0.0594789445400239',
#   '나진짜 이런거 안쓰는데 이건 너무하지 않나... 너무너무 배우빼고 볼게없다'],
#  ['1.0', '0.327886164188385', '0.227886164188385', '무엇을 이야기하고자 하는지 모르겠습니다'],
#  ['10.0', '0.5997282266616821', '0.4002717733383178', '역사를바로알게하는영화다'],
#  ['1.0',
#   '0.3243834972381592',
#   '0.2243834972381591',
#   'ㅋㅋ정권유지를 위해 북한을 이용하려했다?ㅋㅋㅋ일어나지도 않는 도발계획을 미화시키네 현실은 북은 핵을 가지고 끊임없이 남한의 적화를 원함'],
#  ['1.0',
#   '0.2261222004890442',
#   '0.1261222004890441',
#   '영화가 말로 시작해서 말로 끝남.재미는 ↓'],
#  ['10.0',
#   '0.2936601042747497',
#   '0.7063398957252502',
#   '한국사회가 좌편향이라니 ㅋㅋ 소가 웃을일이지 ㅋㅋㅋㅋ'],
#  ['1.0',
#   '0.0434796512126922',
#   '0.0565203487873078',
#   '실화라는 미명하에 좌편향적인 감독의 상상의 나래를 펼친 김대중 찬양 영화 1점도 아깝다'],
#  ['10.0',
#   '0.9587804079055786',
#   '0.0412195920944213',
#   '오랜만에 재밌게본 영화!!인랑 덕분인가?'],
#  ['1.0',
#   '0.4252458214759826',
#   '0.3252458214759826',
#   '정부 지원 받은 영화 아닌가 의심이 들 정도  김대중 미화 좌향좌 이 시국에 젊은이들에게 북한 미화시키고 혹세무민하려고 만든 선동 영화일 뿐'],
#  ['1.0', '0.3006268441677093', '0.2006268441677093', '다큐를 찍으려면 차라리 다큐를 해라'],
#  ['10.0', '0.5288988947868347', '0.4711011052131653', '굿 입니딘 실화 ㄷㄷㄷㄷ'],
#  ['1.0',
#   '0.0890732705593109',
#   '0.0109267294406891',
#   '적당히 좀 하자! 달도 차면 기운다는 사실을 알아야 한다. 그냥 좀 적당히!'],
#  ['1.0', '0.3729286789894104', '0.2729286789894104', '아 내누우우ㅜㅜㅜㅜ우ㅜㅜ운'],
#  ['1.0',
#   '0.0135906636714935',
#   '0.0864093363285065',
#   '좋은 배우 모셔다가 이딴 영화를 만듭니까?대한민국 빨갱이 만들라고요?? 미화를 해도 적당히 해야지 아무리 픽션이라지만 머리에 뭐가 들었기에 이런 스토리를 만들어요? 북한에서 건너 오셨어?'],
#  ['1.0',
#   '0.6391199827194214',
#   '0.5391199827194214',
#   '심하다 진짜 좌빨들 진짜 노골적이네 이젠 대놓고...'],
#  ['10.0',
#   '0.9610049724578856',
#   '0.0389950275421143',
#   '재밌다! 거기에 연기잘하는 연기자들까지 더해져서 엄청 집중해서 봤음.'],
#  ['1.0', '0.3725659847259521', '0.272565984725952', '정치색이 ...너무...'],
#  ['1.0', '0.4537034332752228', '0.3537034332752228', '정치색이 너무 많이 들어간 영화'],
#  ['1.0', '0.0242522060871124', '0.0757477939128876', '그냥 재미가 너무나 없다'],
#  ['1.0',
#   '0.2366664707660675',
#   '0.1366664707660675',
#   '진짜 이건해도해도 너무했다.. 연평도같은대다가 무력도발해달라고 북한한태 부탁하는 장면넣으면서 연평도  천안함같은 북한 무력도발들을 남한 보수당측에서 부탁해서 했다고 사실로 밝혀지지않은걸 완전사실처럼 선동하면 보통사람들은 와 진짜 저랬구나 한다고..'],
#  ['1.0', '0.3840973675251007', '0.2840973675251007', '기대한만큼 실망도큰...'],
#  ['1.0', '0.0657266974449157', '0.0342733025550843', '연기는 잘합니다 재미는 없구요'],
#  ['1.0', '0.6367776393890381', '0.5367776393890381', '정권바뀔때마다 나오는 영화가 딴판이네'],
#  ['10.0',
#   '0.9679701328277588',
#   '0.0320298671722412',
#   '이성민 황정민 님 연기 너무 잘하시고 두 인물간의 관계가 이끄는 긴잠감 키야~'],
#  ['1.0', '0.3624584674835205', '0.2624584674835205', '영화가 끝났는데 아직 중반부 본 느낌임'],
#  ['10.0',
#   '0.9424105286598206',
#   '0.0575894713401794',
#   '오늘 보고 왔는데 인생영화다 진심...연기 지린다'],
#  ['10.0', '0.4260659217834472', '0.5739340782165527', '액션씬이 없어도 충분한 긴장감과 스릴감'],
#  ['1.0',
#   '0.9756996035575868',
#   '0.8756996035575868',
#   '별점 조차 아까운 역사조작 영화 영화계 좌파 ㄹㅇ 개많네.. 재밌게 잘보다가 자기 생각 너무 강요해서 불편했다'],
#  ['10.0',
#   '0.3782209753990173',
#   '0.6217790246009827',
#   '좌파영화 빨갱이미화...ㅎ 박근혜 빨아주던 넘들 이제와서 지들 믿을곳 없으니까 부들대는거 봐라ㅋㅋㅋ'],
#  ['10.0', '0.9374394416809082', '0.0625605583190918', '인생영화 등극 몰입도 최고'],
#  ['1.0', '0.424200028181076', '0.3242000281810759', '정치색이 뚜렷해 보는내내 불편 했습니다'],
#  ['10.0', '0.408413290977478', '0.591586709022522', '평점테러 오지네보지도 않은 것들이'],
#  ['1.0',
#   '0.0195667445659637',
#   '0.0804332554340363',
#   '댓글알바가 장악한 영화 볼거 1도없음 ㄹㅇ재미도 없고 액션신도 없고 롤렉스 ppl광고 홍보 오지게 하는 영화주제에 ㅋㅋ진짜 노답이다 노답 북한가서 살지그래?북한인들이 안바뀌는데 우리가 바뀌면 쟤들이 와!하고 바뀌나?ㅋ'],
#  ['1.0',
#   '0.3430491089820862',
#   '0.2430491089820861',
#   'ㅋㅋㅋ 요즘들어서 빨갱이 미화영화 많이 나오네'],
#  ['1.0',
#   '0.0143107771873474',
#   '0.0856892228126526',
#   '별 반개도 아까운 좌빨영화 하다하다 이제 김정일을 빨아주네ㅋㄱㄱ동무들 핵맛좀볼래?'],
#  ['1.0',
#   '0.3199273347854614',
#   '0.2199273347854614',
#   '연기들은 잘하지만 너무 지루해서 영화보다 김대중 이회창 당선 결과 보기전 나감 ㅠㅠ'],
#  ['1.0', '0.0352900922298431', '0.0647099077701569', '기대햇는데 지루해요..'],
#  ['1.0',
#   '0.3293737173080444',
#   '0.2293737173080443',
#   '걍^^  푹~자다가 왔다.돈도 시간도 뒤통수맞은듯댓글평에  낚겨서 이게 뭔가요.차라리 댓글악평중인 인랑이그나마 잠은 안온다.뒤통수 정말 지대로 맞은영화'],
#  ['1.0', '0.5569618344306946', '0.4569618344306946', '김대업 영화도 만드쇼잉ㅋ'],
#  ['1.0',
#   '0.0117815136909484',
#   '0.0882184863090516',
#   '지루해서 볼수가 없네요처음으로 영화보다 졸았어요너무 느슨한 진행으로 기대했는데 실망스럽네요'],
#  ['1.0', '0.1845422685146331', '0.084542268514633', '선동영화그러지 말자'],
#  ['10.0', '0.2856490314006805', '0.7143509685993195', '과거를 바로 알아야 한다는...'],
#  ['10.0', '0.2559803128242492', '0.7440196871757507', '엄청난 내용이다. 엄청 기대가 된다.'],
#  ['1.0', '0.3825401663780212', '0.2825401663780211', '좌편향 인정해야죠.. 대놓고 좌편향'],
#  ['1.0',
#   '0.21924489736557',
#   '0.11924489736557',
#   '딱 현 정권 사상에 맞는 개돼지 조련영화. 하품만 수십번 하다가 영화 본질 깨닫고 팝콘던지고 나감ㅅㄱ'],
#  ['10.0',
#   '0.4134722948074341',
#   '0.5865277051925659',
#   '방금 영화보고와서 평점이 생각보다 낮아서 나라도 평점달려고 왔건만 ㅋㅋ 좌표찍고 대대적으로 공작이란 영화에 대해 평점 테러 공작이 들어왔네요 평점 낮으면 극장 안가는 나도 속을뻔했다 진짜 ㅋㅋㅋ 놀랍다 ㅅㅂ'],
#  ['1.0', '0.7688928842544556', '0.6688928842544556', '진짜 양심이 있는건가...?'],
#  ['1.0',
#   '0.0277579128742218',
#   '0.0722420871257782',
#   '편파적인 내용 사실 왜곡 지루한 내용 보다 나올뻔'],
#  ['1.0', '0.1045223772525787', '0.0045223772525786', '이게 영화냐? 별점0.5점이 아깝다'],
#  ['1.0',
#   '0.2026250660419464',
#   '0.1026250660419464',
#   '왜? 아예 북한을 왕처럼 떠받들고 살지? ㅋㅋㅋ'],
#  ['1.0', '0.0181702673435211', '0.0818297326564789', '지루함.. 재미없다. 밋밋하'],
#  ['10.0', '0.3874712288379669', '0.6125287711620331', '딱봐도 실화구만 OO들 하네'],
#  ['1.0', '0.6585513353347778', '0.5585513353347779', '선동영화네요 진짜...'],
#  ['10.0',
#   '0.0310530960559844',
#   '0.9689469039440156',
#   '보면서 불편했던 나만 그런거야...우리나라보수 아니 그냥 쓰레기 만들려고 하는 의도는 알겠는데 너무 노골적이다...심하게..'],
#  ['1.0',
#   '0.7953675985336304',
#   '0.6953675985336304',
#   'ㅠㅠ 슬프다. 영화로 역사를 배우지마세요. 북한의 지난 수천번의 도발을 면피시켜주는 영화네요'],
#  ['10.0', '0.8753145933151245', '0.1246854066848754', '연기 좋다 이상민 황정민'],
#  ['10.0',
#   '0.6094220280647278',
#   '0.3905779719352722',
#   '최고다 신념에 따라 다른 길을 선택한 공작스파이의 고뇌와 각자를 인정하는 관계   북풍공작이 일어난 한국만의 완성도 높은 스파이첩보극 황정민 이성민 연기 대박 연출 대박'],
#  ['1.0', '0.402153730392456', '0.3021537303924559', '좌빨 빨갱이영화 암걸리네요'],
#  ['1.0',
#   '0.3968380689620971',
#   '0.2968380689620971',
#   '아니근데 영화의 대사와는 다르게 김대중이 당선된게 북한에 이득준건 지나가는 개도 아는사실아니야??'],
#  ['10.0',
#   '0.9587578773498536',
#   '0.0412421226501463',
#   '잘봤습니다 이런류의 영화 더 많이 나왔으면 좋겠습니다'],
#  ['1.0',
#   '0.4508479535579681',
#   '0.350847953557968',
#   '배우 라인업 가지고 이따위로 만든감독에게 ㅂㄹ탁치고 갑니다. 에혀ㅋㅋ'],
#  ['1.0',
#   '0.0522601902484893',
#   '0.0477398097515107',
#   '첩보 스릴러가 이렇게 지루할수가 있을지 몰랐다'],
#  ['10.0',
#   '0.6015940308570862',
#   '0.3984059691429138',
#   '이걸 누가 북한찬양영화라고 하는거냐? 명작이다!!'],
#  ['1.0', '0.3998540341854095', '0.2998540341854094', '한쪽으로 지나치게 치우친 영화'],
#  ['1.0',
#   '0.7277271151542664',
#   '0.6277271151542664',
#   '좌파 진짜 구질하다ㅋㅋ이렇게 까지 하고싶냐ㅋ'],
#  ['1.0',
#   '0.0100332200527191',
#   '0.0899667799472809',
#   '정치적인거 다 떠나서그냥. 못 만든 영화올해 가장 쓰레기'],
#  ['10.0',
#   '0.8349871635437012',
#   '0.1650128364562988',
#   '연평도 논리점프ㅋㅋㅋ 김정일에 대해 얘기하는 장면 봐서는 북 미화 전혀 없는데ㅋㅋ 머리 있으면 생각을 좀 하면서 봅시다 그리고 죄다 사실인데 정치색이랄게 있나 총풍사건에 ㅂㄷㅂㄷ 별점테러 하는 넘들이 정치색 티내는 거지'],
#  ['1.0',
#   '0.0339002311229705',
#   '0.0660997688770295',
#   '평이 아주 좌파찬송가로구나 댓글부대가 인랑을 망쳐놓더니 이영화를 위한조작이엇구나 무지한 국민들아 제대로평가나 해라액션업는첩보물 돈을 다회식비로 쓰고 구강액션이라구 말로만영화를 처바르는구나 이러니 우리나라영화가 쓰레기라하지'],
#  ['10.0',
#   '0.835553765296936',
#   '0.1644462347030639',
#   '흑금성...대박입니다. 역시 믿고보는 윤종빈'],
#  ['1.0', '0.0300231873989105', '0.0699768126010895', '너무지루하고지겨운영횐'],
#  ['10.0',
#   '0.9575666189193726',
#   '0.0424333810806274',
#   '그냥 보세요. 긴장감 쩌는 영화ㅠㅠ최근들어 제일재밌게봄 !'],
#  ['1.0',
#   '0.2204486429691314',
#   '0.1204486429691313',
#   '문재인 지지자들을 위한 헌정영화임. 진짜 너무 심함'],
#  ['1.0', '0.277520477771759', '0.1775204777717589', '정신나간 영화 도라인가 감독은'],
#  ['1.0',
#   '0.2290302217006683',
#   '0.1290302217006683',
#   '8점대 평점은 아닌데 평점이 너무높네지루해 보링!!'],
#  ['2.0',
#   '0.419016420841217',
#   '0.2190164208412169',
#   '무섭다...영화로  정치를  배우지맙시다...'],
#  ['10.0',
#   '0.5665397644042969',
#   '0.4334602355957031',
#   '일베세끼들 또 ㅂㄷㅂㄷ하네 OO게세들ㅋㅋ'],
#  ['1.0', '0.0050205290317535', '0.0949794709682465', '쓰레기 중쓰레기다 ㅋㅋㅋ'],
#  ['10.0',
#   '0.015037178993225',
#   '0.984962821006775',
#   '다른쓰레기는 9.0이상이고 이건 8.0대냐?ㅋㅋㅋㅋ 대단하다 ㅋㅋㅋ'],
#  ['10.0', '0.6057149171829224', '0.3942850828170776', '오늘봤는데 배우들 연기 지린다'],
#  ['10.0', '0.9567101001739502', '0.0432898998260498', '기대없이 봤는데 재미있었습니다'],
#  ['10.0',
#   '0.7737371921539307',
#   '0.2262628078460693',
#   '여기도 댓글알바들 총출동이네ㅋㅋ 영화 잘 만들었어요 일단 흥미진진함'],
#  ['1.0',
#   '0.0348307192325592',
#   '0.0651692807674408',
#   '와~ 아무리 영화라지만ㅋㅋ 할말을잃었다ㅋㅋㅋ 실화를 바탕으로했으면요 펙트로만 제작하세요~당신이 상상하고 생각한것들을 영화로 만들지말구요ㅋㅋ 대놓고 개 빨갱이영화네 씨발ㅋㅋ 앞으로 이감독새끼 영화 무조건 거른다 심지어 재미도없어ㅋㅋ'],
#  ['1.0', '0.2632268667221069', '0.1632268667221068', '북한미화영화 ㅋㅋ 개불편'],
#  ['1.0',
#   '0.0108917653560638',
#   '0.0891082346439362',
#   '진짜 최악의영화 알바들이 평점올리고 난리네'],
#  ['1.0', '0.1396825909614563', '0.0396825909614562', '빨갱이를 위한 빨갱이가 원한 빨갱영화'],
#  ['9.0', '0.5567697882652283', '0.3432302117347717', '우리 현실의 미션임파서블'],
#  ['1.0', '0.0078532695770263', '0.0921467304229737', '줜니 돈아깝네.. 정치영화 징글맞다'],
#  ['10.0',
#   '0.6703076362609863',
#   '0.3296923637390136',
#   'TK 자유빨갱이당 나라를 좀 먹는 인간들의 이중인격 실체 잘봤습니다'],
#  ['1.0',
#   '0.0008533596992492',
#   '0.0991466403007508',
#   '최악의 독재정권 북한미화 진짜 쓰레기 영회'],
#  ['1.0',
#   '0.1421655714511871',
#   '0.0421655714511871',
#   '북한이 피해자냐? 보다 시1발 어이가 없어서 그냥 나옴'],
#  ['1.0',
#   '0.4163021445274353',
#   '0.3163021445274353',
#   '전형적인 영화로 역사를 배우는 개돼지 겨냥영화'],
#  ['1.0',
#   '0.4208809435367584',
#   '0.3208809435367584',
#   '진짜..    논리라고는 전혀없는 멍청이들 감성 자극하기좋은영화   실화사건5퍼센트에 95퍼센트허구로  공산당보다 자유한국당이 나쁜놈이다공산당은 원래착하다ㅋㅋㅋ하..  뇌가 진짜'],
#  ['1.0', '0.0004786550998687', '0.0995213449001313', '와   진짜  돈아까워요  정말재미없어요'],
#  ['1.0',
#   '0.0088185966014862',
#   '0.0911814033985138',
#   '최악의 좌빨 선동영화보는 내내 보고 난 후더러운 기분 어쩔꺼'],
#  ['1.0',
#   '0.045877605676651',
#   '0.054122394323349',
#   '좌파 빨갱이들 선동도 지극정성으로 한다  니 돈 아니라고 영화를  이따위로  거짓으로 만들어도 되냐?'],
#  ['1.0', '0.5375542044639587', '0.4375542044639587', '졸개노잼...진짜지루허네'],
#  ['1.0',
#   '0.1161278188228607',
#   '0.0161278188228607',
#   '과도한 김대중 포장 좌파포장까진 참아준다 근데 진짜 ㅈㄴ지루하다 이건아니지 이성민 황정민 둘이 연기로 살린 졸작이다 진짜로'],
#  ['1.0',
#   '0.1676662862300872',
#   '0.0676662862300871',
#   '현재 상황을 고려한다면 이따위 소설 영화를 만들면 안됐다 감독은'],
#  ['1.0',
#   '0.211536169052124',
#   '0.1115361690521239',
#   '윤종빈 당신 용서받지 못한자 찍었으면 군대 다녀왔을텐데 대북관이 왜 그럽니까'],
#  ['1.0', '0.0019494593143463', '0.0980505406856537', '진짜 올해 본 영화중에 최악이다 ...'],
#  ['10.0', '0.8971478939056396', '0.1028521060943603', '시간가는줄모르고봤다'],
#  ['2.0',
#   '0.6376619338989258',
#   '0.4376619338989257',
#   '롤렉스가 가장 기억에 남는 영화.롤렉스 광고 같음.'],
#  ['1.0',
#   '0.8425713181495667',
#   '0.7425713181495667',
#   '"초중반까진 잘 가다가 어느 순간 ""공작""질로 빠져서 현실과 픽션을 혼동시키게 만드는 교묘한 주작질 "'],
#  ['1.0', '0.5758284330368042', '0.4758284330368042', '기대하고봤는데 개인적으로  별루에요..'],
#  ['1.0', '0.6433951258659363', '0.5433951258659363', '시간가는줄 모르고잤다...'],
#  ['10.0',
#   '0.3683665990829468',
#   '0.6316334009170532',
#   '좌파 어쩌고 하는것들 지들이 언제부터 정치에 관심이 많았다고 영화는 영화로 봐야지 선동이고 어쩌고 영화한편으로 선동 당행으면 벌써 우리나라 북한 됐겠다 ㅡㅡ 액션하나없는 정치 스파이 영화 나름 신선했고 난 재미있었다'],
#  ['1.0', '0.9514585733413696', '0.8514585733413697', '좋아여 잘봣습니다! 짱짱맨'],
#  ['1.0',
#   '0.3965838253498077',
#   '0.2965838253498076',
#   '황정민 사투리 연기 거부감  들정도로너무 어색함다신 경상도사람 연기하지마라'],
#  ['1.0', '0.1581489741802215', '0.0581489741802215', '한국 정치영화는 1점을 만점으로 치자'],
#  ['10.0', '0.594197154045105', '0.405802845954895', '뭐지 이 명작을 1점 준 사람들은.'],
#  ['1.0', '0.5115748047828674', '0.4115748047828674', '무슨 이딴 영화가 다있어'],
#  ['10.0',
#   '0.6242305040359497',
#   '0.3757694959640503',
#   '네티즌 평점을 보면 보지도 않고 씨부리는구나 알수있는 영화 차떼기 사실인데 북한찬양이라고 물타기를 당하네 ㅋㅋ'],
#  ['1.0',
#   '0.0302312970161438',
#   '0.0697687029838562',
#   '허구를 다큐 처럼 만든 영화  실제인것 처럼 하지만 실제론 99퍼가 허구 국민들로 하여금 오해를 만들게 하는 3류 영화 처음부터 허구였으면 이해를 하는데..실제인것 처럼 묘사 감독 말대로면 북한을 조정할수 곳이 신한국당이라니 정말 황당함'],
#  ['1.0',
#   '0.0421664118766784',
#   '0.0578335881233216',
#   '좌파정권들어서니 영화도 빨개~ 인랑..공작 쓰레기영화들..애들선동하려고12세관람으로만들었나?정사신빼고?'],
#  ['9.0', '0.4589979648590088', '0.4410020351409912', '누가 국민을 위하고 누가 나라를 위하는가'],
#  ['1.0', '0.0274921357631683', '0.0725078642368317', '에휴 ㅉㅉ 이것도 영화라고'],
#  ['1.0',
#   '0.4902390241622925',
#   '0.3902390241622925',
#   '진짜 씨발 ㅋㅋㅋ OO하지마셈 문재앙 죽어라'],
#  ['1.0',
#   '0.5891431570053101',
#   '0.4891431570053101',
#   '20년동안 살면서 영화보면서잔적 처음이네요'],
#  ['1.0', '0.476584792137146', '0.376584792137146', '공작은 공작 맞네. 댓글 공작'],
#  ['1.0',
#   '0.0515836179256439',
#   '0.0484163820743561',
#   '와.... 연평해전도 돈 주고 사주했다고 할 기세네.. 적당히 좀 해라 진짜'],
#  ['1.0',
#   '0.7154704928398132',
#   '0.6154704928398133',
#   '딱 현 정권에 맞는영화. 북한이 지금까지 했던 짓들이 남한에서 부탁해서 한 짓이다?? 보는 내내 짜증과 답답함을 방불케함'],
#  ['1.0',
#   '0.2426776587963104',
#   '0.1426776587963104',
#   '위대한 김대중 위원장 선상님이 평화를 이룩하였다. ;; 전라도 위인?전 영화.  홍어 싫어 하는분과 김대중  싫어하는 분들이 보면 심한 역겨움으로 구토유발하는  정치 영화.  좌빨들  호주머니 터는 .'],
#  ['1.0', '0.5944473147392273', '0.4944473147392273', '햇볕정책을 미화시킨 쓰래기영화'],
#  ['1.0',
#   '0.4737831950187683',
#   '0.3737831950187683',
#   '보수정권과 국정원은 쳐죽일 조직이고 김대중과 북한은 정의로운 인사와 집단으로 포장한 전형적인 좌파 띄우기 영화 골때린다'],
#  ['1.0',
#   '0.4936900436878204',
#   '0.3936900436878203',
#   '픽션이라고 쓰고 왜곡이라고 읽는다. 당장의 남과 북의 관계만봐도 이게 거짓이라는것을 알 수 있다. 북핵은 김대중 노무현이 완성시켰다고 확언할순없지만 엄청난기여를했다는것  거부할수없는 사실아닌가?'],
#  ['1.0',
#   '0.6916157603263855',
#   '0.5916157603263855',
#   '정치색이 너무 짙어 놀랐던 영화.. 보는 내내 불편했다. 현재 우리나라가 이정도로 좌편향 이념적이 됐나 우려스러울정도'],
#  ['10.0',
#   '0.3701194822788238',
#   '0.6298805177211761',
#   '네티즌 평점은 나와는 좀 다른 ..하지만 ..천재 윤종빈 감독님 정말 영화 잘 만드세요!'],
#  ['1.0',
#   '0.004620611667633',
#   '0.095379388332367',
#   '1점도 아까운 영화 걍 보지마세요. 클레멘타인급'],
#  ['10.0', '0.4028452932834625', '0.5971547067165375', '방구석일베충들 댓글조작 오지네'],
#  ['1.0', '0.1032262742519378', '0.0032262742519377', '배우들 연기력만 돋보이는 쓰렉'],
#  ['1.0',
#   '0.1385610997676849',
#   '0.0385610997676849',
#   '진짜 끔찍한 정치 이용영화 실화라고 앞에다 써놨지만 실제로는개그짓말에 픽션집어넣은영화'],
#  ['10.0', '0.5515133142471313', '0.4484866857528686', '아는사람들은 안다  제발 눈을떠라'],
#  ['1.0', '0.1269243657588958', '0.0269243657588957', '좌파영화 그만 좀...'],
#  ['1.0', '0.23068368434906', '0.13068368434906', '말할 가치도 없는 영화 저질'],
#  ['1.0', '0.3444824814796448', '0.2444824814796447', '이럴 수가.  ~~~~!'],
#  ['1.0',
#   '0.2392989099025726',
# ...
#  ['1.0',
#   '0.5963771343231201',
#   '0.4963771343231201',
#   '정은이가 참 좋아할 영화 이쯤되면 조사한번 받아야할듯 간첩일수도...'],
#  ['9.0',
#   '0.7681963443756104',
#   '0.1318036556243896',
#   '한국사람이라면 올해 꼭 봐야하는 영화임..'],
#  ['10.0',
#   '0.9799708724021912',
#   '0.0200291275978088',
#   '최고의 명작.북한 미화 그 어디에도 없음. 총풍사건 실화를 기반으로 한 영화. 너무 실감나고 재미있었다. 댓글 비공알바 넘쳐나네 ㅋ키'],
#  ['2.0', '0.313602864742279', '0.1136028647422789', '공작이란  공산당이 만든작품'],
#  ['1.0',
#   '0.4576559662818908',
#   '0.3576559662818908',
#   '초반 20분 재밌고 ㅋㅋㅋ전형적인 좌파 영화네 ㅋㅋㅋ문죄인 정권에서 이런영화만 나오듯김대중ㅇ 우상화 북한 도발은 모두 우파가 조작한거 흑금성은 무죄다 ㅋㅋ이말하고 싶은거네 ㅋ진짜 좌좀영화 지겹다'],
#  ['8.0',
#   '0.7041674852371216',
#   '0.0958325147628784',
#   '좋은연기 픽션이라는뜻을 모르는사람들 아쉬운엔딩'],
#  ['1.0',
#   '0.1085128486156463',
#   '0.0085128486156463',
#   '영화가 너무 실망스러워서 황정민까지 꼴보기 싫어졌어요. 욕나오는 영화. 영화보다 잠든건 처음이네요.'],
#  ['10.0',
#   '0.5136741399765015',
#   '0.4863258600234985',
#   '박근혜 뽑은사람 보지 마세요..암생깁니다.'],
#  ['1.0',
#   '0.2969563901424408',
#   '0.1969563901424408',
#   '검증되지 않은 사실을 믿는 개돼지들이 없기를.'],
#  ['10.0', '0.746448814868927', '0.253551185131073', '연기는 이런 것이고 각본은 이런 것이다.'],
#  ['10.0', '0.280392974615097', '0.719607025384903', '2시간 20분가량 긴장을 놓지 못함'],
#  ['2.0', '0.5681533217430115', '0.3681533217430114', '좌파정부의 입맛에 딱 맞는 영화'],
#  ['10.0',
#   '0.3080823421478271',
#   '0.6919176578521729',
#   '재미있구만 왜들 난리냐. 여기 친박 노친네 태극기부대가 왜케 많냐. 영화도 안보고 악플 달기 담합한 티가 너무 많이 난다.'],
#  ['1.0',
#   '0.1269280314445495',
#   '0.0269280314445495',
#   '정치성향 띠는 영화는 이제 그만좀 나오고 배우들도 가려가면서 찍으세요!-'],
#  ['10.0',
#   '0.2661476731300354',
#   '0.7338523268699646',
#   '일베를 위한 영화. 왜냐? 일베벌레들 아가리에 거품물고 달려 들테니까 ㅋㅋ'],
#  ['10.0', '0.3286156058311462', '0.6713843941688538', '영감많이 받았어요 멋져요'],
#  ['10.0',
#   '0.2395267188549041',
#   '0.7604732811450959',
#   '피해자들 눈에 피눈물 나게 하는 새끼들은 대처 못한 정부 옹호하는 너네들이고'],
#  ['10.0', '0.7659250497817993', '0.2340749502182006', '웰메이드 스파이영화!'],
#  ['10.0', '0.3868077397346496', '0.6131922602653503', '정치는더럽다 .. 극우들 부들부들 ㅋ'],
#  ['1.0',
#   '0.461284875869751',
#   '0.361284875869751',
#   '정치선동영화. 재미는 고사하고 지극히 평면적인 인물들의 지나치게 무거운 이야기'],
#  ['1.0',
#   '0.189023345708847',
#   '0.0890233457088469',
#   '레알 개선동 영화냐? 연평도 순직장병 유족들께 대가리 숙여 사과해야 할 삘인데'],
#  ['1.0',
#   '0.5188915729522705',
#   '0.4188915729522705',
#   '좌좀 천국  불신지옥  백수나라  부칸만세'],
#  ['2.0',
#   '9.139013127423824e-05',
#   '0.1999086098687257',
#   '최악의 영화. 재미도 없고 감동도없고'],
#  ['1.0',
#   '0.3078829050064087',
#   '0.2078829050064086',
#   '황정민 주연의 다큐멘터리... 그저 북한 린민들이 보면 딱 좋아할 스토리! 다만 김정일로 나온 기주봉 선생만 깜놀... 스크린 쿼터제 당장 폐지하라!'],
#  ['10.0',
#   '0.9758766889572144',
#   '0.0241233110427856',
#   '역시베충이들 훑고 지난간 리뷰는  꼭봐야하는 명작 ㅋㅋㅋ'],
#  ['1.0',
#   '0.3725737929344177',
#   '0.2725737929344177',
#   '살다살다 김정일 찬양 영화까지 나올줄이야..'],
#  ['10.0',
#   '0.577888548374176',
#   '0.422111451625824',
#   '이건 대한민국 국민이라면 꼭 봐야할 영화. 그 흔한 총질 한번 없이 스릴넘치는 수작'],
#  ['10.0', '0.7601264119148254', '0.2398735880851745', '조선민주주의 린민공화국 만세!!'],
#  ['2.0', '0.3210074305534363', '0.1210074305534362', '현정부가 우리마음속에 공작을 거는 영화'],
#  ['1.0',
#   '0.0952648520469665',
#   '0.0047351479530335',
#   '말도 안되는 북한 및 김대중 미화이게 진짜라고 생각하는 사람들도 있나..보면 볼수록 스토리가 어이가 없네'],
#  ['1.0',
#   '0.5524841547012329',
#   '0.4524841547012329',
#   '앞뒤가 맞지않는 엉터리 영화에 억지로 북한과의 우정을 엮는 빨갱이 영화'],
#  ['1.0',
#   '0.6316361427307129',
#   '0.5316361427307129',
#   '팩트를 소재로 다룬 영화라면 지금같은 시국일 수록 보다 신중에 신중을 기해야하지 않을까요? 아무리 영화라지만 대중들이 영화를 본뒤 남는 잔상이 어떨지 생각을 좀 하고 만들었으면 합니다.'],
#  ['1.0', '0.0015023350715637', '0.0984976649284363', '최악의 선동영화. 0점'],
#  ['10.0', '0.9373091459274292', '0.0626908540725708', '배우분들 연기가 너무 좋았습니다'],
#  ['1.0', '0.2839882969856262', '0.1839882969856262', '과거 미화는 ...대체 언제까지 할건데'],
#  ['1.0', '0.836216390132904', '0.7362163901329041', '어떤 부분이 재밌는지...'],
#  ['1.0',
#   '0.0403591096401214',
#   '0.0596408903598786',
#   '김정일이 김대중 당선을 싫어했다고? 총풍 실체다루는 척하면서 대법 판결 제시도 못하고? 아무리 뇌피셜 선동 영화라도 최소한의 개연성은 좀 갖추자 대북송금사건도 좀 다뤄보지 그랬냐?'],
#  ['10.0',
#   '0.6917998790740967',
#   '0.3082001209259033',
#   '과연 진실은 무엇일까  언졘간 알게되겠죠'],
#  ['1.0',
#   '0.1620102226734161',
#   '0.0620102226734161',
#   '요새 짱짱한 배우들 다 넣어놓고 스토리 망쳐놓는게 유행인가 ?'],
#  ['10.0',
#   '0.9823164343833924',
#   '0.0176835656166075',
#   '영화라서 어느 정도 허구가 있었겠지만 남북의 뒷면을 볼 수 있었고  주인공을 통해  통일은 상대와 우리에 대한 정확한 인식을 필요로 한다는 것을  생각하게 해 준 깊은 영화였던 것같습니다.  배우들의 표정연기.. 입술의 주름까지 표현된 연기력 감동.'],
#  ['10.0', '0.910502314567566', '0.0894976854324339', '꼭 보세요 2시간이 후딱'],
#  ['1.0',
#   '0.0425716340541839',
#   '0.0574283659458161',
#   '기자 평론가 새끼들 싹다 좌파 빨갱이 놈들이네 이거 평점 존나게 높게 주네 좌파 찬양영화에  글고 감독아 영화 이딴식으로 만들지 마라 눈 배리고 왓다 시  발'],
#  ['1.0', '0.5002219080924988', '0.4002219080924988', '진짜 감독 뇌속이 궁금해지는 영화다'],
#  ['1.0', '0.6121552586555481', '0.5121552586555481', '북한미화 뇌내망상 오지구요 지렸네요'],
#  ['4.0', '0.024460881948471', '0.375539118051529', '....별로임ㄹㅇㅇㅇ'],
#  ['10.0',
#   '0.9668028354644777',
#   '0.0331971645355223',
#   '리명운과 박석영의 브로맨스가 돋보였던 영화. 얼마나 수줍고 애타보였으면 마지막 서로 마주보고 걸어가다가 검은 화면으로 뒤덮이는 장면을 내가 키스신이라 가렸다고 표현했겠는가. 이정민과 황정민의 BL물 연성이 시급한 영화.'],
#  ['10.0',
#   '0.4111358523368835',
#   '0.5888641476631165',
#   '개꾸루루으으잼알바들 테러하러와서 고생많으다'],
#  ['10.0', '0.8572123646736145', '0.1427876353263855', '이성민 인생연기  대단합니다.'],
#  ['10.0', '0.687565803527832', '0.3124341964721679', '신과함께 같은 거지같은 영화보다 이게좋다'],
#  ['10.0',
#   '0.1803048253059387',
#   '0.8196951746940613',
#   'ㅋㅋㅋ 왜 1점테러가 많은가했더니 일배충들이  거품물고 OO발광할만한 내용이었구나ㅋㅋ 굉장히 현실적이고 직설적으로  꼴보수의 수법들을 나열해버리니까 ㅋ 그모습들을 상상하니까 너무 웃기긴함'],
#  ['10.0',
#   '0.8312047719955444',
#   '0.1687952280044555',
#   '선동이네 뭐네 해도 재미있음!!좌파 우파 나누지마라 OO들아 코딱자만한 나라에ㅉㅉ'],
#  ['1.0',
#   '0.4028452932834625',
#   '0.3028452932834625',
#   '좌빨조센징들 때려잡고 박근혜 폐하 구출해드리자 이기야'],
#  ['10.0',
#   '0.5871555209159851',
#   '0.4128444790840149',
#   '알바들한테 속아서 이걸 이제보네...꼭 보세요.. 두 번 보세요..'],
#  ['10.0',
#   '0.4353605508804321',
#   '0.5646394491195679',
#   '안보신분 없길....우리가 꼭 알아야할 이야기입니다'],
#  ['1.0',
#   '0.2798605561256408',
#   '0.1798605561256408',
#   '왜 역사를 북한쪽에서 주장하는 것을 일방적으로 믿도록 강요하는 이런 영화를 만드는지 모르겠다. 북한의 정치학습을 영화로 하게 하는 것 같은 느낌..'],
#  ['10.0',
#   '0.810011625289917',
#   '0.189988374710083',
#   '날이더워서 영화나볼까하면서 봤는데 찡하더군요  시간나시면 꼭보세요'],
#  ['10.0',
#   '0.9371064901351928',
#   '0.0628935098648072',
#   'ㄹㅇ진짜 재밌게 봄ㅋㅋㅋ 친구들이랑 봤는데 다른 친구들은 지루했다는데 나는 너무 몰입해서 봄ㅋㅋ 인생영화!!ㅋㅋ'],
#  ['1.0',
#   '0.0035327970981597',
#   '0.0964672029018403',
#   '1점도 아까운 그냥 첩보물인척 하면서 정치색을 너무 드러내는 영화'],
#  ['1.0',
#   '0.4868339300155639',
#   '0.3868339300155639',
#   '.... 레알 ... 정치적영화 사실인냥 포장하기 극혐..'],
#  ['10.0',
#   '0.4444299340248108',
#   '0.5555700659751892',
#   '통구이  OO.도 자유일본당. 자한당 커넥션 공.작'],
#  ['10.0',
#   '0.5103018283843994',
#   '0.4896981716156006',
#   '베충이들 평점테러 오지네 ㅋㅋ북한찬양은 1도안나오는데 영화는 봤냐방구석에만있지말고 여가생활좀해라 벌레들아그리고 북풍조작은 팩트야 벌레들아'],
#  ['1.0',
#   '0.3763302266597748',
#   '0.2763302266597748',
#   '팩트확인. 1. 북풍공작 안기부 공무원들 1심 2심 대법원까지 무죄 나왔음2. 흑금성 공작원 김대중 정권때 휴민트 공작원 다 공개되었었음.3.  북한 사람들 다 호인으로 연출한 감독과 CJ 정말 악독스러울 정도 이네요'],
#  ['1.0',
#   '0.211875706911087',
#   '0.111875706911087',
#   '선동이 너무 심하다 이번 정권 영화는 다 이런식'],
#  ['10.0',
#   '0.6416304111480713',
#   '0.3583695888519287',
#   '기대안하고 봤는데 재미있었고 잔인한 장면은 나오지 않지만 심장이 아플정도로 무서웠음ㅋㅋ'],
#  ['1.0', '0.1167582273483276', '0.0167582273483275', '솔직히 이건 너무 심했다'],
#  ['1.0',
#   '0.022110641002655',
#   '0.077889358997345',
#   '처음으로 평 쓰는데 ㄱㅐ 노잼 네이버 진심 알바천국임 재미 감동 스토리 하나도 없음'],
#  ['10.0',
#   '0.9805588722229004',
#   '0.0194411277770996',
#   '최고의 연기와 연출  보기드문 고급스러운 한국 영화'],
#  ['10.0',
#   '0.0763160288333892',
#   '0.9236839711666108',
#   '이게 실화인줄 아는 대깨문 없제? 아!! 삶은 소대가리도 판도라고보 탈원전했지?ㅋㅋㅋㅋ'],
#  ['10.0', '0.8991772532463074', '0.1008227467536926', '대유잼...꼭보세욜 재밌습니다'],
#  ['10.0',
#   '0.9292075634002686',
#   '0.0707924365997314',
#   '황정민 이성민 연기력이 끝내줍니다말이필요없는영화입니다 10점'],
#  ['1.0', '0.4335383474826813', '0.3335383474826813', '완전 좌편향이네...'],
#  ['1.0',
#   '0.0005994141101837',
#   '0.0994005858898163',
#   '사람들이 재미있다 없다의 기준을 내가 판단할 순 없지만없는 시간 쪼개서 그것도 2년만에 영화를 본게 이공작이란 건데 참 시간이 너무 아까웠다 ㅠ 참;;;; 그리고 여기 댓글알바 오지게 많은거 같은데 너무 놀랍다 ㅅㄱ'],
#  ['1.0',
#   '0.0083797574043273',
#   '0.0916202425956727',
#   '혹시나 했지만 역시나 배우들만 아까운 영화'],
#  ['1.0', '0.2926356196403503', '0.1926356196403502', '선동을 목적으로하는 3류영화'],
#  ['1.0', '0.5440484285354614', '0.4440484285354614', '무더운 여름날 잘 자고 왔습니다.'],
#  ['10.0',
#   '0.9850417375564576',
#   '0.0149582624435423',
#   '잘 봤습니다... 실화를 바탕으로 한 영화라 더 몰입감있게 잘 본 것 같아요. 배우들의 연기도 좋았습니다.'],
#  ['10.0', '0.9367761611938475', '0.0632238388061524', '긴장감 넘치는 재밌는 영화'],
#  ['10.0',
#   '0.0332766473293304',
#   '0.9667233526706696',
#   '이영화 볼만합니다 시간아깝지않음~몰입감 좋음 개인적으로 마녀 독전 특히 인랑 등등 시간 아까웠습니다'],
#  ['10.0',
#   '0.8074288368225098',
#   '0.1925711631774902',
#   '연기자들의 명연기에 소름이.. 기대했던 액션 영화가 아님에도 불구하고 런닝타임 내내 몰입해서 재미있게 봤네요~'],
#  ['10.0',
#   '0.4572915732860565',
#   '0.5427084267139435',
#   '평점 조작하지 말고 ~  본 사람만 평점쓰자'],
#  ['1.0', '0.0148079693317413', '0.0851920306682587', '연기가 아깝다.. 대놓고 좌편향'],
#  ['1.0', '0.0334612727165222', '0.0665387272834778', '개노잼영화임 ㅡㅡ 절대보지마셈 제볼'],
#  ['10.0', '0.510441780090332', '0.4895582199096679', '하나하나 칭찬하기도 어려울 만큼 완벽하다'],
#  ['1.0',
#   '0.5705891251564026',
#   '0.4705891251564026',
#   '실화는 개뿔ㅋㅋ김대중 정부때 박지원이 대북 송금한 것은 실화다 ㅋ'],
#  ['1.0',
#   '0.5866339206695557',
#   '0.4866339206695557',
#   '역대급 노잼영화..북한 선전영화 보는듯한 느낌'],
#  ['1.0', '0.3463207483291626', '0.2463207483291626', '하...이거를 진짜...'],
#  ['1.0',
#   '0.4879152178764343',
#   '0.3879152178764343',
#   '강철비가 아직까진 북한물 중에선 젤 잼나네'],
#  ['1.0',
#   '0.3554248809814453',
#   '0.2554248809814453',
#   '좌빨 영화 대단해.. 북한 미화 그만 해라 빨갱이 새기들아'],
#  ['10.0', '0.4150411486625671', '0.5849588513374329', '대박.. .쫄깃쪼ㄹ깃'],
#  ['10.0',
#   '0.3929063677787781',
#   '0.6070936322212219',
#   '피 튀기는 장면이 없어도 충분히 첩보물을 만들수있다는 증거'],
#  ['10.0',
#   '0.0816374719142913',
#   '0.9183625280857088',
#   '사실을 배경으로 긴장감있는 연출지루할 틈 없이 직관한 몇안되는 작품임'],
#  ['1.0',
#   '0.2037298679351806',
#   '0.1037298679351806',
#   '거짓말을 위해 만들어진 영화. 김대중 정부에서 돈을 줘서 핵개발이 되었는걸 다 아는데. 김대중 주둥이가 약속한 북은 핵을 만든적이 없다 개 씸하는 소리는 왜 했단 말인가. 아주 대놓고 조작하는 영화'],
#  ['10.0', '0.9639461636543274', '0.0360538363456726', '연기도 좋고 긴장감 잘만든영화'],
#  ['1.0',
#   '0.372383177280426',
#   '0.272383177280426',
#   '좌빨선동영화. 영화가 언제부터 정권의 이데올로기를 반영했는가'],
#  ['10.0',
#   '0.4270825982093811',
#   '0.5729174017906189',
#   '졸잼이네요 박사모 어버이연합은  테러그만하세요'],
#  ['10.0', '0.6667695045471191', '0.3332304954528808', '정말 웰메이드 영화립니다'],
#  ['1.0',
#   '0.6113855242729187',
#   '0.5113855242729187',
#   '개념은 안드로메다로. .이들이 말하는 진실은 사실이 아니라 이들이 원하는 소설.'],
#  ['1.0', '0.3800817131996155', '0.2800817131996155', '너무한다 이게 무슨 8 점대야'],
#  ['1.0', '0.3393208980560303', '0.2393208980560302', '이런 기획영화는 그만 나왔으면'],
#  ['1.0', '0.5288988947868347', '0.4288988947868347', '바람바람바람 신세계 국제시장 생각남'],
#  ['1.0',
#   '0.1198289692401886',
#   '0.0198289692401885',
#   '캐비어로 알밥을 만들어도 적당히 장난질을해야지   ㅋㅋㅋ참...  고생들한다'],
#  ['1.0',
#   '0.9743226766586304',
#   '0.8743226766586304',
#   '정치색을 떠나서 잘 만들었긴하지만.... 너무나 좌향좌다 . 하지만 정말 잘만들었다'],
#  ['4.0',
#   '0.0044416487216949',
#   '0.3955583512783051',
#   '너무 재미없드라...황정민의 연기력만 아깝다옥구슬을. 똥위에 굴리는듯한. 그런영화였다'],
#  ['1.0', '0.5467092394828796', '0.4467092394828796', '문재인ㅋ  적당히해라 욕나온다.'],
#  ['1.0', '0.1197686493396759', '0.0197686493396758', '연기는 좋았는데 내용은 모르겠다'],
#  ['1.0',
#   '0.1769909262657165',
#   '0.0769909262657164',
#   '북한이 연평도 공격한게 왜 우리 책임인가요?'],
#  ['10.0',
#   '0.5780624151229858',
#   '0.4219375848770141',
#   '진짜 볼만함...첨으로 평 달아봄이게 신과함께에 밀리는게 안타까워서훨씬 잼잇는데'],
#  ['1.0', '0.4254978895187378', '0.3254978895187378', '좌든 우든 정치색 강한 영화는 질색이다'],
#  ['4.0',
#   '0.976333737373352',
#   '0.576333737373352',
#   '김정일 장군님 다시 보게되는 계기~ 솔직히 존경스러운것도 사실'],
#  ['10.0',
#   '0.5812314748764038',
#   '0.4187685251235962',
#   '영화는 이렇게 꽉 차게 만드는 거다. 천하의 황정민 연기가 모자라 보일 정도였다!'],
#  ['10.0',
#   '0.2932518124580383',
#   '0.7067481875419617',
#   '유튜브로 역사를 배우고  댓글로 현 상황을 판단 하고 확신 하는 틀딱과 20.30 꼰대들이 봐야 할 영화.'],
#  ['10.0',
#   '0.2158147692680359',
#   '0.7841852307319641',
#   '총풍사건. 역사를 잊은 민족에겐 미래란 없다'],
#  ['1.0', '0.1779337227344513', '0.0779337227344512', '진짜 왜 별점이 높은지 이유를 모르겠다'],
#  ['10.0',
#   '0.5003856420516968',
#   '0.4996143579483032',
#   '조여오는 긴장감이 부족했지  영화는 훌륭합니다.'],
#  ['1.0',
#   '0.1727238893508911',
#   '0.0727238893508911',
#   '북한정권에 희생된 희생되고 있는 북한주민이나 우리 군인들한테 미안하지도 않을까 이럴거면 장르를 판타지로 했어야지'],
#  ['6.0',
#   '0.2765321433544159',
#   '0.3234678566455841',
#   '액션 없는 총싸움 그리고 배우 4명의 연기는 좋았지만 중간에 잤습니다...'],
#  ['10.0',
#   '0.8361304998397827',
#   '0.1638695001602172',
#   '이런 영화가 있기에 한국은 더 발전한다. 사회적 비판 영화들도 꼭 필요함.'],
#  ['1.0',
#   '0.2818857133388519',
#   '0.1818857133388518',
#   '아따 니들이 쏴달라고 해서 쏜거랑깨...ㄷㄷ'],
#  ['2.0',
#   '0.5483433604240417',
#   '0.3483433604240417',
#   '북한 미화 이렇게 심한 영화가 한국에서 나올줄은 상상도 못해봣습니다 북한은 도발은 모두 한국정부가 시킨거고 북한의 나쁜 이미지는 모두 한국정치인들에 의해 조작된거다 이거 입니다'],
#  ['1.0',
#   '0.9835506677627563',
#   '0.8835506677627564',
#   '최고의 영화였다이기야 !! 10점 줘야하지 않겠노 !!'],
#  ['1.0',
#   '0.4485133588314056',
#   '0.3485133588314055',
#   '조선 왕조의 부패한 중앙집권적인 왕권을 그대로 계승한 북한을 옹호한다... 다음대통령 문재인 귀걸이 아들래미가 무혈입성 한다고 하면 좌좀애들만 좋아라 하겠네 ㅎㅎㅎ'],
#  ['1.0', '0.2028269171714782', '0.1028269171714781', '아무리 그래도 북한미화 선동은 좀...'],
#  ['1.0',
#   '0.0260390043258667',
#   '0.0739609956741333',
#   '좀 기다렸다가 채널cgv에서 볼걸....아...내 돈....ㅠㅠ'],
#  ['10.0',
#   '0.3172213435173034',
#   '0.6827786564826965',
#   '이게 현실이다 검찰 한국당 어버이연합 재벌가 조선일보 중앙일보 동아일보 및 재벌가 대기업에게 광고료 받는 언론사장님들아'],
#  ['1.0',
#   '0.563490629196167',
#   '0.463490629196167',
#   '배우들 연기나 재미를 떠나서 정치색 너무 강해서 심하게 거부감듦'],
#  ['10.0',
#   '0.8152387142181396',
#   '0.1847612857818603',
#   '아무리.별점테러를.해도 영화는 잘 만들어졌다. 아무렴 현실이 더 했겠지 안기부 보수곰팡이들 저러고도 남지..일반 국민들 목숨을 파리처럼보는...'],
#  ['10.0',
#   '0.8856327533721924',
#   '0.1143672466278076',
#   '연기 너무좋았고 스톨카 실화라는점에 정말 놀랐어요'],
#  ['4.0',
#   '0.0756893455982208',
#   '0.3243106544017792',
#   '정치적 주입의도가 너무 불편했다. 좌우 떠나서 좌측의 영화들이 변호인  택시운전사 1986등등 너무 많이 나와서 대중미디어로 한쪽 사상만 정의라는 느낌을 너무 강요받는 느낌이고..좀 질린다 우측영화가 전무하다시피해서.. 이젠 중립적 시각을 갖고싶다'],
#  ['10.0', '0.3282458186149597', '0.6717541813850403', '배우들 연기만점이다.'],
#  ['1.0',
#   '0.6572294235229492',
#   '0.5572294235229492',
#   'ㅋㅋㅋㅋ  정말 재미와  연기를 떠나 북한의  기득권층의 김씨부자  밑에서  피빨아먹는  인물이들을  너무  미화시킨듯  마지막만보면  독립운동가인줄 ㅋㅋㅋ'],
#  ['1.0',
#   '0.1334388554096222',
#   '0.0334388554096221',
#   '맨날 여당까는 영화만 나오네 그럼 연평해전 천안함 연평도포격 다 우리나라에서 북한한태 부탁해서 이뤄진거라고? 김대중 햇볕정책 퍼줘서 북핵개발한건 눈꼽만치도 안나오네 먼저 전사한 전우들이 통곡할 영화다'],
#  ['10.0',
#   '0.7267304062843323',
#   '0.2732695937156677',
#   '영화가 멋있음  재미로 말고요 ~ 정말 좋았어요 저는'],
#  ['1.0',
#   '0.2412939965724945',
#   '0.1412939965724945',
#   '0점 안되냐? 이딴 정치병걸린 영화가 있냐?'],
#  ['2.0',
#   '0.4291463494300842',
#   '0.2291463494300841',
#   '정치판엔 선과 악은 존재하지 않는다 오직 당리당략만을 노리는 이리들이 존재할 뿐'],
#  ['10.0', '0.4239936470985412', '0.5760063529014587', '정치와무관하게 스토리가탄탄한영화'],
#  ['4.0',
#   '0.2900466918945312',
#   '0.1099533081054688',
#   '영화는볼만하나 정치적성향이은근히 베여있는영화에요 이감독작품을개인적으로좋아하긴하지만 이감독의영화들을보다보면 우리나라 군대에 불만이많은감독인거같음 특히이작품에서 연평도포격의배후가우리나라의소행처럼나오는뉘앙스는 고인이된병사가족들의마음을찢어버리는거같은생각이듬'],
#  ['2.0',
#   '0.1451878547668457',
#   '0.0548121452331543',
#   '대놓고 좌파정권에 아부하는 내용이 참기힘들다.. 이런 영화를 보고 역사적 사실로 착각하는 관객이 분명 있을텐데...'],
#  ['2.0',
#   '0.8621492385864258',
#   '0.6621492385864258',
#   '영화 자체는 재밌었으니 별2개 근대 너무 선동하는 내용이 많고 혼돈되게 하는 장면이 너무 많다 어떻게 보면 노골적으로 어느정당 편드는 분위까지 든다'],
#  ['2.0',
#   '0.1738151013851165',
#   '0.0261848986148835',
#   '반공영화인가? 결국 북한은 대한민국 정치인 사주를 받아 한국을 공격했고 북한은 아무 문제없는 교훈을 주는 영화? 진짜 대단하다 이번정부.'],
#  ['9.0', '0.8151469230651855', '0.0848530769348144', '이성민씨 연기 좋았습니다. 잘 봤습니다.'],
#  ['10.0',
#   '0.4207313060760498',
#   '0.5792686939239502',
#   '평점을 하라고 했지  어벙이연합 할배들 댓글 달라고 하지 않았다.'],
#  ['1.0', '0.7722144722938538', '0.6722144722938538', '노잼입니다 힘들다 영화'],
#  ['5.0',
#   '0.5984437465667725',
#   '0.0984437465667724',
#   '이 영화가 어디까지 진실인고 거짓인가는 중요하지않다. 작가가 하고자 하는말은 과거있었던 사건들과 미래에 일어날 사건들이 눈에 보여지는 것 (언론)보다 다른 누군가의 이익을 위해 일어난 사건일수 있다는것을 경고하는것이다.'],
#  ['10.0', '0.2743867635726928', '0.7256132364273071', '이게 실화임 같은 ㅣ민족임'],
#  ['10.0',
#   '0.9980077743530272',
#   '0.0019922256469727',
#   '재밌었다 김대중대통령님 뵀을때 눈물 났다 ㅠ 감동도 있었고.. 주지훈도 멋있었다!'],
#  ['2.0',
#   '0.6502490043640137',
#   '0.4502490043640136',
#   '진짜 대놓고 북한찬양  ..보는내내 기분드럽'],
#  ['1.0',
#   '0.33266082406044',
#   '0.23266082406044',
#   '북한영화인줄알았음 이 나라를 무너뜨릴려라는 자들이 너무 많다'],
#  ['10.0',
#   '0.5779356956481934',
#   '0.4220643043518066',
#   '정치성향 이런걸 떠나서 영화는 재밌었다.어려운 소재로 이정도 작품을 만든 윤종빈감독대단한듯. 이성민과 황정민 연기도 좋았다. 다만 조진웅은 역에 비해뭔가 장난치는듯한 가벼움이 느껴짐.신과 함께 보단 모든면에서 훨씬 재밌었다.'],
#  ['1.0', '0.4348197281360626', '0.3348197281360626', '아~씨. 또 좌빨 영화에 낚였네'],
#  ['1.0',
#   '0.0288998782634735',
#   '0.0711001217365265',
#   '북한에게 퍼주는것이 정의다? 1점 박습니다'],
#  ['1.0',
#   '0.1032063066959381',
#   '0.003206306695938',
#   '목격자 나오면 보는게 낫다 본다. 이거 액션도 없고 지루하고 재미 없는데 평점 디게 높네. 연기는 다들잘한거 인정한다. 정치색 짙은 다큐멘터리 한 편 본거 같다.'],
#  ['1.0',
#   '0.0280457437038421',
#   '0.0719542562961579',
#   '우파정권이 정권유지를위해 북한과 내통해서 남한에 전쟁도발을시켰다?  이거 발상이 거의 미친거 아닌가? 저번 강철비도 그렇고 좌파감독아 진짜심각하게사실왜곡하고북한미화시키네 미디어가 정말무서운게 명배우들인기로 이런식으로 영화만들어 사상세뇌교육시키는거다'],
#  ...]

# %%
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(0)
for j in range(len(lines_ut)):
    train_labels.append(1)
for i in range(len(test_t)):
    test_labels.append(0)
for j in range(len(test_ut)):
    test_labels.append(1)
    
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

okt = Okt()
x_train = []
x_test = []
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# train data
for sentence in tqdm(lines1_):
    tokenized_sentence = okt.morphs(sentence[3], stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_train.append(stopwords_removed_sentence)

# test data
for sentence in tqdm(lines2_):
    tokenized_sentence = okt.morphs(sentence[3], stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_test.append(stopwords_removed_sentence)

maxlen = 1000  # 100개 단어 이후는 버립니다
training_samples = 200  # 훈련 샘플은 200 -> 200개입니다
validation_samples = 10000  # 검증 샘플은 10,000개입니다
max_words = 10000  # 데이터셋에서 가장 빈도 높은 10,000개의 단어만 사용합니다
# train 토큰화
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(x_train)
sequences = tokenizer.texts_to_sequences(x_train)

word_index = tokenizer.word_index
train = pad_sequences(sequences,maxlen=maxlen)

# test 토큰화
tokenizer2 = Tokenizer(num_words=max_words)
tokenizer2.fit_on_texts(x_test)
sequences2 = tokenizer2.texts_to_sequences(x_test)

word_index2 = tokenizer2.word_index
test = pad_sequences(sequences2,maxlen=maxlen)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)

from keras.preprocessing import sequence
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

max_features = 10000  # 특성으로 사용할 단어의 수

batch_size = 32
input_train = sequence.pad_sequences(train,maxlen=maxlen)
input_test = sequence.pad_sequences(test,maxlen=maxlen)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6400/6400 [00:18<00:00, 348.21it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1600/1600 [00:03<00:00, 433.35it/s]

# %%
input_train
# Out:
# array([[   0,    0,    0, ...,   37,    5, 2820],
#        [   0,    0,    0, ..., 1925,    6,  396],
#        [   0,    0,    0, ...,  192, 1927,  193],
#        ...,
#        [   0,    0,    0, ...,  146,  921,  445],
#        [   0,    0,    0, ...,  346,  117,   32],
#        [   0,    0,    0, ...,  720,    6,  205]])

# %%
lines3_ = np.asarray(lines3_)
lines4_ = np.asarray(lines4_)

# %%
lines3_
# Out:
# array([[10.        ,  0.95316052,  0.04683948],
#        [ 1.        ,  0.13667676,  0.03667676],
#        [ 1.        ,  0.6950928 ,  0.5950928 ],
#        ...,
#        [10.        ,  0.21163929,  0.78836071],
#        [10.        ,  0.90768266,  0.09231734],
#        [10.        ,  0.94078314,  0.05921686]])

# %%
max_len = 50
from keras import models, layers
def multi_input_lstm_embedding_model(timesteps, columns_size, max_words, max_len):
    # lstm model
    lstm_input = layers.Input(shape=(timesteps, columns_size))
    lstm_out = layers.LSTM(64, dropout=0.3, recurrent_dropout=0.3)(lstm_input)

    lstm_model = Model(inputs=lstm_input, outputs=lstm_out)

    # embedding model 
    embed_input = layers.Input(shape=(None,))
    embed_out = layers.Embedding(max_words, 8, input_length=max_len)(embed_input)
    embed_out = layers.Bidirectional(layers.LSTM(64, dropout=0.3, recurrent_dropout=0.3))(embed_out)

    embed_model = Model(inputs=embed_input, outputs=embed_out)

    # concatenate
    concatenated = layers.concatenate([lstm_model.output, embed_model.output])
    concatenated = layers.Dense(32, activation='relu')(concatenated)
    concatenated = layers.BatchNormalization()(concatenated)
    concat_out = layers.Dense(2, activation='sigmoid')(concatenated)

    concat_model = models.Model([lstm_input, embed_input], concat_out)

    return concat_model

concat_model = multi_input_lstm_embedding_model(1, 1, max_words, max_len)
concat_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# model fit
concat_model.fit([feature1,input_train], train_labels,epochs=7, batch_size=32,validation_data=([feature2,input_test], test_labels),
                 shuffle=False)# because of time-series
# Out:
# Epoch 1/7
# WARNING:tensorflow:Model was constructed with shape (None, 1, 1) for input KerasTensor(type_spec=TensorSpec(shape=(None, 1, 1), dtype=tf.float32, name='input_3'), name='input_3', description="created by layer 'input_3'"), but it was called on an input with incompatible shape (32,).
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13396/1663858450.py in <module>
#      29
#      30 # model fit
# ---> 31 concat_model.fit([feature1,input_train], train_labels,epochs=7, batch_size=32,validation_data=([feature2,input_test], test_labels),
#      32                  shuffle=False)# because of time-series
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 213, in assert_input_compatibility
#         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#
#     ValueError: Exception encountered when calling layer "model_5" (type Functional).
#
#     Input 0 of layer "lstm_2" is incompatible with the layer: expected ndim=3, found ndim=1. Full shape received: (32,)
#
#     Call arguments received:
#       • inputs=('tf.Tensor(shape=(32,), dtype=string)', 'tf.Tensor(shape=(32, 1000), dtype=int32)')
#       • training=True
#       • mask=None

# %% [markdown]
# ### simpleRNN

# %%
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

model = Sequential()
model.add(Embedding(max_features, 32))
model.add(SimpleRNN(32))
model.add(Dense(1, activation='sigmoid'))
mc = ModelCheckpoint('best_simpleRNN.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit([feature1,input_train], train_labels,
                    epochs=10,
                    batch_size=128,
                    validation_split=0.2)

import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

model.evaluate([feature2,input_test], test_labels)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12368/4255170833.py in <module>
#      10 mc = ModelCheckpoint('best_simpleRNN.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)
#      11 model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
# ---> 12 history = model.fit([input_train, lines3_], train_labels,
#      13                     epochs=10,
#      14                     batch_size=128,
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\func_graph.py in autograph_handler(*args, **kwargs)
#    1127           except Exception as e:  # pylint:disable=broad-except
#    1128             if hasattr(e, "ag_error_metadata"):
# -> 1129               raise e.ag_error_metadata.to_exception(e)
#    1130             else:
#    1131               raise
#
# ValueError: in user code:
#
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 878, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 867, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 860, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\training.py", line 808, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 67, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\user\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 199, in assert_input_compatibility
#         raise ValueError(f'Layer "{layer_name}" expects {len(input_spec)} input(s),'
#
#     ValueError: Layer "sequential" expects 1 input(s), but it received 2 input tensors. Inputs received: [<tf.Tensor 'IteratorGetNext:0' shape=(128, 1000) dtype=int32>, <tf.Tensor 'IteratorGetNext:1' shape=(128, 3) dtype=float32>]

# %% [markdown]
# ### LSTM

# %%
from keras.preprocessing.text import Tokenizer
import codecs
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import nltk
from konlpy.tag import Okt
from tqdm import tqdm

# train set
name = "2"
filename1 = './new_data/definition'+name+'_spynorth_scaling_trust.txt'
filename2 = './new_data/definition'+name+'_spynorth_scaling_untrust.txt'
filename3 = './new_data/definition'+name+'_intistranger_scaling_trust.txt'
filename4 = './new_data/definition'+name+'_intistranger_scaling_untrust.txt'
filename5 = './new_data/definition'+name+'_assassin_scaling_trust.txt'
filename6 = './new_data/definition'+name+'_assassin_scaling_untrust.txt'
filename7 = './new_data/definition'+name+'_1987_scaling_trust.txt'
filename8 = './new_data/definition'+name+'_1987_scaling_untrust.txt'
filename9 = './new_data/definition'+name+'_taxi_scaling_trust.txt'
filename10 = './new_data/definition'+name+'_taxi_scaling_untrust.txt'


with codecs.open(filename1, 'r', encoding='utf-8-sig') as f:
    lines1 = f.readlines()
with codecs.open(filename2, 'r', encoding='utf-8-sig') as f:
    lines2 = f.readlines()
with codecs.open(filename3, 'r', encoding='utf-8-sig') as f:
    lines3 = f.readlines()
with codecs.open(filename4, 'r', encoding='utf-8-sig') as f:
    lines4 = f.readlines()
with codecs.open(filename5, 'r', encoding='utf-8-sig') as f:
    lines5 = f.readlines()
with codecs.open(filename6, 'r', encoding='utf-8-sig') as f:
    lines6 = f.readlines()
with codecs.open(filename7, 'r', encoding='utf-8-sig') as f:
    lines7 = f.readlines()
with codecs.open(filename8, 'r', encoding='utf-8-sig') as f:
    lines8 = f.readlines()
with codecs.open(filename9, 'r', encoding='utf-8-sig') as f:
    lines9 = f.readlines()
with codecs.open(filename10, 'r', encoding='utf-8-sig') as f:
    lines10 = f.readlines()




# test set


with codecs.open('./new_data/definition'+name+'_spynorth_test_t.txt', 'r', 'utf-8-sig') as f:
    test1 = f.readlines()
with codecs.open('./new_data/definition'+name+'_spynorth_test_ut.txt', 'r', 'utf-8-sig') as f:
    test2 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test3 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test4 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test5 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test6 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test7 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test8 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test9 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test10 = f.readlines()

    

from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1
lines_ut = lines2
test_t = test1
test_ut = test2


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []
for line in lines_t:
    a = list(map(float, line.split(",")[:3])) 
    text = line.split(",")[3]
    lines_.append(text.strip())
    feature1.append(a)
    
    

for line in lines_ut:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = list(map(float, line.split(",")[:3])) 
    feature1.append(a)

for line in test_t:
    text = line.split(",")[3]
    test_lines_.append(text.strip()) # trust
    a = list(map(float, line.split(",")[:3])) 
    feature2.append(a)

for line in test_ut:
    text = line.split(",")[3]
    test_lines_.append(text.strip()) # untrust\
    a = list(map(float, line.split(",")[:3])) 
    feature2.append(a)

    
    

from keras.layers import Input, Dense
from keras.models import Model


from keras.preprocessing import sequence
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(0)
for j in range(len(lines_ut)):
    train_labels.append(1)
for i in range(len(test_t)):
    test_labels.append(0)
for j in range(len(test_ut)):
    test_labels.append(1)
    
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

okt = Okt()
x_train = []
x_test = []
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

for sentence in tqdm(lines_):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_train.append(stopwords_removed_sentence)

for sentence in tqdm(test_lines_):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_test.append(stopwords_removed_sentence)

maxlen = 1000  # 100개 단어 이후는 버립니다
training_samples = 200  # 훈련 샘플은 200 -> 200개입니다
validation_samples = 10000  # 검증 샘플은 10,000개입니다
max_words = 10000  # 데이터셋에서 가장 빈도 높은 10,000개의 단어만 사용합니다
# train 토큰화
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(x_train)
sequences = tokenizer.texts_to_sequences(x_train)

word_index = tokenizer.word_index
train = pad_sequences(sequences,maxlen=maxlen)

# test 토큰화
tokenizer2 = Tokenizer(num_words=max_words)
tokenizer2.fit_on_texts(x_test)
sequences2 = tokenizer2.texts_to_sequences(x_test)

word_index2 = tokenizer2.word_index
test = pad_sequences(sequences2,maxlen=maxlen)

train_labels = np.asarray(train_labels).astype('int32').reshape((-1,1))
test_labels = np.asarray(test_labels).astype('int32').reshape((-1,1))

from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

max_features = 10000  # 특성으로 사용할 단어의 수

batch_size = 32
input_train = sequence.pad_sequences(train,maxlen=maxlen)
input_test = sequence.pad_sequences(test,maxlen=maxlen)

train_feature = np.asarray(feature1)
test_feature = np.asarray(feature2)

# Dense 1로 했을 때
from keras import layers
# lstm model
text_input = layers.Input(shape=(None,),)
text_output = layers.Embedding(max_features, 32) (text_input)
text_output = layers.LSTM(32)(text_output)
#lstm_model = Model(inputs=text_input, outputs=text_output)

feature_input = layers.Input(shape=(3,),)
feature_output = layers.Dense(32,activation="relu")(feature_input)

concatenated = layers.concatenate([text_output, feature_output])
concat_out = layers.Dense(1, activation='sigmoid')(concatenated)
model = Model([text_input, feature_input], concat_out)

model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
model.fit([input_train,train_feature],train_labels,epochs=10,
                    validation_split=0.2)
model.evaluate([input_test,test_feature], test_labels)

from keras.preprocessing.text import Tokenizer
import codecs
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import nltk
from konlpy.tag import Okt
from tqdm import tqdm

# train set
name = "3"
filename1 = './new_data/definition'+name+'_spynorth_scaling_trust.txt'
filename2 = './new_data/definition'+name+'_spynorth_scaling_untrust.txt'
filename3 = './new_data/definition'+name+'_intistranger_scaling_trust.txt'
filename4 = './new_data/definition'+name+'_intistranger_scaling_untrust.txt'
filename5 = './new_data/definition'+name+'_assassin_scaling_trust.txt'
filename6 = './new_data/definition'+name+'_assassin_scaling_untrust.txt'
filename7 = './new_data/definition'+name+'_1987_scaling_trust.txt'
filename8 = './new_data/definition'+name+'_1987_scaling_untrust.txt'
filename9 = './new_data/definition'+name+'_taxi_scaling_trust.txt'
filename10 = './new_data/definition'+name+'_taxi_scaling_untrust.txt'


with codecs.open(filename1, 'r', encoding='utf-8-sig') as f:
    lines1 = f.readlines()
with codecs.open(filename2, 'r', encoding='utf-8-sig') as f:
    lines2 = f.readlines()
with codecs.open(filename3, 'r', encoding='utf-8-sig') as f:
    lines3 = f.readlines()
with codecs.open(filename4, 'r', encoding='utf-8-sig') as f:
    lines4 = f.readlines()
with codecs.open(filename5, 'r', encoding='utf-8-sig') as f:
    lines5 = f.readlines()
with codecs.open(filename6, 'r', encoding='utf-8-sig') as f:
    lines6 = f.readlines()
with codecs.open(filename7, 'r', encoding='utf-8-sig') as f:
    lines7 = f.readlines()
with codecs.open(filename8, 'r', encoding='utf-8-sig') as f:
    lines8 = f.readlines()
with codecs.open(filename9, 'r', encoding='utf-8-sig') as f:
    lines9 = f.readlines()
with codecs.open(filename10, 'r', encoding='utf-8-sig') as f:
    lines10 = f.readlines()




# test set


with codecs.open('./new_data/definition'+name+'_spynorth_test_t.txt', 'r', 'utf-8-sig') as f:
    test1 = f.readlines()
with codecs.open('./new_data/definition'+name+'_spynorth_test_ut.txt', 'r', 'utf-8-sig') as f:
    test2 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test3 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test4 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test5 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test6 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test7 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test8 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test9 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test10 = f.readlines()

    

from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1
lines_ut = lines2
test_t = test1
test_ut = test2


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []
for line in lines_t:
    a = list(map(float, line.split(",")[:3])) 
    text = line.split(",")[3]
    lines_.append(text.strip())
    feature1.append(a)
    
    

for line in lines_ut:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = list(map(float, line.split(",")[:3])) 
    feature1.append(a)

for line in test_t:
    text = line.split(",")[3]
    test_lines_.append(text.strip()) # trust
    a = list(map(float, line.split(",")[:3])) 
    feature2.append(a)

for line in test_ut:
    text = line.split(",")[3]
    test_lines_.append(text.strip()) # untrust\
    a = list(map(float, line.split(",")[:3])) 
    feature2.append(a)

    
    

from keras.layers import Input, Dense
from keras.models import Model


from keras.preprocessing import sequence
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(0)
for j in range(len(lines_ut)):
    train_labels.append(1)
for i in range(len(test_t)):
    test_labels.append(0)
for j in range(len(test_ut)):
    test_labels.append(1)
    
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import numpy as np

okt = Okt()
x_train = []
x_test = []
stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

for sentence in tqdm(lines_):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_train.append(stopwords_removed_sentence)

for sentence in tqdm(test_lines_):
    tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    x_test.append(stopwords_removed_sentence)

maxlen = 1000  # 100개 단어 이후는 버립니다
training_samples = 200  # 훈련 샘플은 200 -> 200개입니다
validation_samples = 10000  # 검증 샘플은 10,000개입니다
max_words = 10000  # 데이터셋에서 가장 빈도 높은 10,000개의 단어만 사용합니다
# train 토큰화
tokenizer = Tokenizer(num_words=max_words)
tokenizer.fit_on_texts(x_train)
sequences = tokenizer.texts_to_sequences(x_train)

word_index = tokenizer.word_index
train = pad_sequences(sequences,maxlen=maxlen)

# test 토큰화
tokenizer2 = Tokenizer(num_words=max_words)
tokenizer2.fit_on_texts(x_test)
sequences2 = tokenizer2.texts_to_sequences(x_test)

word_index2 = tokenizer2.word_index
test = pad_sequences(sequences2,maxlen=maxlen)

train_labels = np.asarray(train_labels).astype('int32').reshape((-1,1))
test_labels = np.asarray(test_labels).astype('int32').reshape((-1,1))

from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint

max_features = 10000  # 특성으로 사용할 단어의 수

batch_size = 32
input_train = sequence.pad_sequences(train,maxlen=maxlen)
input_test = sequence.pad_sequences(test,maxlen=maxlen)

train_feature = np.asarray(feature1)
test_feature = np.asarray(feature2)

# Dense 1로 했을 때
from keras import layers
# lstm model
text_input = layers.Input(shape=(None,),)
text_output = layers.Embedding(max_features, 32) (text_input)
text_output = layers.LSTM(32)(text_output)
#lstm_model = Model(inputs=text_input, outputs=text_output)

feature_input = layers.Input(shape=(3,),)
feature_output = layers.Dense(32,activation="relu")(feature_input)

concatenated = layers.concatenate([text_output, feature_output])
concat_out = layers.Dense(1, activation='sigmoid')(concatenated)
model = Model([text_input, feature_input], concat_out)

model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
model.fit([input_train,train_feature],train_labels,epochs=10,
                    validation_split=0.2)
model.evaluate([input_test,test_feature], test_labels)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6400/6400 [00:14<00:00, 436.77it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1600/1600 [00:03<00:00, 432.86it/s]
# Epoch 1/10
# 160/160 [==============================] - 30s 180ms/step - loss: 0.6715 - acc: 0.6105 - val_loss: 0.6938 - val_acc: 0.5828
# Epoch 2/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.6424 - acc: 0.6287 - val_loss: 0.9419 - val_acc: 0.1172
# Epoch 3/10
# 160/160 [==============================] - 27s 172ms/step - loss: 0.5962 - acc: 0.6816 - val_loss: 0.9576 - val_acc: 0.2789
# Epoch 4/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.5537 - acc: 0.7115 - val_loss: 1.1712 - val_acc: 0.2562
# Epoch 5/10
# 160/160 [==============================] - 27s 172ms/step - loss: 0.5158 - acc: 0.7496 - val_loss: 1.0515 - val_acc: 0.3672
# Epoch 6/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.5950 - acc: 0.6703 - val_loss: 0.8679 - val_acc: 0.5602
# Epoch 7/10
# 160/160 [==============================] - 28s 172ms/step - loss: 0.5000 - acc: 0.7568 - val_loss: 1.5140 - val_acc: 0.2289
# Epoch 8/10
# 160/160 [==============================] - 28s 172ms/step - loss: 0.4473 - acc: 0.7875 - val_loss: 1.2691 - val_acc: 0.3523
# Epoch 9/10
# 160/160 [==============================] - 28s 172ms/step - loss: 0.4143 - acc: 0.8105 - val_loss: 1.2257 - val_acc: 0.3836
# Epoch 10/10
# 160/160 [==============================] - 28s 172ms/step - loss: 0.3844 - acc: 0.8219 - val_loss: 1.3838 - val_acc: 0.3750
# 50/50 [==============================] - 3s 54ms/step - loss: 0.9966 - acc: 0.5481
# 100%|█████████████████████████████████████████████████████████████████████████████| 6400/6400 [00:14<00:00, 426.69it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 1600/1600 [00:03<00:00, 426.55it/s]
# Epoch 1/10
# 160/160 [==============================] - 29s 173ms/step - loss: 0.6767 - acc: 0.6213 - val_loss: 0.8842 - val_acc: 0.0000e+00
# Epoch 2/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.6398 - acc: 0.6389 - val_loss: 0.9023 - val_acc: 0.1484
# Epoch 3/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.6038 - acc: 0.6830 - val_loss: 1.0067 - val_acc: 0.2859
# Epoch 4/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.5620 - acc: 0.7211 - val_loss: 2.3746 - val_acc: 0.0227
# Epoch 5/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.5313 - acc: 0.7352 - val_loss: 1.0677 - val_acc: 0.3523
# Epoch 6/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.4886 - acc: 0.7719 - val_loss: 1.0842 - val_acc: 0.4164
# Epoch 7/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.5609 - acc: 0.7375 - val_loss: 1.1593 - val_acc: 0.3961
# Epoch 8/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.4283 - acc: 0.8049 - val_loss: 1.1541 - val_acc: 0.4234
# Epoch 9/10
# 160/160 [==============================] - 28s 173ms/step - loss: 0.3884 - acc: 0.8240 - val_loss: 1.5928 - val_acc: 0.3703
# Epoch 10/10
# 160/160 [==============================] - 27s 172ms/step - loss: 0.6621 - acc: 0.7910 - val_loss: 3.7511 - val_acc: 0.0000e+00
# 50/50 [==============================] - 3s 54ms/step - loss: 1.9122 - acc: 0.5000
# [1.9121702909469604, 0.5]

# %%
text_input = layers.Input(shape=(None,),)
text_output = layers.Embedding(max_features, 32) (text_input)
text_output = layers.LSTM(32)(text_output)
#lstm_model = Model(inputs=text_input, outputs=text_output)

feature_input = layers.Input(shape=(3,),)
feature_output = layers.Dense(32,activation="relu")(feature_input)

concatenated = layers.concatenate([text_output, feature_output])
concat_out = layers.Dense(1, activation='sigmoid')(concatenated)
model = Model([text_input, feature_input], concat_out)

model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['acc'])
model.fit([input_train,train_feature],train_labels,epochs=10,
                    validation_split=0.2)
model.evaluate([input_test,test_feature], test_labels)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9188/1676875356.py in <module>
#       8
#       9 concatenated = layers.concatenate([text_output, feature_output])
# ---> 10 concatenated = layers.LSTM(32)(concatenated)
#      11 concat_out = layers.Dense(1, activation='sigmoid')(concatenated)
#      12 model = Model([text_input, feature_input], concat_out)
#
# ~\anaconda3\lib\site-packages\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     677
#     678     if initial_state is None and constants is None:
# --> 679       return super(RNN, self).__call__(inputs, **kwargs)
#     680
#     681     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\engine\input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     211       ndim = shape.rank
#     212       if ndim != spec.ndim:
# --> 213         raise ValueError(f'Input {input_index} of layer "{layer_name}" '
#     214                          'is incompatible with the layer: '
#     215                          f'expected ndim={spec.ndim}, found ndim={ndim}. '
#
# ValueError: Input 0 of layer "lstm_4" is incompatible with the layer: expected ndim=3, found ndim=2. Full shape received: (None, 64)
