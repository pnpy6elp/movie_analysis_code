# %% [markdown]
# # 1987

# %% [markdown]
# ## definition 1

# %%
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_1987_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_1987_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_1987_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_1987_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
# Out:
# 11781   3413

# %%
n1 = 1
n2 = 11782
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1

# %%
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_1987_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_1987_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_1987_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_1987_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
    
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_1987_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_1987_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_1987_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_1987_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
# Out:
# 11781   3413
# 11781   3413

# %% [markdown]
# # assassination

# %%
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_assassin_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_assassin_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_assassin_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_assassin_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1

f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_assassin_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_assassin_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_assassin_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_assassin_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
    
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_assassin_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_assassin_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_assassin_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_assassin_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
# Out:
# 6753   4430
# 6753   4430
# 6753   4430

# %% [markdown]
# # 공조

# %%
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_gonjo_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_gonjo_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_gongjo_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_gongjo_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1

f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_gonjo_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_gonjo_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_gongjo_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_gongjo_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
    
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_gonjo_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_gonjo_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_gongjo_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_gongjo_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
# Out:
# 6461   4993
# 6461   4993
# 6461   4993

# %% [markdown]
# # 공작

# %%
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_spynorth_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_spynorth_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1

f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_spynorth_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_spynorth_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
    
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_spynorth_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_spynorth_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
# Out:
# 6608   5706
# 6608   5706
# 6608   5706

# %% [markdown]
# # taxi

# %%
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_taxi_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_taxi_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_taxi_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_taxi_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1

f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_taxi_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_taxi_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_taxi_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_taxi_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
    
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_taxi_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_taxi_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_taxi_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_taxi_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
# Out:
# 14814   4840
# 14814   4840
# 14814   4840

# %% [markdown]
# # 완벽한 타인

# %%
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_intistranger_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition1_intistranger_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_intistranger_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_intistranger_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1

f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_intistranger_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition2_intistranger_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_intistranger_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_intistranger_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
    
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_intistranger_t.txt",  "r", encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/definition/definition3_intistranger_ut.txt",  "r", encoding='utf-8')

f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_intistranger_t.txt",  "w", encoding='utf-8')
f4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_intistranger_ut.txt",  "w", encoding='utf-8')

lines1 = f1.readlines()
lines2 = f2.readlines()

print(len(lines1), " ", len(lines2))
n1 = 1
n2 = len(lines1) + 1
for line in lines1:
    f3.write(line.strip())
    f3.write(",")
    f3.write(str(n1))
    f3.write("\n")
    n1 += 1
for line in lines2:
    f4.write(line.strip())
    f4.write(",")
    f4.write(str(n2))
    f4.write("\n")
    n2 += 1
# Out:
# 4520   4847
# 4520   4847
# 4520   4847
