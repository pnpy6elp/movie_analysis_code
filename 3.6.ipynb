# %% [markdown]
# # 공조

# %%
import pandas as pd
import numpy
import json
import matplotlib.pyplot as plt

import sklearn.metrics as sk 



df = pd.read_csv("./csvfile/gongjo1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 1",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/gongjo1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 2",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/gongjo1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
df["spearman"] = df["spearman"].abs()
df = df.sort_values(by=['spearman'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 3",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/gongjo1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 1 - rating",sk.classification_report(y_true,y_pred))


df = pd.read_csv("./csvfile/gongjo1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 2 - sentiment",sk.classification_report(y_true,y_pred))
# Out:
# definition 1               precision    recall  f1-score   support
#
#          0.0       0.51      0.51      0.51      5022
#          1.0       0.62      0.62      0.62      6504
#
#     accuracy                           0.57     11526
#    macro avg       0.56      0.56      0.56     11526
# weighted avg       0.57      0.57      0.57     11526
#
# definition 2               precision    recall  f1-score   support
#
#          0.0       0.47      0.47      0.47      5022
#          1.0       0.59      0.59      0.59      6504
#
#     accuracy                           0.54     11526
#    macro avg       0.53      0.53      0.53     11526
# weighted avg       0.54      0.54      0.54     11526
#
# definition 3               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45      5022
#          1.0       0.57      0.57      0.57      6504
#
#     accuracy                           0.52     11526
#    macro avg       0.51      0.51      0.51     11526
# weighted avg       0.52      0.52      0.52     11526
#
# 비교 1 - rating               precision    recall  f1-score   support
#
#          0.0       0.17      0.17      0.17      5022
#          1.0       0.36      0.36      0.36      6504
#
#     accuracy                           0.27     11526
#    macro avg       0.26      0.26      0.26     11526
# weighted avg       0.27      0.27      0.27     11526
#
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#          0.0       0.33      0.33      0.33      5022
#          1.0       0.48      0.48      0.48      6504
#
#     accuracy                           0.41     11526
#    macro avg       0.40      0.40      0.40     11526
# weighted avg       0.41      0.41      0.41     11526

# %%
print("Precision : %f" % sk.precision_score(y_true, y_pred, average='weighted'))
print("Recall :    %f" % sk.recall_score(y_true, y_pred, average='weighted'))
print("F1 score:  %f" % sk.f1_score(y_true, y_pred, average='weighted'), end='\n\n')
# Out:
# Precision : 0.412632
# Recall :    0.412632
# F1 score:  0.412632

# %% [markdown]
# # 1987

# %%
import pandas as pd
import numpy
import json
import matplotlib.pyplot as plt

import sklearn.metrics as sk 



df = pd.read_csv("./csvfile/1987.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t2 = df_t1.loc[0:11926]


df_ut2 = df[df["pred"] == 0] # distrust
df_ut2 = df_ut2.loc[11926:15416]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 1",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/1987.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t2 = df_t1.loc[0:11926]


df_ut2 = df[df["pred"] == 0] # distrust
df_ut2 = df_ut2.loc[11926:15416]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 2",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/1987.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
df["spearman"] = df["spearman"].abs()
df = df.sort_values(by=['spearman'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:11926]


df_ut2 = df[df["pred"] == 0] # distrust
df_ut2 = df_ut2.loc[11926:15416]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 3",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/1987.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:11926]


df_ut2 = df[df["pred"] == 0] # distrust
df_ut2 = df_ut2.loc[11926:15416]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 1 - rating",sk.classification_report(y_true,y_pred))


df = pd.read_csv("./csvfile/1987.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:11926]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[11926:15416]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 2 - sentiment",sk.classification_report(y_true,y_pred))
# Out:
# definition 1               precision    recall  f1-score   support
#
#          0.0       0.13      0.13      0.13      3490
#          1.0       0.75      0.75      0.75     11926
#
#     accuracy                           0.61     15416
#    macro avg       0.44      0.44      0.44     15416
# weighted avg       0.61      0.61      0.61     15416
#
# definition 2               precision    recall  f1-score   support
#
#          0.0       0.20      0.20      0.20      3490
#          1.0       0.77      0.77      0.77     11926
#
#     accuracy                           0.64     15416
#    macro avg       0.48      0.48      0.48     15416
# weighted avg       0.64      0.64      0.64     15416
#
# definition 3               precision    recall  f1-score   support
#
#          0.0       0.21      0.21      0.21      3490
#          1.0       0.77      0.77      0.77     11926
#
#     accuracy                           0.64     15416
#    macro avg       0.49      0.49      0.49     15416
# weighted avg       0.64      0.64      0.64     15416
#
# 비교 1 - rating               precision    recall  f1-score   support
#
#          0.0       0.58      0.58      0.58      3490
#          1.0       0.88      0.88      0.88     11926
#
#     accuracy                           0.81     15416
#    macro avg       0.73      0.73      0.73     15416
# weighted avg       0.81      0.81      0.81     15416
#
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#          0.0       0.41      0.41      0.41      3490
#          1.0       0.83      0.83      0.83     11926
#
#     accuracy                           0.73     15416
#    macro avg       0.62      0.62      0.62     15416
# weighted avg       0.73      0.73      0.73     15416

# %% [markdown]
# # 암살

# %%
import pandas as pd
import numpy
import json
import matplotlib.pyplot as plt

import sklearn.metrics as sk 



df = pd.read_csv("./csvfile/assassin1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 1",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/assassin1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 2",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/assassin1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
df["spearman"] = df["spearman"].abs()
df = df.sort_values(by=['spearman'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 3",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/assassin1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 1 - rating",sk.classification_report(y_true,y_pred))


df = pd.read_csv("./csvfile/assassin1.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 2 - sentiment",sk.classification_report(y_true,y_pred))
# Out:
# definition 1               precision    recall  f1-score   support
#
#          0.0       0.36      0.36      0.36      4477
#          1.0       0.58      0.58      0.58      6821
#
#     accuracy                           0.49     11298
#    macro avg       0.47      0.47      0.47     11298
# weighted avg       0.49      0.49      0.49     11298
#
# definition 2               precision    recall  f1-score   support
#
#          0.0       0.38      0.38      0.38      4477
#          1.0       0.59      0.59      0.59      6821
#
#     accuracy                           0.51     11298
#    macro avg       0.49      0.49      0.49     11298
# weighted avg       0.51      0.51      0.51     11298
#
# definition 3               precision    recall  f1-score   support
#
#          0.0       0.39      0.39      0.39      4477
#          1.0       0.60      0.60      0.60      6821
#
#     accuracy                           0.52     11298
#    macro avg       0.50      0.50      0.50     11298
# weighted avg       0.52      0.52      0.52     11298
#
# 비교 1 - rating               precision    recall  f1-score   support
#
#          0.0       0.35      0.35      0.35      4477
#          1.0       0.58      0.58      0.58      6821
#
#     accuracy                           0.49     11298
#    macro avg       0.47      0.47      0.47     11298
# weighted avg       0.49      0.49      0.49     11298
#
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#          0.0       0.44      0.44      0.44      4477
#          1.0       0.63      0.63      0.63      6821
#
#     accuracy                           0.55     11298
#    macro avg       0.53      0.53      0.53     11298
# weighted avg       0.55      0.55      0.55     11298

# %% [markdown]
# # 공작

# %%
import pandas as pd
import numpy
import json
import matplotlib.pyplot as plt

import sklearn.metrics as sk 



df = pd.read_csv("./csvfile/spynorth.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가

# %%
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 1",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/spynorth.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가

y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 2",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/spynorth.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
df["spearman"] = df["spearman"].abs()
df = df.sort_values(by=['spearman'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust

t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 3",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/spynorth.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust

t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 1 - rating",sk.classification_report(y_true,y_pred))


df = pd.read_csv("./csvfile/spynorth.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust

t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 2 - sentiment",sk.classification_report(y_true,y_pred))
# Out:
# definition 1               precision    recall  f1-score   support
#
#          0.0       0.52      0.52      0.52      5761
#          1.0       0.59      0.59      0.59      6703
#
#     accuracy                           0.56     12464
#    macro avg       0.56      0.56      0.56     12464
# weighted avg       0.56      0.56      0.56     12464
#
# definition 2               precision    recall  f1-score   support
#
#          0.0       0.48      0.48      0.48      5761
#          1.0       0.55      0.55      0.55      6703
#
#     accuracy                           0.52     12464
#    macro avg       0.52      0.52      0.52     12464
# weighted avg       0.52      0.52      0.52     12464
#
# definition 3               precision    recall  f1-score   support
#
#          0.0       0.50      0.50      0.50      5761
#          1.0       0.57      0.57      0.57      6703
#
#     accuracy                           0.53     12464
#    macro avg       0.53      0.53      0.53     12464
# weighted avg       0.53      0.53      0.53     12464
#
# 비교 1 - rating               precision    recall  f1-score   support
#
#          0.0       0.28      0.28      0.28      5761
#          1.0       0.38      0.38      0.38      6703
#
#     accuracy                           0.34     12464
#    macro avg       0.33      0.33      0.33     12464
# weighted avg       0.34      0.34      0.34     12464
#
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#          0.0       0.40      0.40      0.40      5761
#          1.0       0.49      0.49      0.49      6703
#
#     accuracy                           0.45     12464
#    macro avg       0.44      0.44      0.44     12464
# weighted avg       0.45      0.45      0.45     12464

# %% [markdown]
# # 택시운전사

# %%
import pandas as pd
import numpy
import json
import matplotlib.pyplot as plt

import sklearn.metrics as sk 



df = pd.read_csv("./csvfile/taxi.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 1",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/taxi.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 2",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/taxi.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
df["spearman"] = df["spearman"].abs()
df = df.sort_values(by=['spearman'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 3",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/taxi.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 1 - rating",sk.classification_report(y_true,y_pred))


df = pd.read_csv("./csvfile/taxi.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 2 - sentiment",sk.classification_report(y_true,y_pred))
# Out:
# definition 1               precision    recall  f1-score   support
#
#          0.0       0.13      0.13      0.13      4929
#          1.0       0.71      0.71      0.71     14976
#
#     accuracy                           0.57     19905
#    macro avg       0.42      0.42      0.42     19905
# weighted avg       0.57      0.57      0.57     19905
#
# definition 2               precision    recall  f1-score   support
#
#          0.0       0.20      0.20      0.20      4929
#          1.0       0.74      0.74      0.74     14976
#
#     accuracy                           0.60     19905
#    macro avg       0.47      0.47      0.47     19905
# weighted avg       0.60      0.60      0.60     19905
#
# definition 3               precision    recall  f1-score   support
#
#          0.0       0.23      0.23      0.23      4929
#          1.0       0.75      0.75      0.75     14976
#
#     accuracy                           0.62     19905
#    macro avg       0.49      0.49      0.49     19905
# weighted avg       0.62      0.62      0.62     19905
#
# 비교 1 - rating               precision    recall  f1-score   support
#
#          0.0       0.65      0.65      0.65      4929
#          1.0       0.89      0.89      0.89     14976
#
#     accuracy                           0.83     19905
#    macro avg       0.77      0.77      0.77     19905
# weighted avg       0.83      0.83      0.83     19905
#
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#          0.0       0.46      0.46      0.46      4929
#          1.0       0.82      0.82      0.82     14976
#
#     accuracy                           0.73     19905
#    macro avg       0.64      0.64      0.64     19905
# weighted avg       0.73      0.73      0.73     19905

# %% [markdown]
# # 범죄도시

# %%
import pandas as pd
import numpy
import json
import matplotlib.pyplot as plt

import sklearn.metrics as sk 



df = pd.read_csv("./csvfile/outlaws.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 1",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/outlaws.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 2",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/outlaws.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
df["spearman"] = df["spearman"].abs()
df = df.sort_values(by=['spearman'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 3",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/outlaws.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 1 - rating",sk.classification_report(y_true,y_pred))


df = pd.read_csv("./csvfile/outlaws.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 2 - sentiment",sk.classification_report(y_true,y_pred))
# Out:
# definition 1               precision    recall  f1-score   support
#
#          0.0       0.03      0.03      0.03      1745
#          1.0       0.88      0.88      0.88     14582
#
#     accuracy                           0.79     16327
#    macro avg       0.46      0.46      0.46     16327
# weighted avg       0.79      0.79      0.79     16327
#
# definition 2               precision    recall  f1-score   support
#
#          0.0       0.06      0.06      0.06      1745
#          1.0       0.89      0.89      0.89     14582
#
#     accuracy                           0.80     16327
#    macro avg       0.47      0.47      0.47     16327
# weighted avg       0.80      0.80      0.80     16327
#
# definition 3               precision    recall  f1-score   support
#
#          0.0       0.07      0.07      0.07      1745
#          1.0       0.89      0.89      0.89     14582
#
#     accuracy                           0.80     16327
#    macro avg       0.48      0.48      0.48     16327
# weighted avg       0.80      0.80      0.80     16327
#
# 비교 1 - rating               precision    recall  f1-score   support
#
#          0.0       0.62      0.62      0.62      1745
#          1.0       0.95      0.95      0.95     14582
#
#     accuracy                           0.92     16327
#    macro avg       0.79      0.79      0.79     16327
# weighted avg       0.92      0.92      0.92     16327
#
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#          0.0       0.30      0.30      0.30      1745
#          1.0       0.92      0.92      0.92     14582
#
#     accuracy                           0.85     16327
#    macro avg       0.61      0.61      0.61     16327
# weighted avg       0.85      0.85      0.85     16327

# %% [markdown]
# # 완벽한 타인

# %%
import pandas as pd
import numpy
import json
import matplotlib.pyplot as plt

import sklearn.metrics as sk 



df = pd.read_csv("./csvfile/intistranger.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 1",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/intistranger.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment std'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 2",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/intistranger.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
df["spearman"] = df["spearman"].abs()
df = df.sort_values(by=['spearman'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("definition 3",sk.classification_report(y_true,y_pred))

df = pd.read_csv("./csvfile/intistranger.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['rating'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 1 - rating",sk.classification_report(y_true,y_pred))


df = pd.read_csv("./csvfile/intistranger.csv", sep=",")
df = df[df["sympathy"] != df["unsympathy"]]

for index, row in df.iterrows(): 
    if df.loc[index, "sympathy"] > df.loc[index, "unsympathy"]:
        df.loc[index, "label"] = 1 #좋아요 > 싫어요 -> trust -> label을 1로 설정
    elif(df.loc[index, "sympathy"] < df.loc[index, "unsympathy"]):
        df.loc[index, "label"] = 0 # trust을 제외한 나머지 -> untrust -> label을 0으로 설정
    else:
        df.loc[index, "label"] = -1 # sympathy와 unsympathy가 같은 경우는 뺌. 같은 경우가 많아서 untrust로 넣으면 원하는 결과가 안나올까봐..

t = len(df[df["label"] == 1])
ut = len(df[df["label"] == 0])
       
li = []

n = 0
for i in range(0, t):
    li.append(1)
for i in range(0, ut):
    li.append(0)
# li : 1은 t개, 0은 ut개 (정답과 크기를 맞추기 위해 설정)
df = df.sort_values(by=['sentiment'], axis=0, ascending=False) 
df = df.reset_index()
# correlation score을 기준으로 오름차순, 위에서 t번째까지는 pred가 1, 나머지는 untrust이므로 0개 
df["pred"] = li # column 추가
rating_df_t = df[df["pred"] == 1] # trust
rating_df_ut = df[df["pred"] == 0] # distrust

df_t1 = df[df["pred"] == 1] # trust
df_t1 = df_t1.loc[0:6504]


df_ut1 = df[df["pred"] == 0] # distrust
df_ut1 = df_ut1.loc[6504:11526]
t1 = df_t1["sentiment"].to_numpy()
u1 = df_ut1["sentiment"].to_numpy()
y_true = df["label"].to_numpy()
y_pred = df["pred"].to_numpy()
print("비교 2 - sentiment",sk.classification_report(y_true,y_pred))
# Out:
# definition 1               precision    recall  f1-score   support
#
#          0.0       0.56      0.56      0.56      4885
#          1.0       0.53      0.53      0.53      4571
#
#     accuracy                           0.54      9456
#    macro avg       0.54      0.54      0.54      9456
# weighted avg       0.54      0.54      0.54      9456
#
# definition 2               precision    recall  f1-score   support
#
#          0.0       0.53      0.53      0.53      4885
#          1.0       0.50      0.50      0.50      4571
#
#     accuracy                           0.52      9456
#    macro avg       0.52      0.52      0.52      9456
# weighted avg       0.52      0.52      0.52      9456
#
# definition 3               precision    recall  f1-score   support
#
#          0.0       0.52      0.52      0.52      4885
#          1.0       0.48      0.48      0.48      4571
#
#     accuracy                           0.50      9456
#    macro avg       0.50      0.50      0.50      9456
# weighted avg       0.50      0.50      0.50      9456
#
# 비교 1 - rating               precision    recall  f1-score   support
#
#          0.0       0.45      0.45      0.45      4885
#          1.0       0.41      0.41      0.41      4571
#
#     accuracy                           0.43      9456
#    macro avg       0.43      0.43      0.43      9456
# weighted avg       0.43      0.43      0.43      9456
#
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#          0.0       0.47      0.47      0.47      4885
#          1.0       0.43      0.43      0.43      4571
#
#     accuracy                           0.45      9456
#    macro avg       0.45      0.45      0.45      9456
# weighted avg       0.45      0.45      0.45      9456

# %%
t1 = [1,0,1,0,1,0,0,0,0,1]
t2 = [1,0,1,0,0,0,0,1,0,1]
print("비교 2 - sentiment",sk.classification_report(t1,t2))
# Out:
# 비교 2 - sentiment               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83         6
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.80        10
#    macro avg       0.79      0.79      0.79        10
# weighted avg       0.80      0.80      0.80        10

# %%
print("Precision : %f" % sk.precision_score(y_true, y_pred, average='macro'))
print("Recall :    %f" % sk.recall_score(y_true, y_pred, average='macro'))
print("F1 score:  %f" % sk.f1_score(y_true, y_pred, average='macro'), end='\n\n')
# Out:
# Precision : 0.641899
# Recall :    0.641899
# F1 score:  0.641899
