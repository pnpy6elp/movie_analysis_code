# %%
import random

file = open("./helpfulness/1987_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/1987_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/1987_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/1987_ut.txt",  "r",encoding='utf-8')
f = open("./helpfulness/1987_test_t.txt",  "w",encoding='utf-8')
f1 = open("./helpfulness/1987_test_ut.txt",  "w",encoding='utf-8')
f2 = open("./helpfulness/1987_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("./helpfulness/1987_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =11781
untrust_num =3413
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("./helpfulness/gongjo_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/gongjo_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/gongjo_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/gongjo_ut.txt",  "r",encoding='utf-8')
f = open("./helpfulness/gongjo_test_t.txt",  "w",encoding='utf-8')
f1 = open("./helpfulness/gongjo_test_ut.txt",  "w",encoding='utf-8')
f2 = open("./helpfulness/gongjo_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("./helpfulness/gongjo_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6461
untrust_num =4993
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("./helpfulness/assassin_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/assassin_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/assassin_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/assassin_ut.txt",  "r",encoding='utf-8')
f = open("./helpfulness/assassin_test_t.txt",  "w",encoding='utf-8')
f1 = open("./helpfulness/assassin_test_ut.txt",  "w",encoding='utf-8')
f2 = open("./helpfulness/assassin_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("./helpfulness/assassin_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6753
untrust_num =4430
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./helpfulness/spynorth_test_t.txt",  "w",encoding='utf-8')
f1 = open("./helpfulness/spynorth_test_ut.txt",  "w",encoding='utf-8')
f2 = open("./helpfulness/spynorth_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("./helpfulness/spynorth_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("./helpfulness/taxi_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/taxi_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/taxi_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/taxi_ut.txt",  "r",encoding='utf-8')
f = open("./helpfulness/taxi_test_t.txt",  "w",encoding='utf-8')
f1 = open("./helpfulness/taxi_test_ut.txt",  "w",encoding='utf-8')
f2 = open("./helpfulness/taxi_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("./helpfulness/taxi_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =14814
untrust_num =4840
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("./helpfulness/intistranger_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/intistranger_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/intistranger_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/intistranger_ut.txt",  "r",encoding='utf-8')
f = open("./helpfulness/intistranger_test_t.txt",  "w",encoding='utf-8')
f1 = open("./helpfulness/intistranger_test_ut.txt",  "w",encoding='utf-8')
f2 = open("./helpfulness/intistranger_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("./helpfulness/intistranger_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =4520
untrust_num =4847
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()
