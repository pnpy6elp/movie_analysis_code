# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_1987_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_1987_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_1987_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_1987_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_1987_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_1987_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_1987_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_1987_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =11781
untrust_num =3413
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_1987_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_1987_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_1987_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_1987_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_1987_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_1987_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_1987_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_1987_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =11781
untrust_num =3413
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_1987_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_1987_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_1987_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_1987_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_1987_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_1987_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_1987_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_1987_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =11781
untrust_num =3413
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_assassin_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_assassin_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_assassin_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_assassin_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_assassin_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_assassin_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_assassin_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_assassin_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6753
untrust_num =4430
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          


import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_assassin_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_assassin_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_assassin_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_assassin_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_assassin_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_assassin_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_assassin_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_assassin_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6753
untrust_num =4430
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          
    

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_assassin_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_assassin_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_assassin_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_assassin_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_assassin_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_assassin_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_assassin_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_assassin_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6753
untrust_num =4430
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_gongjo_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_gongjo_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_gongjo_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_gongjo_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_gongjo_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_gongjo_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_gongjo_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_gongjo_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6461
untrust_num =4993
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_gongjo_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_gongjo_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_gongjo_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_gongjo_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_gongjo_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_gongjo_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_gongjo_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_gongjo_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6461
untrust_num =4993
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_gongjo_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_gongjo_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_gongjo_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_gongjo_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_gongjo_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_gongjo_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_gongjo_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_gongjo_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6461
untrust_num =4993
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_spynorth_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_spynorth_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_spynorth_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_spynorth_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_spynorth_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_spynorth_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_spynorth_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_spynorth_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close() 

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_spynorth_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_spynorth_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_spynorth_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_spynorth_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_taxi_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_taxi_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_taxi_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_taxi_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_taxi_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_taxi_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_taxi_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_taxi_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =14814
untrust_num =4840
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_taxi_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_taxi_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_taxi_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_taxi_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_taxi_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_taxi_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_taxi_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_taxi_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =14814
untrust_num =4840
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_taxi_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_taxi_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_taxi_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_taxi_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_taxi_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_taxi_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_taxi_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_taxi_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =14814
untrust_num =4840
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_intistranger_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_intistranger_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_intistranger_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_intistranger_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_intistranger_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_intistranger_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_intistranger_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition1_intistranger_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =4520
untrust_num =4847
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_intistranger_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_intistranger_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_intistranger_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_intistranger_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_intistranger_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_intistranger_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_intistranger_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition2_intistranger_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =4520
untrust_num =4847
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_intistranger_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_intistranger_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_intistranger_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_intistranger_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_intistranger_test_t.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_intistranger_test_ut.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_intistranger_scaling_trust.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/new data/definition3_intistranger_scaling_untrust.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =4520
untrust_num =4847
scaling =3200
test = 800

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()
