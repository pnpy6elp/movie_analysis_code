# %% [markdown]
# # definition 3

# %%
from keras.preprocessing.text import Tokenizer
import codecs
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import nltk
from konlpy.tag import Okt
from tqdm import tqdm

# train set
name = "3"
filename1 = './new_data/definition'+name+'_spynorth_scaling_trust.txt'
filename2 = './new_data/definition'+name+'_spynorth_scaling_untrust.txt'
filename3 = './new_data/definition'+name+'_intistranger_scaling_trust.txt'
filename4 = './new_data/definition'+name+'_intistranger_scaling_untrust.txt'
filename5 = './new_data/definition'+name+'_assassin_scaling_trust.txt'
filename6 = './new_data/definition'+name+'_assassin_scaling_untrust.txt'
filename7 = './new_data/definition'+name+'_1987_scaling_trust.txt'
filename8 = './new_data/definition'+name+'_1987_scaling_untrust.txt'
filename9 = './new_data/definition'+name+'_taxi_scaling_trust.txt'
filename10 = './new_data/definition'+name+'_taxi_scaling_untrust.txt'


with codecs.open(filename1, 'r', encoding='utf-8-sig') as f:
    lines1 = f.readlines()
with codecs.open(filename2, 'r', encoding='utf-8-sig') as f:
    lines2 = f.readlines()
with codecs.open(filename3, 'r', encoding='utf-8-sig') as f:
    lines3 = f.readlines()
with codecs.open(filename4, 'r', encoding='utf-8-sig') as f:
    lines4 = f.readlines()
with codecs.open(filename5, 'r', encoding='utf-8-sig') as f:
    lines5 = f.readlines()
with codecs.open(filename6, 'r', encoding='utf-8-sig') as f:
    lines6 = f.readlines()
with codecs.open(filename7, 'r', encoding='utf-8-sig') as f:
    lines7 = f.readlines()
with codecs.open(filename8, 'r', encoding='utf-8-sig') as f:
    lines8 = f.readlines()
with codecs.open(filename9, 'r', encoding='utf-8-sig') as f:
    lines9 = f.readlines()
with codecs.open(filename10, 'r', encoding='utf-8-sig') as f:
    lines10 = f.readlines()




# test set


with codecs.open('./new_data/definition'+name+'_spynorth_test_t.txt', 'r', 'utf-8-sig') as f:
    test1 = f.readlines()
with codecs.open('./new_data/definition'+name+'_spynorth_test_ut.txt', 'r', 'utf-8-sig') as f:
    test2 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test3 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test4 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test5 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test6 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test7 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test8 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test9 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test10 = f.readlines()

# %% [markdown]
# ## 공작

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1
lines_ut = lines2
test_t = test1
test_ut = test2


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []
for line in lines_t:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    text = line.split(",")[3]
    test_lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    text = line.split(",")[3]
    test_lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(0)
for j in range(len(lines_ut)):
    train_labels.append(1)
for i in range(len(test_t)):
    test_labels.append(0)
for j in range(len(test_ut)):
    test_labels.append(1)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200]
lines_ut = lines2[:3200]
test_t = test1[:800]
test_ut = test2[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/1000
# 50/50 [==============================] - 8s 3ms/step - loss: 0.6901 - acc: 0.5383
# Epoch 2/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6862 - acc: 0.5636
# Epoch 3/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6842 - acc: 0.5678
# Epoch 4/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6830 - acc: 0.5672
# Epoch 5/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6823 - acc: 0.5666
# Epoch 6/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6812 - acc: 0.5663
# Epoch 7/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6805 - acc: 0.5648
# Epoch 8/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6791 - acc: 0.5706
# Epoch 9/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6780 - acc: 0.5691
# Epoch 10/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6773 - acc: 0.5695
# Epoch 11/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6762 - acc: 0.5694
# Epoch 12/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6761 - acc: 0.5722
# Epoch 13/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6752 - acc: 0.5702
# Epoch 14/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6758 - acc: 0.5725
# Epoch 15/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6758 - acc: 0.5683
# Epoch 16/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6753 - acc: 0.5727
# Epoch 17/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6758 - acc: 0.5709
# Epoch 18/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6751 - acc: 0.5714
# Epoch 19/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6747 - acc: 0.5742
# Epoch 20/1000
# 50/50 [==============================] - 0s 5ms/step - loss: 0.6750 - acc: 0.5763
# Epoch 21/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6749 - acc: 0.5759
# Epoch 22/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6745 - acc: 0.5756
# Epoch 23/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6752 - acc: 0.5705
# Epoch 24/1000
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6746 - acc: 0.5748
# Epoch 25/1000
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6746 - acc: 0.5717
# Epoch 26/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6745 - acc: 0.5759
# Epoch 27/1000
# 50/50 [==============================] - 0s 6ms/step - loss: 0.6742 - acc: 0.5741
# Epoch 28/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6744 - acc: 0.5742
# Epoch 29/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6741 - acc: 0.5736
# Epoch 30/1000
# 50/50 [==============================] - 0s 4ms/step - loss: 0.6741 - acc: 0.5761
# 50/50 [==============================] - 2s 1ms/step - loss: 0.6733 - acc: 0.5856
# [0.6733306646347046, 0.5856249928474426]

# %% [markdown]
# ## 공작 + 완벽한 타인

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200]
lines_ut = lines2[:3200] + lines4[:3200]
test_t = test1[:800] + test3[:800]
test_ut = test2[:800] + test4[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/1000
# 100/100 [==============================] - 7s 3ms/step - loss: 0.6900 - acc: 0.5434
# Epoch 2/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6859 - acc: 0.5477
# Epoch 3/1000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6836 - acc: 0.5462
# Epoch 4/1000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6821 - acc: 0.5420
# Epoch 5/1000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6807 - acc: 0.5502
# Epoch 6/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6804 - acc: 0.5507
# Epoch 7/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6793 - acc: 0.5535
# Epoch 8/1000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6783 - acc: 0.5550
# Epoch 9/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6780 - acc: 0.5582
# Epoch 10/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6779 - acc: 0.5575
# Epoch 11/1000
# 100/100 [==============================] - 0s 4ms/step - loss: 0.6777 - acc: 0.5620
# Epoch 12/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6777 - acc: 0.5562
# Epoch 13/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6774 - acc: 0.5638
# Epoch 14/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6777 - acc: 0.5609
# Epoch 15/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6776 - acc: 0.5557
# Epoch 16/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.6769 - acc: 0.5679
# Epoch 17/1000
# 100/100 [==============================] - 0s 3ms/step - loss: 0.
# 150/150 [==============================] - 1s 4ms/step - loss: 0.6787 - acc: 0.5639
# 150/150 [==============================] - 3s 2ms/step - loss: 0.6792 - acc: 0.5675
# [0.679181694984436, 0.5674999952316284]

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살 + 1987

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200] + lines7[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200] + lines8[:3200]
test_t = test1[:800] + test3[:800] + test5[:800] + test7[:800]
test_ut = test2[:800] + test4[:800] + test6[:800] + test8[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )


model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/1000
# 200/200 [==============================] - 8s 3ms/step - loss: 0.6915 - acc: 0.5281
# Epoch 2/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6890 - acc: 0.5271
# Epoch 3/1000
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6869 - acc: 0.5313
# Epoch 4/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6858 - acc: 0.5361
# Epoch 5/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6847 - acc: 0.5386
# Epoch 6/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6841 - acc: 0.5425
# Epoch 7/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6837 - acc: 0.5457
# Epoch 8/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6833 - acc: 0.5450
# Epoch 9/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6832 - acc: 0.5472
# Epoch 10/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6831 - acc: 0.5473
# Epoch 11/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6830 - acc: 0.5472
# Epoch 12/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6828 - acc: 0.5457
# Epoch 13/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6825 - acc: 0.5495
# Epoch 14/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6825 - acc: 0.5477
# Epoch 15/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6822 - acc: 0.5510
# Epoch 16/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6823 - acc: 0.5507
# Epoch 17/1000
# 200/200 [==============================] - 1s 3ms/step - loss: 0.6823 - acc: 0.5522
# Epoch 18/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6819 - acc: 0.5496
# Epoch 19/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6820 - acc: 0.5527
# Epoch 20/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6820 - acc: 0.5508
# Epoch 21/1000
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6819 - acc: 0.5522
# Epoch 22/1000
# 158/200 [======================>.......] - ETA: 0s - loss: 0.6820 - acc: 0.5534

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살 + 1987 + 택시운전사

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200] + lines7[:3200] + lines9[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200] + lines8[:3200] + lines10[:3200]
test_t = test1[:800] + test3[:800] + test5[:800] + test7[:800] + test9[:800]
test_ut = test2[:800] + test4[:800] + test6[:800] + test8[:800] + test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )



model.evaluate(input_test, test_labels)

# %% [markdown]
# ## 완벽한 타인 + 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines3[:3200] + lines5[:3200] 
lines_ut = lines4[:3200] + lines6[:3200]
test_t = test3[:800] + test5[:800] 
test_ut = test4[:800] + test6[:800] 


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )



model.evaluate(input_test, test_labels)

# %% [markdown]
# ## 완벽한 타인

# %%
from keras.models import Model
lines_t = lines3[:3200]
lines_ut = lines4[:3200]
test_t = test3[:800]
test_ut = test4[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )

model.evaluate(input_test, test_labels)

# %% [markdown]
# ## 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines5[:3200]
lines_ut = lines6[:3200]
test_t = test5[:800]
test_ut = test6[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )

model.evaluate(input_test, test_labels)

# %% [markdown]
# ## 1987

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines7[:3200]
lines_ut = lines8[:3200]
test_t = test7[:800]
test_ut = test8[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )



model.evaluate(input_test, test_labels)

# %% [markdown]
# ## 택시운전사

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines9[:3200]
lines_ut = lines10[:3200]
test_t = test9[:800]
test_ut = test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )


model.evaluate(input_test, test_labels)

# %% [markdown]
# ## 택시운전사 - corelation과 sentiment만

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines9[:3200]
lines_ut = lines10[:3200]
test_t = test9[:800]
test_ut = test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,2)
input_test = input_test.reshape(-1,1,2)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])

from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='acc', patience=10, mode='auto')

history = model.fit(input_train, train_labels,
                    epochs=1000,
                    batch_size=128,callbacks=[early_stopping]
                    )



model.evaluate(input_test, test_labels)

# %% [markdown]
# # definition 1

# %% [markdown]
# ## 공작

# %% [markdown]
# ## 공작 + 완벽한 타인

# %% [markdown]
# ## 완벽한 타인

# %% [markdown]
# ## 암살

# %% [markdown]
# ## 1987

# %% [markdown]
# # definition 1
