# %%
import random

file = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/spynorth_test_t1.txt",  "w",encoding='utf-8')
f1 = open("./spy/spynorth_test_ut1.txt",  "w",encoding='utf-8')
f2 = open("./spy/spynorth_scaling_trust1.txt",  "w",encoding='utf-8')
f3 = open("./spy/spynorth_scaling_untrust1.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =4560
test = 1140

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
file = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/spynorth_test_t2.txt",  "w",encoding='utf-8')
f1 = open("./spy/spynorth_test_ut2.txt",  "w",encoding='utf-8')
f2 = open("./spy/spynorth_scaling_trust2.txt",  "w",encoding='utf-8')
f3 = open("./spy/spynorth_scaling_untrust2.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =3760
test = 940


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
file = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/spynorth_test_t3.txt",  "w",encoding='utf-8')
f1 = open("./spy/spynorth_test_ut3.txt",  "w",encoding='utf-8')
f2 = open("./spy/spynorth_scaling_trust3.txt",  "w",encoding='utf-8')
f3 = open("./spy/spynorth_scaling_untrust3.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =2960
test = 740


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
file = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/spynorth_test_t4.txt",  "w",encoding='utf-8')
f1 = open("./spy/spynorth_test_ut4.txt",  "w",encoding='utf-8')
f2 = open("./spy/spynorth_scaling_trust4.txt",  "w",encoding='utf-8')
f3 = open("./spy/spynorth_scaling_untrust4.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =2160
test = 540


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
file = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/spynorth_test_t5.txt",  "w",encoding='utf-8')
f1 = open("./spy/spynorth_test_ut5.txt",  "w",encoding='utf-8')
f2 = open("./spy/spynorth_scaling_trust5.xt",  "w",encoding='utf-8')
f3 = open("./spy/spynorth_scaling_untrust5.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =1360
test = 340


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
file = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./helpfulness/spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./helpfulness/spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/spynorth_test_t6.txt",  "w",encoding='utf-8')
f1 = open("./spy/spynorth_test_ut6.txt",  "w",encoding='utf-8')
f2 = open("./spy/spynorth_scaling_trust6.txt",  "w",encoding='utf-8')
f3 = open("./spy/spynorth_scaling_untrust6.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =560
test = 140

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()
