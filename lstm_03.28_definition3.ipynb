# %% [markdown]
# # definition 3

# %%
from keras.preprocessing.text import Tokenizer
import codecs
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import nltk
from konlpy.tag import Okt
from tqdm import tqdm

# train set
name = "3"
filename1 = './new_data/definition'+name+'_spynorth_scaling_trust.txt'
filename2 = './new_data/definition'+name+'_spynorth_scaling_untrust.txt'
filename3 = './new_data/definition'+name+'_intistranger_scaling_trust.txt'
filename4 = './new_data/definition'+name+'_intistranger_scaling_untrust.txt'
filename5 = './new_data/definition'+name+'_assassin_scaling_trust.txt'
filename6 = './new_data/definition'+name+'_assassin_scaling_untrust.txt'
filename7 = './new_data/definition'+name+'_1987_scaling_trust.txt'
filename8 = './new_data/definition'+name+'_1987_scaling_untrust.txt'
filename9 = './new_data/definition'+name+'_taxi_scaling_trust.txt'
filename10 = './new_data/definition'+name+'_taxi_scaling_untrust.txt'


with codecs.open(filename1, 'r', encoding='utf-8-sig') as f:
    lines1 = f.readlines()
with codecs.open(filename2, 'r', encoding='utf-8-sig') as f:
    lines2 = f.readlines()
with codecs.open(filename3, 'r', encoding='utf-8-sig') as f:
    lines3 = f.readlines()
with codecs.open(filename4, 'r', encoding='utf-8-sig') as f:
    lines4 = f.readlines()
with codecs.open(filename5, 'r', encoding='utf-8-sig') as f:
    lines5 = f.readlines()
with codecs.open(filename6, 'r', encoding='utf-8-sig') as f:
    lines6 = f.readlines()
with codecs.open(filename7, 'r', encoding='utf-8-sig') as f:
    lines7 = f.readlines()
with codecs.open(filename8, 'r', encoding='utf-8-sig') as f:
    lines8 = f.readlines()
with codecs.open(filename9, 'r', encoding='utf-8-sig') as f:
    lines9 = f.readlines()
with codecs.open(filename10, 'r', encoding='utf-8-sig') as f:
    lines10 = f.readlines()




# test set


with codecs.open('./new_data/definition'+name+'_spynorth_test_t.txt', 'r', 'utf-8-sig') as f:
    test1 = f.readlines()
with codecs.open('./new_data/definition'+name+'_spynorth_test_ut.txt', 'r', 'utf-8-sig') as f:
    test2 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test3 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test4 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test5 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test6 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test7 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test8 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test9 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test10 = f.readlines()

# %% [markdown]
# ## 공작

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1
lines_ut = lines2
test_t = test1
test_ut = test2


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []
for line in lines_t:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    text = line.split(",")[3]
    test_lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    text = line.split(",")[3]
    test_lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(0)
for j in range(len(lines_ut)):
    train_labels.append(1)
for i in range(len(test_t)):
    test_labels.append(0)
for j in range(len(test_ut)):
    test_labels.append(1)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200]
lines_ut = lines2[:3200]
test_t = test1[:800]
test_ut = test2[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6925 - acc: 0.5319
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6864 - acc: 0.5636
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6841 - acc: 0.5653
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6826 - acc: 0.5700
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6814 - acc: 0.5680
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6805 - acc: 0.5678
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6798 - acc: 0.5703
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6791 - acc: 0.5692
# Epoch 9/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6783 - acc: 0.5713
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6779 - acc: 0.5725
# 50/50 [==============================] - 1s 896us/step - loss: 0.6766 - acc: 0.5750
# [0.6765523552894592, 0.574999988079071]

# %% [markdown]
# ## 공작 + 완벽한 타인

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200]
lines_ut = lines2[:3200] + lines4[:3200]
test_t = test1[:800] + test3[:800]
test_ut = test2[:800] + test4[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 1s 1ms/step - loss: 0.6878 - acc: 0.5504
# Epoch 2/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6852 - acc: 0.5455
# Epoch 3/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6836 - acc: 0.5429
# Epoch 4/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6823 - acc: 0.5437
# Epoch 5/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6815 - acc: 0.5475
# Epoch 6/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6805 - acc: 0.5525
# Epoch 7/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6801 - acc: 0.5494
# Epoch 8/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6794 - acc: 0.5564
# Epoch 9/10
# 100/100 [==============================] - 0s 2ms/step - loss: 0.6790 - acc: 0.5553
# Epoch 10/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6788 - acc: 0.5547
# 100/100 [==============================] - 1s 785us/step - loss: 0.6812 - acc: 0.5556
# [0.6812061071395874, 0.5556250214576721]

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200]
test_t = test1[:800] + test3[:800] + test5[:800]
test_ut = test2[:800] + test4[:800] + test6[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 150/150 [==============================] - 2s 1ms/step - loss: 0.6906 - acc: 0.5346
# Epoch 2/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6874 - acc: 0.5360
# Epoch 3/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6856 - acc: 0.5402
# Epoch 4/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6846 - acc: 0.5371
# Epoch 5/10
# 150/150 [==============================] - 0s 2ms/step - loss: 0.6836 - acc: 0.5392
# Epoch 6/10
# 150/150 [==============================] - 0s 2ms/step - loss: 0.6832 - acc: 0.5410
# Epoch 7/10
# 150/150 [==============================] - 0s 2ms/step - loss: 0.6827 - acc: 0.5439
# Epoch 8/10
# 150/150 [==============================] - 0s 2ms/step - loss: 0.6823 - acc: 0.5437
# Epoch 9/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6819 - acc: 0.5471
# Epoch 10/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6817 - acc: 0.5508
# 150/150 [==============================] - 1s 776us/step - loss: 0.6821 - acc: 0.5579
# [0.6821079850196838, 0.5579166412353516]

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살 + 1987

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200] + lines7[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200] + lines8[:3200]
test_t = test1[:800] + test3[:800] + test5[:800] + test7[:800]
test_ut = test2[:800] + test4[:800] + test6[:800] + test8[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 2s 1ms/step - loss: 0.6911 - acc: 0.5281
# Epoch 2/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6884 - acc: 0.5306
# Epoch 3/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6868 - acc: 0.5340
# Epoch 4/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6860 - acc: 0.5405
# Epoch 5/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6853 - acc: 0.5408
# Epoch 6/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6847 - acc: 0.5412
# Epoch 7/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6841 - acc: 0.5446
# Epoch 8/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6840 - acc: 0.5432
# Epoch 9/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6837 - acc: 0.5456
# Epoch 10/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6834 - acc: 0.5464
# 200/200 [==============================] - 1s 962us/step - loss: 0.6809 - acc: 0.5573
# [0.6809489727020264, 0.5573437213897705]

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살 + 1987 + 택시운전사

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200] + lines7[:3200] + lines9[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200] + lines8[:3200] + lines10[:3200]
test_t = test1[:800] + test3[:800] + test5[:800] + test7[:800] + test9[:800]
test_ut = test2[:800] + test4[:800] + test6[:800] + test8[:800] + test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 2s 1ms/step - loss: 0.6910 - acc: 0.5246
# Epoch 2/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6877 - acc: 0.5315
# Epoch 3/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6863 - acc: 0.5398
# Epoch 4/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6857 - acc: 0.5389
# Epoch 5/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6852 - acc: 0.5415
# Epoch 6/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6847 - acc: 0.5426
# Epoch 7/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6846 - acc: 0.5453
# Epoch 8/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6843 - acc: 0.5454
# Epoch 9/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6841 - acc: 0.5460
# Epoch 10/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6841 - acc: 0.5471
# 250/250 [==============================] - 1s 785us/step - loss: 0.6820 - acc: 0.5569
# [0.6820316910743713, 0.5568749904632568]

# %% [markdown]
# ## 완벽한 타인 + 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines3[:3200] + lines5[:3200] 
lines_ut = lines4[:3200] + lines6[:3200]
test_t = test3[:800] + test5[:800] 
test_ut = test4[:800] + test6[:800] 


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 2s 1ms/step - loss: 0.6916 - acc: 0.5233
# Epoch 2/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6897 - acc: 0.5216
# Epoch 3/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6885 - acc: 0.5320
# Epoch 4/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6878 - acc: 0.5329
# Epoch 5/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6873 - acc: 0.5387
# Epoch 6/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6870 - acc: 0.5391
# Epoch 7/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6867 - acc: 0.5408
# Epoch 8/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6863 - acc: 0.5377
# Epoch 9/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6859 - acc: 0.5410
# Epoch 10/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6856 - acc: 0.5422
# 100/100 [==============================] - 1s 897us/step - loss: 0.6873 - acc: 0.5372
# [0.6872842907905579, 0.5371875166893005]

# %% [markdown]
# ## 완벽한 타인

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines3[:3200]
lines_ut = lines4[:3200]
test_t = test3[:800]
test_ut = test4[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6926 - acc: 0.5172
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6906 - acc: 0.5316
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6893 - acc: 0.5352
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6880 - acc: 0.5389
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6868 - acc: 0.5402
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6862 - acc: 0.5381
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6855 - acc: 0.5344
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6850 - acc: 0.5347
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6843 - acc: 0.5367
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6838 - acc: 0.5369
# 50/50 [==============================] - 1s 875us/step - loss: 0.6873 - acc: 0.5206
# [0.687253475189209, 0.5206249952316284]

# %% [markdown]
# ## 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines5[:3200]
lines_ut = lines6[:3200]
test_t = test5[:800]
test_ut = test6[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6933 - acc: 0.5091
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6927 - acc: 0.5102
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6922 - acc: 0.5167
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6916 - acc: 0.5183
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6912 - acc: 0.5323
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6910 - acc: 0.5156
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6908 - acc: 0.5206
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6902 - acc: 0.5327
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6901 - acc: 0.5348
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6899 - acc: 0.5266
# 50/50 [==============================] - 1s 956us/step - loss: 0.6892 - acc: 0.5194
# [0.6891966462135315, 0.5193750262260437]

# %% [markdown]
# ## 1987

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines7[:3200]
lines_ut = lines8[:3200]
test_t = test7[:800]
test_ut = test8[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6938 - acc: 0.5078
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6929 - acc: 0.5034
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6922 - acc: 0.5208
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6916 - acc: 0.5316
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6911 - acc: 0.5314
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6907 - acc: 0.5255
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6902 - acc: 0.5350
# Epoch 8/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6900 - acc: 0.5356
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6899 - acc: 0.5317
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6896 - acc: 0.5342
# 50/50 [==============================] - 1s 854us/step - loss: 0.6841 - acc: 0.5719
# [0.6840678453445435, 0.5718749761581421]

# %% [markdown]
# ## 택시운전사

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines9[:3200]
lines_ut = lines10[:3200]
test_t = test9[:800]
test_ut = test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6932 - acc: 0.5106
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6922 - acc: 0.5139
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6917 - acc: 0.5150
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6913 - acc: 0.5227
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6904 - acc: 0.5350
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6905 - acc: 0.5211
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6902 - acc: 0.5205
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6900 - acc: 0.5208
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6899 - acc: 0.5264
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6896 - acc: 0.5373
# 50/50 [==============================] - 1s 814us/step - loss: 0.6902 - acc: 0.5094
# [0.6901735067367554, 0.5093749761581421]

# %% [markdown]
# ## 택시운전사 - corelation과 sentiment만

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines9[:3200]
lines_ut = lines10[:3200]
test_t = test9[:800]
test_ut = test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,2)
input_test = input_test.reshape(-1,1,2)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6933 - acc: 0.4967
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6928 - acc: 0.5086
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6926 - acc: 0.5139
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6923 - acc: 0.5189
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6920 - acc: 0.5211
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6918 - acc: 0.5247
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6917 - acc: 0.5277
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6915 - acc: 0.5245
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6914 - acc: 0.5302
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6913 - acc: 0.5295
# 50/50 [==============================] - 1s 855us/step - loss: 0.6909 - acc: 0.5344
# [0.6909406781196594, 0.534375011920929]

# %% [markdown]
# ## 공작 - correlation 과 sentiment만

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + 
lines_ut = lines2[:3200]
test_t = test1[:800]
test_ut = test2[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,2)
input_test = input_test.reshape(-1,1,2)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 2ms/step - loss: 0.6926 - acc: 0.5197
# Epoch 2/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6913 - acc: 0.5550
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6900 - acc: 0.5631
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6884 - acc: 0.5694
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6868 - acc: 0.5722
# Epoch 6/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6850 - acc: 0.5709
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6834 - acc: 0.5722
# Epoch 8/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6819 - acc: 0.5681
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6808 - acc: 0.5653
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6798 - acc: 0.5705
# 50/50 [==============================] - 0s 875us/step - loss: 0.6788 - acc: 0.5669
# [0.6788248419761658, 0.5668749809265137]

# %% [markdown]
# # definition 1

# %% [markdown]
# ## 공작

# %% [markdown]
# ## 공작 + 완벽한 타인

# %% [markdown]
# ## 완벽한 타인

# %% [markdown]
# ## 암살

# %% [markdown]
# ## 1987

# %% [markdown]
# # definition 1
