# %% [markdown]
# # definition 1

# %%
from keras.preprocessing.text import Tokenizer
import codecs
from keras.preprocessing.sequence import pad_sequences
import numpy as np
import nltk
from konlpy.tag import Okt
from tqdm import tqdm

# train set
name = "1"
filename1 = './new_data/definition'+name+'_spynorth_scaling_trust.txt'
filename2 = './new_data/definition'+name+'_spynorth_scaling_untrust.txt'
filename3 = './new_data/definition'+name+'_intistranger_scaling_trust.txt'
filename4 = './new_data/definition'+name+'_intistranger_scaling_untrust.txt'
filename5 = './new_data/definition'+name+'_assassin_scaling_trust.txt'
filename6 = './new_data/definition'+name+'_assassin_scaling_untrust.txt'
filename7 = './new_data/definition'+name+'_1987_scaling_trust.txt'
filename8 = './new_data/definition'+name+'_1987_scaling_untrust.txt'
filename9 = './new_data/definition'+name+'_taxi_scaling_trust.txt'
filename10 = './new_data/definition'+name+'_taxi_scaling_untrust.txt'


with codecs.open(filename1, 'r', encoding='utf-8-sig') as f:
    lines1 = f.readlines()
with codecs.open(filename2, 'r', encoding='utf-8-sig') as f:
    lines2 = f.readlines()
with codecs.open(filename3, 'r', encoding='utf-8-sig') as f:
    lines3 = f.readlines()
with codecs.open(filename4, 'r', encoding='utf-8-sig') as f:
    lines4 = f.readlines()
with codecs.open(filename5, 'r', encoding='utf-8-sig') as f:
    lines5 = f.readlines()
with codecs.open(filename6, 'r', encoding='utf-8-sig') as f:
    lines6 = f.readlines()
with codecs.open(filename7, 'r', encoding='utf-8-sig') as f:
    lines7 = f.readlines()
with codecs.open(filename8, 'r', encoding='utf-8-sig') as f:
    lines8 = f.readlines()
with codecs.open(filename9, 'r', encoding='utf-8-sig') as f:
    lines9 = f.readlines()
with codecs.open(filename10, 'r', encoding='utf-8-sig') as f:
    lines10 = f.readlines()




# test set


with codecs.open('./new_data/definition'+name+'_spynorth_test_t.txt', 'r', 'utf-8-sig') as f:
    test1 = f.readlines()
with codecs.open('./new_data/definition'+name+'_spynorth_test_ut.txt', 'r', 'utf-8-sig') as f:
    test2 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test3 = f.readlines()
with codecs.open('./new_data/definition'+name+'_intistranger_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test4 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test5 = f.readlines()
with codecs.open('./new_data/definition'+name+'_assassin_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test6 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test7 = f.readlines()
with codecs.open('./new_data/definition'+name+'_1987_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test8 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_t.txt', 'r', encoding='utf-8-sig') as f:
    test9 = f.readlines()
with codecs.open('./new_data/definition'+name+'_taxi_test_ut.txt', 'r', encoding='utf-8-sig') as f:
    test10 = f.readlines()

# %% [markdown]
# ## 공작

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1
lines_ut = lines2
test_t = test1
test_ut = test2


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []
for line in lines_t:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    text = line.split(",")[3]
    lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    text = line.split(",")[3]
    test_lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    text = line.split(",")[3]
    test_lines_.append(text.strip())
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(0)
for j in range(len(lines_ut)):
    train_labels.append(1)
for i in range(len(test_t)):
    test_labels.append(0)
for j in range(len(test_ut)):
    test_labels.append(1)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200]
lines_ut = lines2[:3200]
test_t = test1[:800]
test_ut = test2[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6647 - acc: 0.6884
# Epoch 2/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6456 - acc: 0.7097
# Epoch 3/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6304 - acc: 0.7061
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6165 - acc: 0.7066
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6047 - acc: 0.7050
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5947 - acc: 0.7061
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5859 - acc: 0.7080
# Epoch 8/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5784 - acc: 0.7078
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5728 - acc: 0.7072
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.5685 - acc: 0.7081
# 50/50 [==============================] - 0s 875us/step - loss: 0.5687 - acc: 0.7125
# [0.5686795711517334, 0.7124999761581421]

# %% [markdown]
# ## 공작 + 완벽한 타인

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200]
lines_ut = lines2[:3200] + lines4[:3200]
test_t = test1[:800] + test3[:800]
test_ut = test2[:800] + test4[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 1s 1ms/step - loss: 0.6702 - acc: 0.6528
# Epoch 2/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6476 - acc: 0.6456
# Epoch 3/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6309 - acc: 0.6447
# Epoch 4/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6183 - acc: 0.6505
# Epoch 5/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6088 - acc: 0.6563
# Epoch 6/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6021 - acc: 0.6593
# Epoch 7/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5980 - acc: 0.6598
# Epoch 8/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5955 - acc: 0.6588
# Epoch 9/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5939 - acc: 0.6587
# Epoch 10/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5927 - acc: 0.6596
# 100/100 [==============================] - 1s 786us/step - loss: 0.6006 - acc: 0.6503
# [0.6006318926811218, 0.6503124833106995]

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200]
test_t = test1[:800] + test3[:800] + test5[:800]
test_ut = test2[:800] + test4[:800] + test6[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 150/150 [==============================] - 1s 1ms/step - loss: 0.6729 - acc: 0.6270
# Epoch 2/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6478 - acc: 0.6229
# Epoch 3/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6328 - acc: 0.6230
# Epoch 4/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6240 - acc: 0.6297
# Epoch 5/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6188 - acc: 0.6327
# Epoch 6/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6159 - acc: 0.6320
# Epoch 7/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6142 - acc: 0.6346
# Epoch 8/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6131 - acc: 0.6358
# Epoch 9/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6125 - acc: 0.6377
# Epoch 10/10
# 150/150 [==============================] - 0s 1ms/step - loss: 0.6122 - acc: 0.6382
# 150/150 [==============================] - 1s 763us/step - loss: 0.6178 - acc: 0.6425
# [0.6178112030029297, 0.6424999833106995]

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살 + 1987

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200] + lines7[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200] + lines8[:3200]
test_t = test1[:800] + test3[:800] + test5[:800] + test7[:800]
test_ut = test2[:800] + test4[:800] + test6[:800] + test8[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 200/200 [==============================] - 1s 1ms/step - loss: 0.6736 - acc: 0.6007
# Epoch 2/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6500 - acc: 0.6024
# Epoch 3/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6374 - acc: 0.6065
# Epoch 4/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6313 - acc: 0.6130
# Epoch 5/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6281 - acc: 0.6161
# Epoch 6/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6267 - acc: 0.6179
# Epoch 7/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6259 - acc: 0.6198
# Epoch 8/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6253 - acc: 0.6193
# Epoch 9/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6249 - acc: 0.6214
# Epoch 10/10
# 200/200 [==============================] - 0s 1ms/step - loss: 0.6248 - acc: 0.6230
# 200/200 [==============================] - 1s 697us/step - loss: 0.6272 - acc: 0.6212
# [0.6271951794624329, 0.6212499737739563]

# %% [markdown]
# ## 공작 + 완벽한 타인 + 암살 + 1987 + 택시운전사

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines1[:3200] + lines3[:3200] + lines5[:3200] + lines7[:3200] + lines9[:3200]
lines_ut = lines2[:3200] + lines4[:3200] + lines6[:3200] + lines8[:3200] + lines10[:3200]
test_t = test1[:800] + test3[:800] + test5[:800] + test7[:800] + test9[:800]
test_ut = test2[:800] + test4[:800] + test6[:800] + test8[:800] + test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 250/250 [==============================] - 1s 1ms/step - loss: 0.6707 - acc: 0.5976
# Epoch 2/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6469 - acc: 0.5980
# Epoch 3/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6381 - acc: 0.6044
# Epoch 4/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6342 - acc: 0.6090
# Epoch 5/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6324 - acc: 0.6122
# Epoch 6/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6315 - acc: 0.6094
# Epoch 7/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6310 - acc: 0.6123
# Epoch 8/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6305 - acc: 0.6123
# Epoch 9/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6302 - acc: 0.6139
# Epoch 10/10
# 250/250 [==============================] - 0s 1ms/step - loss: 0.6300 - acc: 0.6127
# 250/250 [==============================] - 1s 693us/step - loss: 0.6311 - acc: 0.6158
# [0.6310908198356628, 0.6157500147819519]

# %% [markdown]
# ## 완벽한 타인 + 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines3[:3200] + lines5[:3200] 
lines_ut = lines4[:3200] + lines6[:3200]
test_t = test3[:800] + test5[:800] 
test_ut = test4[:800] + test6[:800] 


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 1s 1ms/step - loss: 0.6907 - acc: 0.5652
# Epoch 2/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6736 - acc: 0.5970
# Epoch 3/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6631 - acc: 0.5908
# Epoch 4/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6555 - acc: 0.5919
# Epoch 5/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6503 - acc: 0.5938
# Epoch 6/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6460 - acc: 0.5938
# Epoch 7/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6428 - acc: 0.5980
# Epoch 8/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6405 - acc: 0.5988
# Epoch 9/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6385 - acc: 0.6007
# Epoch 10/10
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6369 - acc: 0.6044
# 100/100 [==============================] - 1s 816us/step - loss: 0.6407 - acc: 0.6000
# [0.6406884789466858, 0.6000000238418579]

# %% [markdown]
# ## 완벽한 타인

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines3[:3200]
lines_ut = lines4[:3200]
test_t = test3[:800]
test_ut = test4[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6859 - acc: 0.5714
# Epoch 2/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6772 - acc: 0.6092
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6700 - acc: 0.6059
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6631 - acc: 0.6016
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6581 - acc: 0.6014
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6528 - acc: 0.6003
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6486 - acc: 0.6005
# Epoch 8/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6450 - acc: 0.5989
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6412 - acc: 0.6077
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6385 - acc: 0.6048
# 50/50 [==============================] - 0s 875us/step - loss: 0.6453 - acc: 0.5987
# [0.6453199982643127, 0.5987499952316284]

# %% [markdown]
# ## 암살

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines5[:3200]
lines_ut = lines6[:3200]
test_t = test5[:800]
test_ut = test6[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6906 - acc: 0.5248
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6810 - acc: 0.5877
# Epoch 3/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6735 - acc: 0.6039
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6666 - acc: 0.6012
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6610 - acc: 0.6041
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6568 - acc: 0.6008
# Epoch 7/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6535 - acc: 0.6031
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6510 - acc: 0.6023
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6492 - acc: 0.6031
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6473 - acc: 0.5992
# 50/50 [==============================] - 0s 794us/step - loss: 0.6462 - acc: 0.6031
# [0.6461578607559204, 0.6031249761581421]

# %% [markdown]
# ## 1987

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines7[:3200]
lines_ut = lines8[:3200]
test_t = test7[:800]
test_ut = test8[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 2s 2ms/step - loss: 0.6904 - acc: 0.5427
# Epoch 2/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6854 - acc: 0.5655
# Epoch 3/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6814 - acc: 0.5683
# Epoch 4/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6771 - acc: 0.5719
# Epoch 5/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6735 - acc: 0.5748
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6699 - acc: 0.5766
# Epoch 7/10
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6672 - acc: 0.5727
# Epoch 8/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6649 - acc: 0.5728
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6636 - acc: 0.5748
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6619 - acc: 0.5781
# 50/50 [==============================] - 1s 794us/step - loss: 0.6582 - acc: 0.5806
# [0.6581703424453735, 0.5806249976158142]

# %% [markdown]
# ## 택시운전사

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines9[:3200]
lines_ut = lines10[:3200]
test_t = test9[:800]
test_ut = test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[:3]
    a = list(map(float, a))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,3)
input_test = input_test.reshape(-1,1,3)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6880 - acc: 0.5602
# Epoch 2/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6809 - acc: 0.5906
# Epoch 3/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6745 - acc: 0.5916
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6685 - acc: 0.5867
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6632 - acc: 0.5819
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6593 - acc: 0.5838
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6565 - acc: 0.5784
# Epoch 8/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6540 - acc: 0.5814
# Epoch 9/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6524 - acc: 0.5755
# Epoch 10/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6506 - acc: 0.5800
# 50/50 [==============================] - 0s 814us/step - loss: 0.6469 - acc: 0.5813
# [0.6468532085418701, 0.581250011920929]

# %% [markdown]
# ## 택시운전사 - corelation과 sentiment만

# %%
from keras.layers import Input, Dense
from keras.models import Model
lines_t = lines9[:3200]
lines_ut = lines10[:3200]
test_t = test9[:800]
test_ut = test10[:800]


lines_ = []
test_lines_ = []

lines1_ = []
lines2_ = []
lines3_ = []
lines4_ = []
feature1 = []
feature2 = []
rating = []
sentiment = []
correlation = []

for line in lines_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)
    
    

for line in lines_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature1.append(a)

for line in test_t:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
for line in test_ut:
    a = line.split(",")[1]
    b = line.split(",")[2]
    k = []
    k.append(a)
    k.append(b)
    a = list(map(float, k))
    feature2.append(a)
    
    
train_labels = [] # train 데이터 label
test_labels = [] # test 데이터 label
for i in range(len(lines_t)):
    train_labels.append(1)
for j in range(len(lines_ut)):
    train_labels.append(0)
for i in range(len(test_t)):
    test_labels.append(1)
for j in range(len(test_ut)):
    test_labels.append(0)

train_labels = np.asarray(train_labels)
test_labels = np.asarray(test_labels)
input_train = np.asarray(feature1)
input_test = np.asarray(feature2)

input_train = input_train.reshape(-1,1,2)
input_test = input_test.reshape(-1,1,2)

# LSTM
from keras.layers import LSTM
from tensorflow.python.keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.models import Sequential
from keras.layers import Embedding, SimpleRNN

from keras.layers import Dense

from keras.preprocessing import sequence

model = Sequential()
model.add(LSTM(32))
# 'binary_crossentropy
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['acc'])
history = model.fit(input_train, train_labels,
                    epochs=10,
                    batch_size=128,
                    )



model.evaluate(input_test, test_labels)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 1s 1ms/step - loss: 0.6920 - acc: 0.5231
# Epoch 2/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6902 - acc: 0.5611
# Epoch 3/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6883 - acc: 0.5731
# Epoch 4/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6867 - acc: 0.5734
# Epoch 5/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6854 - acc: 0.5748
# Epoch 6/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6843 - acc: 0.5739
# Epoch 7/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6833 - acc: 0.5758
# Epoch 8/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6825 - acc: 0.5750
# Epoch 9/10
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6820 - acc: 0.5738
# Epoch 10/10
# 50/50 [==============================] - 0s 1ms/step - loss: 0.6815 - acc: 0.5747
# 50/50 [==============================] - 0s 916us/step - loss: 0.6810 - acc: 0.5806
# [0.6809581518173218, 0.5806249976158142]

# %% [markdown]
# # definition 1

# %% [markdown]
# ## 공작

# %% [markdown]
# ## 공작 + 완벽한 타인

# %% [markdown]
# ## 완벽한 타인

# %% [markdown]
# ## 암살

# %% [markdown]
# ## 1987

# %% [markdown]
# # definition 1
