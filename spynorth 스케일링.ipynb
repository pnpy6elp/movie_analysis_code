# %%
import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_t1.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_ut1.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_trust1.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_untrust1.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =4560
test = 1140

num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_t1.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_ut1.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_trust1.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_untrust1.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close() 

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_t1.txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_ut1.txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_trust1.txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_untrust1.txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
n = "2"
file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =3760
test = 940


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close() 

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
n = "3"
file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =2960
test = 740


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close() 

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
n = "4"
file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =2160
test = 540


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close() 

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
n = "5"
file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition1_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =1360
test = 340


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition2_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close() 

import random

file = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("C:/Users/user/Desktop/moviemovie/movie_analysis_code/spy/definition3_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()

# %%
import random
n = "6"
file = open("./data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./data/definition1_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./data/definition1_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/definition1_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("./spy/definition1_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("./spy/definition1_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("./spy/definition1_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]

trust_num =6608
untrust_num =5706
scaling =560
test = 140


num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()          

import random

file = open("./data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./data/definition2_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./data/definition2_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/definition2_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("./spy/definition2_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("./spy/definition2_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("./spy/definition2_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close() 

import random

file = open("./data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file1 = open("./data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
file3 = open("./data/definition3_spynorth_t.txt",  "r",encoding='utf-8')
file4 = open("./data/definition3_spynorth_ut.txt",  "r",encoding='utf-8')
f = open("./spy/definition3_spynorth_test_t"+n+".txt",  "w",encoding='utf-8')
f1 = open("./spy/definition3_spynorth_test_ut"+n+".txt",  "w",encoding='utf-8')
f2 = open("./spy/definition3_spynorth_scaling_trust"+n+".txt",  "w",encoding='utf-8')
f3 = open("./spy/definition3_spynorth_scaling_untrust"+n+".txt",  "w",encoding='utf-8')
random_num = []
random_num1 = []
random_num2 = []
random_num3=[]



num = random.randrange(0,trust_num)

for i in range(scaling):
    while (num in random_num)  :
        num = random.randrange(0,trust_num)
    random_num.append(num)

random_num.sort()    
    

count=1
while (count<=trust_num):
    line = file.readline()
    if count-1 in random_num:
        f2.write(line)
    count+=1
f2.close()

num1 = random.randrange(0,untrust_num)

for i in range(scaling):
    while (num1 in random_num1)  :
        num1 = random.randrange(0,untrust_num)
    random_num1.append(num1)

random_num1.sort()    
    

count=1
while (count<=untrust_num):
    line = file1.readline()
    if count-1 in random_num1:
        f3.write(line)
    count+=1
f3.close()

num2 = random.randrange(0,trust_num)

for i in range(test):
    while (num2 in random_num2)  :
        num2 = random.randrange(0,trust_num)
    random_num2.append(num2)

random_num2.sort()    
    

count=1
while (count<=trust_num):
    line = file3.readline()
    if count-1 in random_num2:
        f.write(line)
    count+=1
f.close()

num3 = random.randrange(0,untrust_num)

for i in range(test):
    while (num3 in random_num3)  :
        num3 = random.randrange(0,untrust_num)
    random_num3.append(num3)

random_num3.sort()    
    

count=1
while (count<=untrust_num):
    line = file4.readline()
    if count-1 in random_num3:
        f1.write(line)
    count+=1
f1.close()
